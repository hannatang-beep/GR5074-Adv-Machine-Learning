# %% [markdown]
# <a href="https://colab.research.google.com/github/hannatang-beep/GR5074-Adv-Machine-Learning/blob/main/Group1_Project_1_updated.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Your Uni : yq2397, hh3098, ht2668
# # Your Full name : Yutong Quan, Han He, Hanna Tang
# # Link to your Public Github repository with Final report  : Fill here

# %% [markdown]
# ### Submission Due Date: 03/07/2025

# %% [markdown]
# # World Happiness Classification Competition
# Goals :
# - Understand how the models function
# - Understand what the parameters control
# - Learn from the model experimentation process
# - Make a good looking notebook report
# - Upload as a personal project on Github
#
# **Overall Steps:**
# 1. Load datasets and merge them.
# 2. Preprocess data using Sklearn Column Transformer/ Write and Save Preprocessor function
# 3. Fit model on preprocessed data and save preprocessor function and model
# 4. Generate predictions from X_test data and submit predictions

# %% [markdown]
# ## 0. Loading Datasets

# %% [markdown]
# Loading the World Happiness 2023 datasets

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from google.colab import drive

# Load the dataset
whr_df = pd.read_csv('https://raw.githubusercontent.com/hannatang-beep/GR5074-Adv-Machine-Learning/refs/heads/main/data/WHR_2023.csv')

# Inspect the first few rows to understand the structure
whr_df.head()
# Out:
#        country                        region  happiness_score  gdp_per_capita  \
# 0      Finland                Western Europe            7.804           1.888
# 1      Denmark                Western Europe            7.586           1.949
# 2      Iceland                Western Europe            7.530           1.926
# 3       Israel  Middle East and North Africa            7.473           1.833
# 4  Netherlands                Western Europe            7.403           1.942
#
#    social_support  healthy_life_expectancy  freedom_to_make_life_choices  \
# 0           1.585                    0.535                         0.772
# 1           1.548                    0.537                         0.734
# 2           1.620                    0.559                         0.738
# 3           1.521                    0.577                         0.569
# 4           1.488                    0.545                         0.672
#
#    generosity  perceptions_of_corruption
# 0       0.126                      0.535
# 1       0.208                      0.525
# 2       0.250                      0.187
# 3       0.124                      0.158
# 4       0.251                      0.394

# %%
# Convert the regression target ('happiness_score') into classification labels
# We'll use quartiles to create 4 happiness categories: Very Low, Low, High, Very High

# Define quartiles
whr_df['happiness_category'] = pd.qcut(whr_df['happiness_score'],
                                       q=5,
                                       labels=['Very Low', 'Low','Average', 'High', 'Very High'])

# Select features and target
X = whr_df.drop(columns=['happiness_score', 'happiness_category'])
y = whr_df['happiness_category']

# Split into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, stratify=y)

# Convert y_train and y_test to numerical labels
y_train_labels = y_train.astype('category').cat.codes
y_test_labels = y_test.astype('category').cat.codes

# %% [markdown]
# Write in the next cell what the y_train.astype('category').cat.codes line does. What is the difference between y_train_labels and y_train?

# %%
# Your answer: y_train.astype('category')is the pre-process to convert the categorical happiness labels into numerical codes;
#.cat.codes - This accesses the numerical codes that pandas assigns to each unique category value.
# y_train_labels: Contains numerical equivalents, typically starting from 0: for this case: 'Very Low' → 0, 'Low' → 1, 'Average' → 2, 'High' → 3, 'Very High' → 4

# %%
# Truncated and cleaned up region data to merge
countrydata=pd.read_csv("https://raw.githubusercontent.com/hannatang-beep/GR5074-Adv-Machine-Learning/refs/heads/main/data/newcountryvars.csv")

countrydata.head()
# Out:
#   country_name  population  population_below_poverty_line       hdi  \
# 0        India  1339180127                           21.9  0.623559
# 1      Nigeria   190886311                           70.0  0.527105
# 2       Mexico   129163276                           46.2  0.761683
# 3     Pakistan   197015955                           29.5  0.550354
# 4   Bangladesh   164669751                           31.5  0.578824
#
#    life_expectancy  expected_years_of_schooling  mean_years_of_schooling  \
# 0           68.322                    11.696590                 6.298834
# 1           53.057                     9.970482                 6.000000
# 2           76.972                    13.299090                 8.554985
# 3           66.365                     8.106910                 5.089460
# 4           71.985                    10.178706                 5.241577
#
#             gni
# 0   5663.474799
# 1   5442.901264
# 2  16383.106680
# 3   5031.173074
# 4   3341.490722

# %%
# Merge in new data to X_train and X_test by taking "country" from first table and "country_name" from 2nd table.
# Also check which countries are common in both the datasets, and which type of merge will you perform for the best results.
# Hint: Look on the 'how' parameter of megre function of pandas.

# Merge the new country variables with X_train
X_train = X_train.merge(
    countrydata,
    left_on='country',
    right_on='country_name',
    how='left'
)

# Merge the new country variables with X_test
X_test = X_test.merge(
    countrydata,
    left_on='country',
    right_on='country_name',
    how='left'
)

# %%
common_countries = set(X_train['country']).intersection(set(countrydata['country_name']))
print(f"\nNumber of common countries in both datasets: {len(common_countries)}")
print(f"Total countries in training set: {X_train['country'].nunique()}")
print(f"Total countries in country dataset: {countrydata['country_name'].nunique()}")
# Out:
# Number of common countries in both datasets: 89
# Total countries in training set: 95
# Total countries in country dataset: 174

# %%
X_train.head(1)
# Out:
#       country              region  gdp_per_capita  social_support  \
# 0  Madagascar  Sub-Saharan Africa           0.632           0.779
#
#    healthy_life_expectancy  freedom_to_make_life_choices  generosity  \
# 0                    0.178                         0.187       0.177
#
#    perceptions_of_corruption country_name  population  \
# 0                      0.134   Madagascar  25570895.0
#
#    population_below_poverty_line       hdi  life_expectancy  \
# 0                           70.7  0.512149           65.515
#
#    expected_years_of_schooling  mean_years_of_schooling          gni
# 0                     10.34614                 6.145955  1319.699397

# %% [markdown]
# ## 1.  EDA

# %%
print(X_train.dtypes)
# Out:
# country                           object
# region                            object
# gdp_per_capita                   float64
# social_support                   float64
# healthy_life_expectancy          float64
# freedom_to_make_life_choices     float64
# generosity                       float64
# perceptions_of_corruption        float64
# country_name                      object
# population                       float64
# population_below_poverty_line    float64
# hdi                              float64
# life_expectancy                  float64
# expected_years_of_schooling      float64
# mean_years_of_schooling          float64
# gni                              float64
# dtype: object

# %% [markdown]
# Describe what you see above?

# %%
## Your answer: This image shows the data types of each column in X_train DataFrame after merging with the country data.
# String columns: country, region, country_name
# Numerical features: gdp_per_capita, population, population_below_poverty_line, gni, hdi, life_expectancy, expected_years_of_schooling, mean_years_of_schooling, social_support, healthy_life_expectancy, freedom_to_make_life_choices, generosity, perceptions_of_corruption

# %% [markdown]
# Find out the number and percentage of missing values in the table per column

# %%
missing_values = X_train.isnull().sum()

# Calculate missing values
total_rows = len(X_train)
missing_percentage = (missing_values / total_rows) * 100

# Create missing values summary
missing_summary = pd.DataFrame({
    'Missing Values': missing_values,
    'Percentage (%)': missing_percentage
})

missing_summary = missing_summary.sort_values('Missing Values', ascending=False)

print(missing_summary)
# Out:
#                                Missing Values  Percentage (%)
# population_below_poverty_line              16       16.842105
# life_expectancy                             7        7.368421
# expected_years_of_schooling                 7        7.368421
# mean_years_of_schooling                     7        7.368421
# gni                                         7        7.368421
# country_name                                6        6.315789
# population                                  6        6.315789
# hdi                                         6        6.315789
# country                                     0        0.000000
# region                                      0        0.000000
# gdp_per_capita                              0        0.000000
# social_support                              0        0.000000
# healthy_life_expectancy                     0        0.000000
# freedom_to_make_life_choices                0        0.000000
# generosity                                  0        0.000000
# perceptions_of_corruption                   0        0.000000

# %% [markdown]
# Plot the frequency distribution / histogram of some of the numerical features that you think are important

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# List of important numerical features to plot
important_features = ['gdp_per_capita', 'healthy_life_expectancy',
                      'social_support', 'freedom_to_make_life_choices',
                      'perceptions_of_corruption', 'hdi']

# Create a figure with multiple subplots
fig, axes = plt.subplots(2, 3, figsize=(18, 10))
axes = axes.flatten()

# Plot histograms for each feature
for i, feature in enumerate(important_features):
    if i < len(axes) and feature in X_train.columns:
        sns.histplot(X_train[feature], kde=True, ax=axes[i])
        axes[i].set_title(f'Distribution of {feature}')
        axes[i].set_xlabel(feature)
        axes[i].set_ylabel('Frequency')

plt.tight_layout()
plt.show()

# %% [markdown]
# Plot the categorical variables and their distribution

# %%
# Set figure size and style
plt.figure(figsize=(14, 10))
sns.set_style("whitegrid")

# region
plt.subplot(2, 1, 1)
region_counts = X_train['region'].value_counts().sort_values(ascending=False)
sns.barplot(x=region_counts.index, y=region_counts.values)
plt.title('Distribution of Countries by Region', fontsize=15)
plt.ylabel('Count', fontsize=12)
plt.xticks(rotation=45, ha='right')
plt.tight_layout(pad=3.0)

# happiness
plt.subplot(2, 1, 2)
happiness_counts = y_train.value_counts().sort_values(ascending=False)
sns.barplot(x=happiness_counts.index, y=happiness_counts.values, palette='viridis')
plt.title('Distribution of Happiness Categories', fontsize=15)
plt.ylabel('Count', fontsize=12)
plt.xlabel('Happiness Category', fontsize=12)
plt.tight_layout()

plt.show()
# Out:
# <ipython-input-111-4ed794a94751>:17: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=happiness_counts.index, y=happiness_counts.values, palette='viridis')

# %% [markdown]
# Perform feature correlation analysis to identify relationships between variables. Use Pearson, Spearman, or Kendall correlation coefficients to analyze feature dependencies.

# %%
import numpy as np
# 1. Calculate correlation matrices

numeric_columns = X_train.select_dtypes(include=[np.number]).columns

# Calculate correlation matrices
pearson_corr = X_train[numeric_columns].corr(method='pearson')
spearman_corr = X_train[numeric_columns].corr(method='spearman')

# Print Pearson correlations
print("Top Pearson Correlations:")
pearson_upper = pearson_corr.where(np.triu(np.ones(pearson_corr.shape), k=1).astype(bool))
pearson_sorted = pearson_upper.stack().sort_values(ascending=False)
print(pearson_sorted.head(10))  # Top 10 positive correlations
print(pearson_sorted.tail(10))  # Top 10 negative correlations

# Print Spearman correlations
print("\nTop Spearman Correlations:")
spearman_upper = spearman_corr.where(np.triu(np.ones(spearman_corr.shape), k=1).astype(bool))
spearman_sorted = spearman_upper.stack().sort_values(ascending=False)
print(spearman_sorted.head(10))  # Top 10 positive correlations
print(spearman_sorted.tail(10))  # Top 10 negative correlations
# Out:
# Top Pearson Correlations:
# healthy_life_expectancy      life_expectancy                0.959434
# hdi                          expected_years_of_schooling    0.939177
#                              mean_years_of_schooling        0.934324
#                              life_expectancy                0.932439
# healthy_life_expectancy      hdi                            0.929456
# gdp_per_capita               hdi                            0.902386
# expected_years_of_schooling  mean_years_of_schooling        0.880690
# gdp_per_capita               healthy_life_expectancy        0.860164
# social_support               hdi                            0.855297
# life_expectancy              expected_years_of_schooling    0.852332
# dtype: float64
# perceptions_of_corruption      population_below_poverty_line   -0.181277
# freedom_to_make_life_choices   population_below_poverty_line   -0.476459
# population_below_poverty_line  gni                             -0.537597
#                                mean_years_of_schooling         -0.579371
#                                expected_years_of_schooling     -0.582770
# social_support                 population_below_poverty_line   -0.605304
# gdp_per_capita                 population_below_poverty_line   -0.620790
# population_below_poverty_line  hdi                             -0.683361
# healthy_life_expectancy        population_below_poverty_line   -0.716390
# population_below_poverty_line  life_expectancy                 -0.719110
# dtype: float64
#
# Top Spearman Correlations:
# hdi                      gni                            0.969057
# gdp_per_capita           gni                            0.966186
# healthy_life_expectancy  life_expectancy                0.956933
# gdp_per_capita           hdi                            0.947752
# hdi                      expected_years_of_schooling    0.943715
#                          life_expectancy                0.940364
#                          mean_years_of_schooling        0.922035
# healthy_life_expectancy  hdi                            0.920871
# life_expectancy          gni                            0.902200
# gdp_per_capita           healthy_life_expectancy        0.892963
# dtype: float64
# social_support                 population                      -0.357605
# freedom_to_make_life_choices   population_below_poverty_line   -0.476760
# population_below_poverty_line  expected_years_of_schooling     -0.612283
# social_support                 population_below_poverty_line   -0.624048
# population_below_poverty_line  mean_years_of_schooling         -0.628192
# gdp_per_capita                 population_below_poverty_line   -0.650409
# population_below_poverty_line  gni                             -0.662375
#                                hdi                             -0.671239
#                                life_expectancy                 -0.677277
# healthy_life_expectancy        population_below_poverty_line   -0.682434
# dtype: float64

# %% [markdown]
# Explore relationships between variables (bivariate, etc), correlation tables, and how they associate with the target variable.

# %%
from sklearn.preprocessing import StandardScaler
import seaborn as sns

# correlation table
def correlation_table(X, y, target_name='Happiness'):
    correlations = {}
    for column in X.select_dtypes(include=[np.number]).columns:
        corr = np.corrcoef(X[column], y)[0, 1]
        correlations[column] = corr

    corr_df = pd.DataFrame({
        'Feature': list(correlations.keys()),
        'Correlation': list(correlations.values())
    })
    corr_df = corr_df.sort_values('Correlation', ascending=False)

    return corr_df

#  correlation heatmap
def plot_heatmap(X):
    numeric_X = X.select_dtypes(include=[np.number])

    corr = numeric_X.corr()

    plt.figure(figsize=(10, 8))
    sns.heatmap(corr, annot=True, cmap='coolwarm', fmt='.2f')
    plt.title('Correlation Heatmap')
    plt.tight_layout()
    plt.show()

# Bivariate plots with target
def plot_top_relationships(X, y, target_name='Happiness', n_features=5):
    corr_table = correlation_table(X, y, target_name)
    top_features = corr_table.iloc[:n_features, 0].tolist()

    plt.figure(figsize=(12, 10))
    for i, feature in enumerate(top_features):
        plt.subplot(n_features, 1, i+1)
        plt.scatter(X[feature], y, alpha=0.6)
        plt.xlabel(feature)
        plt.ylabel(target_name)
        plt.title(f'{feature} vs {target_name}')

    plt.tight_layout()
    plt.show()

# 1. Show correlation table
corr_table = correlation_table(X_train, y_train_labels, 'Happiness')
print("Correlation with Happiness:")
print(corr_table)

# 2. Plot correlation heatmap
plot_heatmap(X_train)

# 3. Plot top 5 features against target
plot_top_relationships(X_train, y_train_labels, 'Happiness', n_features=5)
# Out:
# Correlation with Happiness:
#                           Feature  Correlation
# 0                  gdp_per_capita     0.809400
# 1                  social_support     0.787159
# 2         healthy_life_expectancy     0.752381
# 3    freedom_to_make_life_choices     0.581430
# 5       perceptions_of_corruption     0.470842
# 4                      generosity    -0.012036
# 6                      population          NaN
# 7   population_below_poverty_line          NaN
# 8                             hdi          NaN
# 9                 life_expectancy          NaN
# 10    expected_years_of_schooling          NaN
# 11        mean_years_of_schooling          NaN
# 12                            gni          NaN

# %% [markdown]
# Also, detect outliers using box plots, Z-score analysis, or the IQR method to identify potential data anomalies.

# %%
def detect_outliers_simple(data, columns=None):

    if columns is None:
        columns = data.select_dtypes(include=[np.number]).columns.tolist()[:5]  # Limit to 5 features

    # 1. Box plots - visual detection
    plt.figure(figsize=(12, 8))
    sns.boxplot(data=data[columns])
    plt.title('Box Plots for Outlier Detection')
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()

    # 2. IQR method - simple statistical approach
    print("Outliers detected using IQR method (beyond ±1.5*IQR):")
    for column in columns:
        Q1 = data[column].quantile(0.25)
        Q3 = data[column].quantile(0.75)
        IQR = Q3 - Q1

        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR

        outliers = data[(data[column] < lower_bound) | (data[column] > upper_bound)]

        print(f"{column}: {len(outliers)} outliers ({len(outliers)/len(data)*100:.1f}%)")

        if len(outliers) > 0 and len(outliers) < 10:
            print(f"   Outlier values: {sorted(outliers[column].tolist())}")
            print(f"   Countries: {sorted(outliers['country'].tolist()) if 'country' in outliers.columns else 'N/A'}")

        print(f"   Normal range: [{lower_bound:.3f}, {upper_bound:.3f}]")
        print()


important_features = ['gdp_per_capita', 'social_support', 'healthy_life_expectancy',
                     'freedom_to_make_life_choices', 'generosity']

# Detect outliers
detect_outliers_simple(X_train, columns=important_features)
# Out:
# Outliers detected using IQR method (beyond ±1.5*IQR):
# gdp_per_capita: 1 outliers (1.1%)
#    Outlier values: [0.0]
#    Countries: ['Venezuela']
#    Normal range: [0.001, 2.898]
#
# social_support: 2 outliers (2.1%)
#    Outlier values: [0.0, 0.327]
#    Countries: ['Afghanistan', 'Comoros']
#    Normal range: [0.332, 2.014]
#
# healthy_life_expectancy: 0 outliers (0.0%)
#    Normal range: [-0.140, 0.892]
#
# freedom_to_make_life_choices: 3 outliers (3.2%)
#    Outlier values: [0.0, 0.117, 0.125]
#    Countries: ['Afghanistan', 'Comoros', 'Turkiye']
#    Normal range: [0.152, 0.956]
#
# generosity: 1 outliers (1.1%)
#    Outlier values: [0.422]
#    Countries: ['Indonesia']
#    Normal range: [-0.045, 0.357]

# %% [markdown]
# Write what you observed and your General comments on what should be done:

# %%
### 1. Correlation with Happiness:
#GDP per capita (0.81), social support (0.79), and healthy life expectancy (0.75) have the strongest positive correlations with happiness

### 2. Correlation Heatmap :
#HDI is highly correlated with many variables (especially healthy life expectancy at 0.93), suggesting multicollinearity
#Strong correlations between: GDP per capita and HDI (0.90); Healthy life expectancy and life expectancy (0.96); Expected years of schooling and mean years of schooling (0.88)

### 3. Outliers:
# Venezuela is an outlier for GDP per capita
# Afghanistan and Comoros are outliers for social support and freedom
# Indonesia is an outlier for generosity

# %% [markdown]
# ## 2. Feature Engineering

# %% [markdown]
# Apply log transformations to normalize skewed data and improve model stability (If any).

# %%
import pandas as pd

# Separate numeric columns
numeric_train = X_train.select_dtypes(include=['number'])
numeric_test = X_test.select_dtypes(include=['number'])

# Calculate skewness for numeric variables
skew_train = numeric_train.skew()
skew_test = numeric_test.skew()

print("Skewness of each variable in X_train:")
print(skew_train)

# Filter variables with absolute skewness greater than 1
print("\nVariables with absolute skewness > 1 (high skewness):")
high_skew_train = skew_train[skew_train.abs() > 1]

print("\nVariables in X_train with absolute skewness > 1 (high skewness):")
print(high_skew_train)
# Out:
# Skewness of each variable in X_train:
# gdp_per_capita                  -0.547790
# social_support                  -0.954425
# healthy_life_expectancy         -0.367545
# freedom_to_make_life_choices    -0.970893
# generosity                       0.555203
# perceptions_of_corruption        1.600420
# population                       6.058979
# population_below_poverty_line    1.074529
# hdi                             -0.453412
# life_expectancy                 -0.632233
# expected_years_of_schooling     -0.206557
# mean_years_of_schooling         -0.437315
# gni                              1.270302
# dtype: float64
#
# Variables with absolute skewness > 1 (high skewness):
#
# Variables in X_train with absolute skewness > 1 (high skewness):
# perceptions_of_corruption        1.600420
# population                       6.058979
# population_below_poverty_line    1.074529
# gni                              1.270302
# dtype: float64

# %%
import numpy as np
import pandas as pd

# Define the list of skewed variables
skewed_variables = ['population', 'gni', 'perceptions_of_corruption']

# Apply log transformation to skewed variables
for var in skewed_variables:
    if var in X_train.columns and var in X_test.columns:
        X_train[var + '_log'] = np.log1p(X_train[var])
        X_test[var + '_log'] = np.log1p(X_test[var])

        print(f"{var}_log skewness: {X_train[var + '_log'].skew():.3f}")
# Out:
# population_log skewness: 0.173
# gni_log skewness: -0.414
# perceptions_of_corruption_log skewness: 1.393

# %% [markdown]
# Create at least one interaction feature to capture relationship between existing variables, enhancing predictive power.

# %%
# Create one simple interaction term between the two most important features
# From your correlation results, these are gdp_per_capita and social_support

# Create the interaction
X_train['gdp_social_interaction'] = X_train['gdp_per_capita'] * X_train['social_support']
X_test['gdp_social_interaction'] = X_test['gdp_per_capita'] * X_test['social_support']

# Quick plot to see relationship with happiness
plt.figure(figsize=(8, 6))
plt.scatter(X_train['gdp_social_interaction'], y_train)
plt.xlabel('GDP × Social Support')
plt.ylabel('Happiness Category')
plt.title('Effect of GDP and Social Support Interaction on Happiness')
plt.show()

# Check correlation with target
correlation = np.corrcoef(X_train['gdp_social_interaction'], y_train_labels)[0, 1]
print(f"Correlation between GDP × Social Support and Happiness: {correlation:.4f}")
# Out:
# Correlation between GDP × Social Support and Happiness: 0.8691

# %% [markdown]
# ## 3.   Preprocess data using Sklearn Column Transformer/ Write and Save Preprocessor function

# %%
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer, make_column_transformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder

# Create the preprocessing pipelines for both numeric and categorical data.

numeric_features = X_train.select_dtypes(include=['number']).columns.tolist()
categorical_features = ['country', 'region']

numeric_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='constant', fill_value=0)), ## Is this good enough?
    ('scaler', StandardScaler())]) # You will need to describe why this is being done in the next cell

#Replacing missing values with Modal value and then one hot encoding.
categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))
])
# final preprocessor object set up with ColumnTransformer
preprocessor = ColumnTransformer(transformers=[
    ('num', numeric_transformer, numeric_features),
     ('cat', categorical_transformer, categorical_features)])

#Fit your preprocessor object
preprocess=preprocessor.fit(X_train)

# %%
print(X_train.columns.tolist())
# Out:
# ['country', 'region', 'gdp_per_capita', 'social_support', 'healthy_life_expectancy', 'freedom_to_make_life_choices', 'generosity', 'perceptions_of_corruption', 'country_name', 'population', 'population_below_poverty_line', 'hdi', 'life_expectancy', 'expected_years_of_schooling', 'mean_years_of_schooling', 'gni', 'population_log', 'gni_log', 'perceptions_of_corruption_log', 'gdp_social_interaction']

# %% [markdown]
# Describe step-by-step what we are doing above, and why? You are free to change how values are imputed. What change did you make if any, and why?

# %%
## Your answer : we separate numeric and categorical features to apply different transformations to each type.

## Numeric Data Processing:
# Imputation: We replace missing values with 0 using SimpleImputer(strategy='constant', fill_value=0).
# Scaling: We standardize features using StandardScaler(), which transforms each feature to have mean=0 and standard deviation=1.
# This scaling is crucial because features like GDP and population have vastly different scales, which could cause some variables to dominate in distance-based algorithms or gradient-based optimization.

##Categorical Data Processing:
# Imputation: We replace missing values with the most frequent value using SimpleImputer(strategy='most_frequent').
# Encoding: We convert categorical variables into numeric form using OneHotEncoder(handle_unknown='ignore').
# The handle_unknown='ignore' parameter ensures our pipeline doesn't break if new categories appear in the test set.

##Pipeline Construction:
#We organize these operations into separate pipelines for each data type. -> This ensures transformations are applied in the correct order.

##Combining Transformers:
#ColumnTransformer applies each pipeline to the appropriate columns. -> This creates a unified preprocessing workflow that handles mixed data types.

##Fit and Transform:
#We fit the preprocessor on training data, learning parameters like means and standard deviations.
#We then transform both training and test data consistently.

# %%
# Write function to transform data with preprocessor

def preprocessor(data):
    data.drop(['country', 'region'], axis=1)
    preprocessed_data=preprocess.transform(data)
    return preprocessed_data

# %% [markdown]
# What are the differences between the "preprocessor" object, the "preprocess" object, the "preprocessor" function,  and the "preprocessed_data" that is returned finally?

# %%
## Your Answer :

##Preprocessor object:
#is the ColumnTransformer that defines the transformation steps for numeric and categorical data.

##Preprocess object:
#is the fitted version of that transformer (i.e., it has learned the necessary parameters from the training data).

##Preprocessor function:
#is a user-defined wrapper that first drops unneeded columns (like 'country' and 'region') and then applies the fitted transformation.

##Preprocessed_data:
#is the resulting output after transforming the input data with the preprocessor function, which is ready for modeling.

# %%
# check shape of X data after preprocessing it using our new function
preprocessor(X_train).shape
# Out:
# (95, 122)

# %% [markdown]
# ## 4. Fit model on preprocessed data and save preprocessor function and model

# %%
# Preprocess the training and testing data using the preprocessor function

X_train_preprocessed = preprocessor(X_train)
X_test_preprocessed = preprocessor(X_test)

# %%
from sklearn.ensemble import RandomForestClassifier

## Define a Random Forest Model here, fit it, and score it
model_1 = RandomForestClassifier(n_estimators=100, random_state=42)

# Fit the model on the preprocessed training data and corresponding labels
model_1.fit(X_train_preprocessed, y_train_labels)

# Score the model on the preprocessed test set
score = model_1.score(X_test_preprocessed, y_test_labels)
print("Random Forest Model 1 Test Score:", score)

# Your cell should have a score between 0-1 as output
# Out:
# Random Forest Model 1 Test Score: 0.5952380952380952

# %% [markdown]
# ## 5. Generate predictions from X_test data and compare it with true labels in Y_test

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

#-- Generate predicted values (Model 1)
prediction_labels_1 = model_1.predict(X_test_preprocessed)

## Write code to show model performance by comparing prediction_labels with true labels

# Calculate accuracy
accuracy_1 = accuracy_score(y_test_labels, prediction_labels_1)
print("Model 1 Accuracy:", accuracy_1)

# Print classification report
print("Classification Report (Model 1):")
print(classification_report(y_test_labels, prediction_labels_1))

# Print confusion matrix
print("Confusion Matrix (Model 1):")
print(confusion_matrix(y_test_labels, prediction_labels_1))
# Out:
# Model 1 Accuracy: 0.5952380952380952
# Classification Report (Model 1):
#               precision    recall  f1-score   support
#
#            0       0.57      0.44      0.50         9
#            1       0.40      0.50      0.44         8
#            2       0.60      0.75      0.67         8
#            3       0.62      0.62      0.62         8
#            4       0.86      0.67      0.75         9
#
#     accuracy                           0.60        42
#    macro avg       0.61      0.60      0.60        42
# weighted avg       0.62      0.60      0.60        42
#
# Confusion Matrix (Model 1):
# [[4 5 0 0 0]
#  [3 4 1 0 0]
#  [0 1 6 1 0]
#  [0 0 2 5 1]
#  [0 0 1 2 6]]

# %% [markdown]
# ## 6. Repeat the process with different parameters to improve the accuracy

# %%
# Train model 2 using same preprocessor (note that you could save a new preprocessor, but we will use the same one for this example).
from sklearn.ensemble import RandomForestClassifier

## Make a new model with changed parameters to improve the score

model_2 = RandomForestClassifier(
    n_estimators=500,
    max_depth=15,
    min_samples_split=10,
    random_state=42
)

# Fit the model using the preprocessed training data
model_2.fit(X_train_preprocessed, y_train_labels)
# Out:
# RandomForestClassifier(max_depth=15, min_samples_split=10, n_estimators=500,
#                        random_state=42)

# %% [markdown]
#  What changes did you make, what do the parameters you changed control, and why does it improve performance?

# %%
## Your answer :
# Increased the number of trees (n_estimators=200) to reduce variance
# Limited max_depth (max_depth=10) to prevent overfitting
# Increased min_samples_split (min_samples_split=4) to ensure splits occur only with sufficient data
# These changes help balance complexity and robustness, resulting in improved performance.

# %%
#Evaluate Model 2:

#-- Generate predicted y values (Model 2)
prediction_labels_2 = model_2.predict(X_test_preprocessed)

# Calculate accuracy
accuracy_2 = accuracy_score(y_test_labels, prediction_labels_2)
print("Model 2 Accuracy:", accuracy_2)

# Print classification report
print("Classification Report:")
print(classification_report(y_test_labels, prediction_labels_2))

# Print confusion matrix
print("Confusion Matrix:")
print(confusion_matrix(y_test_labels, prediction_labels_2))
# Out:
# Model 2 Accuracy: 0.5952380952380952
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.57      0.44      0.50         9
#            1       0.45      0.62      0.53         8
#            2       0.60      0.75      0.67         8
#            3       0.57      0.50      0.53         8
#            4       0.86      0.67      0.75         9
#
#     accuracy                           0.60        42
#    macro avg       0.61      0.60      0.60        42
# weighted avg       0.62      0.60      0.60        42
#
# Confusion Matrix:
# [[4 5 0 0 0]
#  [3 5 0 0 0]
#  [0 1 6 1 0]
#  [0 0 3 4 1]
#  [0 0 1 2 6]]

# %% [markdown]
# Do you think it is worth making more changes to the parameters? Should we keep trying random values and see what works better? What is an alternative to doing this manually?

# %%
## Your answer:

# The current improvement is very little.
# Yes, further tuning may help, but manually testing random values can be inefficient and I believe we should not spending time working on that.
# Instead, using automated hyperparameter optimization methods like GridSearchCV with cross-validation can systematically explore the parameter space and often yield better results.

# %%
# Submit a third model using GridSearchCV

from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
import numpy as np

# Use np.arange to create a sequence of numbers for each parameter's space you think should be searched
param_grid = {
    'n_estimators': np.arange(100, 301, 50),
    'max_depth': np.arange(5, 21, 5),
    'min_samples_split': np.arange(2, 7)
}

# Read GridSearchCV docs and create an object with RandomForestClassifier as the model
gridmodel = GridSearchCV(RandomForestClassifier(random_state=42),
                         param_grid,
                         cv=5,
                         scoring='accuracy',
                         n_jobs=-1)

#use model methods to fit score and predict model:
gridmodel.fit(X_train_preprocessed, y_train_labels)

#extract best score and parameter by calling objects "best_score_" and "best_params_"
print("best mean cross-validation score: {:.3f}".format(gridmodel.best_score_))
print("best parameters: {}".format(gridmodel.best_params_))
# Out:
# best mean cross-validation score: 0.568
# best parameters: {'max_depth': 10, 'min_samples_split': 4, 'n_estimators': 150}

# %%
#Submit Model 3:

from sklearn.model_selection import cross_val_score

#-- Generate predicted values
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# Use the best estimator from GridSearchCV as our final model
model_3 = gridmodel.best_estimator_

# Generate predicted values on the preprocessed test set
prediction_labels_3 = model_3.predict(X_test_preprocessed)

## Write code to show model performance by comparing prediction_labels with true labels

accuracy_3 = accuracy_score(y_test_labels, prediction_labels_3)
print("Model 3 Accuracy:", accuracy_3)
print("\nClassification Report:")
print(classification_report(y_test_labels, prediction_labels_3))
print("Confusion Matrix:")
print(confusion_matrix(y_test_labels, prediction_labels_3))

cv_scores = cross_val_score(model_3, X_train_preprocessed, y_train_labels, cv=5)
print(f"\nCV scores: {cv_scores}")
print(f"Average CV score: {cv_scores.mean():.4f} (±{cv_scores.std():.4f})")
# Out:
# Model 3 Accuracy: 0.5952380952380952
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.57      0.44      0.50         9
#            1       0.40      0.50      0.44         8
#            2       0.60      0.75      0.67         8
#            3       0.62      0.62      0.62         8
#            4       0.86      0.67      0.75         9
#
#     accuracy                           0.60        42
#    macro avg       0.61      0.60      0.60        42
# weighted avg       0.62      0.60      0.60        42
#
# Confusion Matrix:
# [[4 5 0 0 0]
#  [3 4 1 0 0]
#  [0 1 6 1 0]
#  [0 0 2 5 1]
#  [0 0 1 2 6]]
#
# CV scores: [0.52631579 0.47368421 0.47368421 0.73684211 0.63157895]
# Average CV score: 0.5684 (±0.1021)

# %%
# Here are several classic ML architectures you can consider choosing from to experiment with next:
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import GradientBoostingClassifier

# Find the best K using GridSearchCV
k_range = range(1, 21)
knn_param_grid = {
    'n_neighbors': k_range,
    'weights': ['uniform', 'distance'],
    'metric': ['euclidean', 'manhattan']
}

knn_grid = GridSearchCV(
    KNeighborsClassifier(),
    knn_param_grid,
    cv=5,
    scoring='accuracy',
    n_jobs=-1
)

knn_grid.fit(X_train_preprocessed, y_train_labels)

# Get the best KNN model
model_4 = knn_grid.best_estimator_
print(f"\nBest KNN params: {knn_grid.best_params_}")
print(f"Best KNN CV score: {knn_grid.best_score_:.4f}")

#-- Generate predicted values
prediction_labels_4 = model_4.predict(X_test_preprocessed)

## Write code to show model performance by comparing prediction_labels with true labels
accuracy = accuracy_score(y_test_labels, prediction_labels_4)
print("KNN Model Accuracy:", accuracy)
print("\nClassification Report:")
print(classification_report(y_test_labels, prediction_labels_4))
print("Confusion Matrix:")
print(confusion_matrix(y_test_labels, prediction_labels_4))
# Out:
# Best KNN params: {'metric': 'euclidean', 'n_neighbors': 14, 'weights': 'uniform'}
# Best KNN CV score: 0.5684
# KNN Model Accuracy: 0.5952380952380952
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.75      0.33      0.46         9
#            1       0.44      0.50      0.47         8
#            2       0.44      0.88      0.58         8
#            3       0.67      0.50      0.57         8
#            4       1.00      0.78      0.88         9
#
#     accuracy                           0.60        42
#    macro avg       0.66      0.60      0.59        42
# weighted avg       0.67      0.60      0.60        42
#
# Confusion Matrix:
# [[3 5 1 0 0]
#  [1 4 3 0 0]
#  [0 0 7 1 0]
#  [0 0 4 4 0]
#  [0 0 1 1 7]]

# %%
# Find the best parameters for GradientBoostingClassifier using GridSearchCV
gbc_param_grid = {
    'n_estimators': [50, 100, 200],
    'learning_rate': [0.01, 0.1, 0.2],
    'max_depth': [3, 5, 7],
    'min_samples_split': [2, 5, 10]
}

gbc_grid = GridSearchCV(
    GradientBoostingClassifier(),
    gbc_param_grid,
    cv=5,
    scoring='accuracy',
    n_jobs=-1
)

gbc_grid.fit(X_train_preprocessed, y_train_labels)

# Get the best GBC model
model_5 = gbc_grid.best_estimator_
print(f"\nBest GBC params: {gbc_grid.best_params_}")
print(f"Best GBC CV score: {gbc_grid.best_score_:.4f}")

# Generate predicted values
prediction_labels_5 = model_5.predict(X_test_preprocessed)

# Write code to show model performance by comparing prediction_labels with true labels
accuracy = accuracy_score(y_test_labels, prediction_labels_5)
print("GBC Model Accuracy:", accuracy)
print("\nClassification Report:")
print(classification_report(y_test_labels, prediction_labels_5))
print("Confusion Matrix:")
print(confusion_matrix(y_test_labels, prediction_labels_5))
# Out:
# Best GBC params: {'learning_rate': 0.2, 'max_depth': 5, 'min_samples_split': 5, 'n_estimators': 100}
# Best GBC CV score: 0.5789
# GBC Model Accuracy: 0.47619047619047616
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.43      0.33      0.38         9
#            1       0.22      0.25      0.24         8
#            2       0.40      0.50      0.44         8
#            3       0.56      0.62      0.59         8
#            4       0.86      0.67      0.75         9
#
#     accuracy                           0.48        42
#    macro avg       0.49      0.47      0.48        42
# weighted avg       0.50      0.48      0.48        42
#
# Confusion Matrix:
# [[3 5 0 1 0]
#  [4 2 2 0 0]
#  [0 2 4 2 0]
#  [0 0 2 5 1]
#  [0 0 2 1 6]]

# %% [markdown]
# Describe what were the parameters you defined in GradientBoostingClassifier, and/or BaggingClassifier, and/or KNNs, and/or SVC? What worked and why?

# %%
## In my experiment, I performed parameter tuning for both KNN and GBC classifiers
## For KNN, I used GridSearchCV to explore three key parameters: n_neighbors (14), weights ('uniform'), and distance metrics ('euclidean')
## For GBC, I explored four key parameters: n_estimators (100), learning_rate (0.2), max_depth (5), and min_samples_split (5)
## I used 5-fold cross-validation for both models to evaluate the performance of different parameter combinations
## Here, KNN performs better than GBC model

# %% [markdown]
# ## 7. Basic Deep Learning

# %%
# Now experiment with deep learning models:
import keras
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.utils import to_categorical

#count features in input data
feature_count = preprocessor(X_train).shape[1]

## Define a Neural Network Model with 5 layers 128->64->64->32->(?)
keras_model = Sequential()
keras_model.add(Dense(128, input_dim=feature_count, activation='relu'))
keras_model.add(Dense(64, activation='relu'))
keras_model.add(Dense(64, activation='relu'))
keras_model.add(Dense(32, activation='relu'))

#Use Softmax activation in last layer. How many neurons should there be in the last layer?
keras_model.add(Dense(5, activation='softmax'))

# Compile model
keras_model.compile(loss='categorical_crossentropy', optimizer='sgd', metrics=['accuracy'])

# Convert y_train numerical labels to one-hot encoding.
y_train_ohe = to_categorical(y_train_labels, num_classes=5)

# Fitting the NN to the Training set
keras_model.fit(preprocessor(X_train), y_train_ohe, ## Note that keras models require a one-hot-encoded y_train object
               batch_size = 20,
               epochs = 300, validation_split=0.25)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 173ms/step - accuracy: 0.2335 - loss: 1.6295 - val_accuracy: 0.1667 - val_loss: 1.5901
# Epoch 2/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.2178 - loss: 1.6048 - val_accuracy: 0.1667 - val_loss: 1.5869
# Epoch 3/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.2178 - loss: 1.6076 - val_accuracy: 0.1667 - val_loss: 1.5839
# Epoch 4/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.2012 - loss: 1.5963 - val_accuracy: 0.1667 - val_loss: 1.5810
# Epoch 5/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.1978 - loss: 1.5915 - val_accuracy: 0.1667 - val_loss: 1.5779
# Epoch 6/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.1862 - loss: 1.5792 - val_accuracy: 0.1667 - val_loss: 1.5746
# Epoch 7/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.2228 - loss: 1.5477 - val_accuracy: 0.1667 - val_loss: 1.5712
# Epoch 8/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.2062 - loss: 1.5531 - val_accuracy: 0.1667 - val_loss: 1.5681
# Epoch 9/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.2278 - loss: 1.5349 - val_accuracy: 0.1667 - val_loss: 1.5645
# Epoch 10/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.2262 - loss: 1.5341 - val_accuracy: 0.1667 - val_loss: 1.5606
# Epoch 11/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.2295 - loss: 1.5133 - val_accuracy: 0.1667 - val_loss: 1.5568
# Epoch 12/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.1951 - loss: 1.5232 - val_accuracy: 0.1667 - val_loss: 1.5531
# Epoch 13/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.2131 - loss: 1.5030 - val_accuracy: 0.1667 - val_loss: 1.5491
# Epoch 14/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.2510 - loss: 1.5026 - val_accuracy: 0.2083 - val_loss: 1.5456
# Epoch 15/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.2873 - loss: 1.4877 - val_accuracy: 0.2083 - val_loss: 1.5424
# Epoch 16/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.3819 - loss: 1.4529 - val_accuracy: 0.2083 - val_loss: 1.5376
# Epoch 17/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.3354 - loss: 1.4580 - val_accuracy: 0.2500 - val_loss: 1.5338
# Epoch 18/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.4061 - loss: 1.4299 - val_accuracy: 0.2500 - val_loss: 1.5287
# Epoch 19/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.3850 - loss: 1.4375 - val_accuracy: 0.2917 - val_loss: 1.5246
# Epoch 20/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.4740 - loss: 1.4012 - val_accuracy: 0.2917 - val_loss: 1.5206
# Epoch 21/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.4246 - loss: 1.4146 - val_accuracy: 0.2917 - val_loss: 1.5156
# Epoch 22/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.4496 - loss: 1.3848 - val_accuracy: 0.2917 - val_loss: 1.5111
# Epoch 23/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.4559 - loss: 1.3986 - val_accuracy: 0.2917 - val_loss: 1.5062
# Epoch 24/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.5065 - loss: 1.3527 - val_accuracy: 0.2917 - val_loss: 1.5015
# Epoch 25/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.5105 - loss: 1.3440 - val_accuracy: 0.2917 - val_loss: 1.4959
# Epoch 26/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.5222 - loss: 1.3524 - val_accuracy: 0.2917 - val_loss: 1.4920
# Epoch 27/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.5495 - loss: 1.3191 - val_accuracy: 0.2917 - val_loss: 1.4866
# Epoch 28/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.5537 - loss: 1.3468 - val_accuracy: 0.2917 - val_loss: 1.4817
# Epoch 29/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.5683 - loss: 1.3296 - val_accuracy: 0.2917 - val_loss: 1.4774
# Epoch 30/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.6100 - loss: 1.2944 - val_accuracy: 0.3333 - val_loss: 1.4721
# Epoch 31/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.5979 - loss: 1.2798 - val_accuracy: 0.3750 - val_loss: 1.4671
# Epoch 32/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.5946 - loss: 1.2971 - val_accuracy: 0.3333 - val_loss: 1.4625
# Epoch 33/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.6160 - loss: 1.2638 - val_accuracy: 0.3750 - val_loss: 1.4574
# Epoch 34/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.6385 - loss: 1.2619 - val_accuracy: 0.4167 - val_loss: 1.4520
# Epoch 35/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.6219 - loss: 1.2567 - val_accuracy: 0.3750 - val_loss: 1.4465
# Epoch 36/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.6169 - loss: 1.2649 - val_accuracy: 0.3333 - val_loss: 1.4426
# Epoch 37/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.6715 - loss: 1.2158 - val_accuracy: 0.3750 - val_loss: 1.4369
# Epoch 38/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 83ms/step - accuracy: 0.6731 - loss: 1.2351 - val_accuracy: 0.3750 - val_loss: 1.4322
# Epoch 39/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.5965 - loss: 1.2506 - val_accuracy: 0.3333 - val_loss: 1.4270
# Epoch 40/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.6681 - loss: 1.1967 - val_accuracy: 0.3333 - val_loss: 1.4214
# Epoch 41/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - accuracy: 0.5831 - loss: 1.2493 - val_accuracy: 0.3333 - val_loss: 1.4168
# Epoch 42/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - accuracy: 0.6575 - loss: 1.1479 - val_accuracy: 0.3333 - val_loss: 1.4103
# Epoch 43/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.6231 - loss: 1.2108 - val_accuracy: 0.3750 - val_loss: 1.4048
# Epoch 44/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.6275 - loss: 1.1906 - val_accuracy: 0.3750 - val_loss: 1.4020
# Epoch 45/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.5712 - loss: 1.1773 - val_accuracy: 0.3750 - val_loss: 1.3969
# Epoch 46/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.6523 - loss: 1.1461 - val_accuracy: 0.3750 - val_loss: 1.3918
# Epoch 47/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.5750 - loss: 1.1491 - val_accuracy: 0.3750 - val_loss: 1.3883
# Epoch 48/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.6360 - loss: 1.1205 - val_accuracy: 0.3750 - val_loss: 1.3826
# Epoch 49/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.6289 - loss: 1.1096 - val_accuracy: 0.3750 - val_loss: 1.3783
# Epoch 50/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.6406 - loss: 1.1141 - val_accuracy: 0.3750 - val_loss: 1.3760
# Epoch 51/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.6079 - loss: 1.0913 - val_accuracy: 0.3750 - val_loss: 1.3731
# Epoch 52/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.6712 - loss: 1.0686 - val_accuracy: 0.3333 - val_loss: 1.3691
# Epoch 53/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.6904 - loss: 1.0737 - val_accuracy: 0.3750 - val_loss: 1.3656
# Epoch 54/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.6162 - loss: 1.0802 - val_accuracy: 0.3750 - val_loss: 1.3634
# Epoch 55/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.6285 - loss: 1.0488 - val_accuracy: 0.3750 - val_loss: 1.3598
# Epoch 56/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.6619 - loss: 1.0180 - val_accuracy: 0.3333 - val_loss: 1.3572
# Epoch 57/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.5985 - loss: 1.0603 - val_accuracy: 0.3333 - val_loss: 1.3528
# Epoch 58/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.6548 - loss: 1.0433 - val_accuracy: 0.3750 - val_loss: 1.3492
# Epoch 59/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.6631 - loss: 1.0172 - val_accuracy: 0.3750 - val_loss: 1.3463
# Epoch 60/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.6769 - loss: 1.0029 - val_accuracy: 0.3750 - val_loss: 1.3447
# Epoch 61/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.6712 - loss: 0.9947 - val_accuracy: 0.2917 - val_loss: 1.3424
# Epoch 62/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.6588 - loss: 1.0439 - val_accuracy: 0.3333 - val_loss: 1.3386
# Epoch 63/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.6888 - loss: 0.9880 - val_accuracy: 0.3750 - val_loss: 1.3342
# Epoch 64/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.6125 - loss: 1.0224 - val_accuracy: 0.3750 - val_loss: 1.3343
# Epoch 65/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.6794 - loss: 0.9816 - val_accuracy: 0.3750 - val_loss: 1.3283
# Epoch 66/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.6558 - loss: 0.9286 - val_accuracy: 0.3750 - val_loss: 1.3236
# Epoch 67/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.6381 - loss: 1.0327 - val_accuracy: 0.3750 - val_loss: 1.3201
# Epoch 68/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.6831 - loss: 0.9470 - val_accuracy: 0.3333 - val_loss: 1.3190
# Epoch 69/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.6588 - loss: 0.9444 - val_accuracy: 0.3750 - val_loss: 1.3154
# Epoch 70/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.6665 - loss: 0.9777 - val_accuracy: 0.2917 - val_loss: 1.3145
# Epoch 71/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.7184 - loss: 0.9262 - val_accuracy: 0.3333 - val_loss: 1.3106
# Epoch 72/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.6215 - loss: 0.9666 - val_accuracy: 0.3750 - val_loss: 1.3093
# Epoch 73/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.6788 - loss: 0.9454 - val_accuracy: 0.3750 - val_loss: 1.3057
# Epoch 74/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.5965 - loss: 0.9631 - val_accuracy: 0.3750 - val_loss: 1.3080
# Epoch 75/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.6521 - loss: 0.8853 - val_accuracy: 0.3750 - val_loss: 1.3019
# Epoch 76/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.6915 - loss: 0.9007 - val_accuracy: 0.3333 - val_loss: 1.3010
# Epoch 77/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.6521 - loss: 0.9345 - val_accuracy: 0.2917 - val_loss: 1.2966
# Epoch 78/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.6865 - loss: 0.9069 - val_accuracy: 0.3333 - val_loss: 1.2936
# Epoch 79/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.7011 - loss: 0.8609 - val_accuracy: 0.3750 - val_loss: 1.2908
# Epoch 80/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.6721 - loss: 0.9103 - val_accuracy: 0.2917 - val_loss: 1.2898
# Epoch 81/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.7311 - loss: 0.8305 - val_accuracy: 0.2917 - val_loss: 1.2894
# Epoch 82/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.7523 - loss: 0.8744 - val_accuracy: 0.2917 - val_loss: 1.2839
# Epoch 83/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 84ms/step - accuracy: 0.7213 - loss: 0.8510 - val_accuracy: 0.3333 - val_loss: 1.2767
# Epoch 84/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - accuracy: 0.6934 - loss: 0.8250 - val_accuracy: 0.3333 - val_loss: 1.2751
# Epoch 85/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.7296 - loss: 0.8815 - val_accuracy: 0.3750 - val_loss: 1.2771
# Epoch 86/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - accuracy: 0.6934 - loss: 0.8927 - val_accuracy: 0.3333 - val_loss: 1.2786
# Epoch 87/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.7486 - loss: 0.8575 - val_accuracy: 0.3333 - val_loss: 1.2750
# Epoch 88/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.7719 - loss: 0.8193 - val_accuracy: 0.3333 - val_loss: 1.2710
# Epoch 89/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.7190 - loss: 0.8908 - val_accuracy: 0.3333 - val_loss: 1.2729
# Epoch 90/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.7369 - loss: 0.8202 - val_accuracy: 0.3333 - val_loss: 1.2683
# Epoch 91/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.7203 - loss: 0.8617 - val_accuracy: 0.3333 - val_loss: 1.2644
# Epoch 92/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.6417 - loss: 0.8723 - val_accuracy: 0.3333 - val_loss: 1.2655
# Epoch 93/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.7063 - loss: 0.8376 - val_accuracy: 0.3333 - val_loss: 1.2640
# Epoch 94/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.7423 - loss: 0.7922 - val_accuracy: 0.3333 - val_loss: 1.2638
# Epoch 95/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.7167 - loss: 0.8300 - val_accuracy: 0.3333 - val_loss: 1.2635
# Epoch 96/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.7296 - loss: 0.8182 - val_accuracy: 0.3333 - val_loss: 1.2648
# Epoch 97/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.7313 - loss: 0.7736 - val_accuracy: 0.3333 - val_loss: 1.2636
# Epoch 98/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.6700 - loss: 0.8108 - val_accuracy: 0.3333 - val_loss: 1.2626
# Epoch 99/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.7446 - loss: 0.7862 - val_accuracy: 0.3333 - val_loss: 1.2630
# Epoch 100/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.7353 - loss: 0.7871 - val_accuracy: 0.3333 - val_loss: 1.2630
# Epoch 101/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.7180 - loss: 0.8042 - val_accuracy: 0.3333 - val_loss: 1.2619
# Epoch 102/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.7669 - loss: 0.7453 - val_accuracy: 0.3333 - val_loss: 1.2612
# Epoch 103/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.7469 - loss: 0.7728 - val_accuracy: 0.3333 - val_loss: 1.2558
# Epoch 104/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.7246 - loss: 0.7834 - val_accuracy: 0.3333 - val_loss: 1.2565
# Epoch 105/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.7486 - loss: 0.7864 - val_accuracy: 0.3333 - val_loss: 1.2592
# Epoch 106/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.7453 - loss: 0.7362 - val_accuracy: 0.3333 - val_loss: 1.2540
# Epoch 107/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.7486 - loss: 0.7451 - val_accuracy: 0.3333 - val_loss: 1.2496
# Epoch 108/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.7413 - loss: 0.7366 - val_accuracy: 0.3333 - val_loss: 1.2585
# Epoch 109/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.7119 - loss: 0.7766 - val_accuracy: 0.3333 - val_loss: 1.2546
# Epoch 110/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.7213 - loss: 0.6993 - val_accuracy: 0.3333 - val_loss: 1.2552
# Epoch 111/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 83ms/step - accuracy: 0.7703 - loss: 0.6983 - val_accuracy: 0.2917 - val_loss: 1.2552
# Epoch 112/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 98ms/step - accuracy: 0.7299 - loss: 0.7630 - val_accuracy: 0.3333 - val_loss: 1.2528
# Epoch 113/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - accuracy: 0.6580 - loss: 0.7870 - val_accuracy: 0.3333 - val_loss: 1.2528
# Epoch 114/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.7336 - loss: 0.7146 - val_accuracy: 0.3333 - val_loss: 1.2545
# Epoch 115/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.7409 - loss: 0.7303 - val_accuracy: 0.3333 - val_loss: 1.2550
# Epoch 116/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.7849 - loss: 0.6879 - val_accuracy: 0.3333 - val_loss: 1.2437
# Epoch 117/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.7923 - loss: 0.6102 - val_accuracy: 0.2917 - val_loss: 1.2506
# Epoch 118/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.7853 - loss: 0.6734 - val_accuracy: 0.2917 - val_loss: 1.2516
# Epoch 119/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.8026 - loss: 0.6517 - val_accuracy: 0.2917 - val_loss: 1.2497
# Epoch 120/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.7092 - loss: 0.7123 - val_accuracy: 0.2917 - val_loss: 1.2504
# Epoch 121/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - accuracy: 0.7965 - loss: 0.6517 - val_accuracy: 0.3333 - val_loss: 1.2419
# Epoch 122/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.8182 - loss: 0.6312 - val_accuracy: 0.3333 - val_loss: 1.2408
# Epoch 123/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.8015 - loss: 0.6589 - val_accuracy: 0.2917 - val_loss: 1.2439
# Epoch 124/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.8038 - loss: 0.6703 - val_accuracy: 0.2917 - val_loss: 1.2429
# Epoch 125/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - accuracy: 0.7819 - loss: 0.6055 - val_accuracy: 0.2917 - val_loss: 1.2484
# Epoch 126/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.7905 - loss: 0.6362 - val_accuracy: 0.2917 - val_loss: 1.2562
# Epoch 127/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.7961 - loss: 0.6765 - val_accuracy: 0.2917 - val_loss: 1.2475
# Epoch 128/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.7865 - loss: 0.6371 - val_accuracy: 0.2500 - val_loss: 1.2506
# Epoch 129/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.7515 - loss: 0.6700 - val_accuracy: 0.2917 - val_loss: 1.2520
# Epoch 130/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.7315 - loss: 0.6530 - val_accuracy: 0.3333 - val_loss: 1.2476
# Epoch 131/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.7688 - loss: 0.6566 - val_accuracy: 0.3333 - val_loss: 1.2460
# Epoch 132/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.7861 - loss: 0.6485 - val_accuracy: 0.3333 - val_loss: 1.2462
# Epoch 133/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.8228 - loss: 0.6423 - val_accuracy: 0.2917 - val_loss: 1.2458
# Epoch 134/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.7545 - loss: 0.6543 - val_accuracy: 0.2500 - val_loss: 1.2512
# Epoch 135/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.7582 - loss: 0.6060 - val_accuracy: 0.2917 - val_loss: 1.2462
# Epoch 136/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.7978 - loss: 0.6008 - val_accuracy: 0.2917 - val_loss: 1.2467
# Epoch 137/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.7755 - loss: 0.6213 - val_accuracy: 0.2917 - val_loss: 1.2502
# Epoch 138/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.8015 - loss: 0.5570 - val_accuracy: 0.2917 - val_loss: 1.2566
# Epoch 139/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.7961 - loss: 0.6134 - val_accuracy: 0.2917 - val_loss: 1.2469
# Epoch 140/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.8222 - loss: 0.5718 - val_accuracy: 0.2917 - val_loss: 1.2432
# Epoch 141/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.8018 - loss: 0.6352 - val_accuracy: 0.2500 - val_loss: 1.2570
# Epoch 142/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.7645 - loss: 0.5989 - val_accuracy: 0.2500 - val_loss: 1.2540
# Epoch 143/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.8330 - loss: 0.6296 - val_accuracy: 0.2500 - val_loss: 1.2421
# Epoch 144/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.8241 - loss: 0.5716 - val_accuracy: 0.2500 - val_loss: 1.2420
# Epoch 145/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.8564 - loss: 0.5762 - val_accuracy: 0.2500 - val_loss: 1.2407
# Epoch 146/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.8680 - loss: 0.5618 - val_accuracy: 0.2500 - val_loss: 1.2404
# Epoch 147/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.8530 - loss: 0.5763 - val_accuracy: 0.2500 - val_loss: 1.2437
# Epoch 148/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.8130 - loss: 0.5889 - val_accuracy: 0.2500 - val_loss: 1.2442
# Epoch 149/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.8524 - loss: 0.5636 - val_accuracy: 0.2500 - val_loss: 1.2359
# Epoch 150/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.8903 - loss: 0.5270 - val_accuracy: 0.2500 - val_loss: 1.2441
# Epoch 151/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.8497 - loss: 0.6115 - val_accuracy: 0.2500 - val_loss: 1.2449
# Epoch 152/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.8760 - loss: 0.5373 - val_accuracy: 0.2500 - val_loss: 1.2446
# Epoch 153/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.8676 - loss: 0.5307 - val_accuracy: 0.2500 - val_loss: 1.2452
# Epoch 154/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.8660 - loss: 0.5486 - val_accuracy: 0.2917 - val_loss: 1.2429
# Epoch 155/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.8787 - loss: 0.5300 - val_accuracy: 0.2917 - val_loss: 1.2382
# Epoch 156/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.8510 - loss: 0.5538 - val_accuracy: 0.2917 - val_loss: 1.2403
# Epoch 157/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.8726 - loss: 0.5165 - val_accuracy: 0.2917 - val_loss: 1.2527
# Epoch 158/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.8453 - loss: 0.5353 - val_accuracy: 0.2500 - val_loss: 1.2499
# Epoch 159/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.8670 - loss: 0.4977 - val_accuracy: 0.2917 - val_loss: 1.2431
# Epoch 160/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9049 - loss: 0.5050 - val_accuracy: 0.2917 - val_loss: 1.2536
# Epoch 161/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9003 - loss: 0.4703 - val_accuracy: 0.2917 - val_loss: 1.2403
# Epoch 162/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.8906 - loss: 0.5085 - val_accuracy: 0.2917 - val_loss: 1.2548
# Epoch 163/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.8560 - loss: 0.5256 - val_accuracy: 0.2917 - val_loss: 1.2524
# Epoch 164/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.8972 - loss: 0.5233 - val_accuracy: 0.2917 - val_loss: 1.2638
# Epoch 165/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.9116 - loss: 0.4961 - val_accuracy: 0.2917 - val_loss: 1.2689
# Epoch 166/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 101ms/step - accuracy: 0.8493 - loss: 0.4882 - val_accuracy: 0.2917 - val_loss: 1.2682
# Epoch 167/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.9026 - loss: 0.4592 - val_accuracy: 0.2917 - val_loss: 1.2547
# Epoch 168/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.8856 - loss: 0.5236 - val_accuracy: 0.2917 - val_loss: 1.2569
# Epoch 169/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.8972 - loss: 0.4582 - val_accuracy: 0.2917 - val_loss: 1.2689
# Epoch 170/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 109ms/step - accuracy: 0.8956 - loss: 0.5065 - val_accuracy: 0.2917 - val_loss: 1.2720
# Epoch 171/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 0.8822 - loss: 0.4683 - val_accuracy: 0.2917 - val_loss: 1.2900
# Epoch 172/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.8893 - loss: 0.4212 - val_accuracy: 0.2917 - val_loss: 1.2636
# Epoch 173/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9206 - loss: 0.4492 - val_accuracy: 0.3333 - val_loss: 1.2721
# Epoch 174/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9056 - loss: 0.4424 - val_accuracy: 0.3333 - val_loss: 1.2678
# Epoch 175/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9006 - loss: 0.4393 - val_accuracy: 0.3333 - val_loss: 1.2757
# Epoch 176/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9406 - loss: 0.3998 - val_accuracy: 0.3333 - val_loss: 1.2640
# Epoch 177/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.8956 - loss: 0.4451 - val_accuracy: 0.3333 - val_loss: 1.2674
# Epoch 178/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9089 - loss: 0.4145 - val_accuracy: 0.3333 - val_loss: 1.2661
# Epoch 179/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9062 - loss: 0.4410 - val_accuracy: 0.3333 - val_loss: 1.2737
# Epoch 180/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.8972 - loss: 0.4642 - val_accuracy: 0.3333 - val_loss: 1.2959
# Epoch 181/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9012 - loss: 0.4138 - val_accuracy: 0.3333 - val_loss: 1.2737
# Epoch 182/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9212 - loss: 0.4025 - val_accuracy: 0.3333 - val_loss: 1.2847
# Epoch 183/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9112 - loss: 0.4518 - val_accuracy: 0.3333 - val_loss: 1.2978
# Epoch 184/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.9429 - loss: 0.4150 - val_accuracy: 0.3333 - val_loss: 1.2868
# Epoch 185/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.8912 - loss: 0.4139 - val_accuracy: 0.3333 - val_loss: 1.2946
# Epoch 186/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.9152 - loss: 0.4306 - val_accuracy: 0.3333 - val_loss: 1.2942
# Epoch 187/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9002 - loss: 0.4073 - val_accuracy: 0.3333 - val_loss: 1.3009
# Epoch 188/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9312 - loss: 0.4024 - val_accuracy: 0.3333 - val_loss: 1.3094
# Epoch 189/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.8662 - loss: 0.4159 - val_accuracy: 0.3333 - val_loss: 1.3062
# Epoch 190/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9252 - loss: 0.3791 - val_accuracy: 0.3333 - val_loss: 1.3107
# Epoch 191/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9318 - loss: 0.3843 - val_accuracy: 0.3333 - val_loss: 1.2972
# Epoch 192/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.9445 - loss: 0.3983 - val_accuracy: 0.3333 - val_loss: 1.3034
# Epoch 193/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9235 - loss: 0.3632 - val_accuracy: 0.3333 - val_loss: 1.3110
# Epoch 194/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.9418 - loss: 0.3507 - val_accuracy: 0.3750 - val_loss: 1.3102
# Epoch 195/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9418 - loss: 0.3698 - val_accuracy: 0.3750 - val_loss: 1.3142
# Epoch 196/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9558 - loss: 0.3712 - val_accuracy: 0.3750 - val_loss: 1.3066
# Epoch 197/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9564 - loss: 0.3687 - val_accuracy: 0.3750 - val_loss: 1.3342
# Epoch 198/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9564 - loss: 0.3575 - val_accuracy: 0.3750 - val_loss: 1.3236
# Epoch 199/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9681 - loss: 0.3318 - val_accuracy: 0.3750 - val_loss: 1.3278
# Epoch 200/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9531 - loss: 0.3458 - val_accuracy: 0.3750 - val_loss: 1.3207
# Epoch 201/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9681 - loss: 0.3437 - val_accuracy: 0.3750 - val_loss: 1.3332
# Epoch 202/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9621 - loss: 0.3335 - val_accuracy: 0.3750 - val_loss: 1.3261
# Epoch 203/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9541 - loss: 0.3360 - val_accuracy: 0.3750 - val_loss: 1.3335
# Epoch 204/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9671 - loss: 0.3601 - val_accuracy: 0.3750 - val_loss: 1.3404
# Epoch 205/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9481 - loss: 0.3420 - val_accuracy: 0.3750 - val_loss: 1.3488
# Epoch 206/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9631 - loss: 0.3483 - val_accuracy: 0.3750 - val_loss: 1.3499
# Epoch 207/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9714 - loss: 0.3313 - val_accuracy: 0.3750 - val_loss: 1.3540
# Epoch 208/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9564 - loss: 0.3442 - val_accuracy: 0.3750 - val_loss: 1.3425
# Epoch 209/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9671 - loss: 0.2958 - val_accuracy: 0.3750 - val_loss: 1.3481
# Epoch 210/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.9381 - loss: 0.3258 - val_accuracy: 0.3750 - val_loss: 1.3673
# Epoch 211/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 99ms/step - accuracy: 0.9764 - loss: 0.2743 - val_accuracy: 0.3750 - val_loss: 1.3522
# Epoch 212/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.9714 - loss: 0.2651 - val_accuracy: 0.3750 - val_loss: 1.3533
# Epoch 213/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 102ms/step - accuracy: 0.9631 - loss: 0.3209 - val_accuracy: 0.3750 - val_loss: 1.3585
# Epoch 214/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9821 - loss: 0.3165 - val_accuracy: 0.3750 - val_loss: 1.3567
# Epoch 215/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 0.9944 - loss: 0.3001 - val_accuracy: 0.3750 - val_loss: 1.3631
# Epoch 216/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.9704 - loss: 0.3122 - val_accuracy: 0.3750 - val_loss: 1.3821
# Epoch 217/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.9860 - loss: 0.2866 - val_accuracy: 0.3750 - val_loss: 1.3632
# Epoch 218/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9621 - loss: 0.3069 - val_accuracy: 0.3750 - val_loss: 1.3844
# Epoch 219/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9771 - loss: 0.3021 - val_accuracy: 0.3750 - val_loss: 1.3748
# Epoch 220/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9854 - loss: 0.2799 - val_accuracy: 0.3750 - val_loss: 1.3746
# Epoch 221/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9860 - loss: 0.2669 - val_accuracy: 0.3750 - val_loss: 1.3848
# Epoch 222/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9854 - loss: 0.2867 - val_accuracy: 0.3750 - val_loss: 1.3784
# Epoch 223/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9860 - loss: 0.2940 - val_accuracy: 0.3750 - val_loss: 1.3958
# Epoch 224/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9521 - loss: 0.2968 - val_accuracy: 0.3750 - val_loss: 1.3841
# Epoch 225/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9860 - loss: 0.2752 - val_accuracy: 0.3750 - val_loss: 1.4048
# Epoch 226/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9704 - loss: 0.2630 - val_accuracy: 0.3750 - val_loss: 1.3981
# Epoch 227/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.9944 - loss: 0.2412 - val_accuracy: 0.3750 - val_loss: 1.4124
# Epoch 228/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9910 - loss: 0.2524 - val_accuracy: 0.3750 - val_loss: 1.4091
# Epoch 229/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9771 - loss: 0.2603 - val_accuracy: 0.3750 - val_loss: 1.4024
# Epoch 230/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.9621 - loss: 0.2897 - val_accuracy: 0.3750 - val_loss: 1.4138
# Epoch 231/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9910 - loss: 0.2378 - val_accuracy: 0.3750 - val_loss: 1.4130
# Epoch 232/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9944 - loss: 0.2621 - val_accuracy: 0.3750 - val_loss: 1.4217
# Epoch 233/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9721 - loss: 0.2197 - val_accuracy: 0.3750 - val_loss: 1.4091
# Epoch 234/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.9760 - loss: 0.2571 - val_accuracy: 0.3750 - val_loss: 1.4183
# Epoch 235/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9760 - loss: 0.2657 - val_accuracy: 0.3750 - val_loss: 1.4214
# Epoch 236/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9860 - loss: 0.2455 - val_accuracy: 0.3750 - val_loss: 1.4383
# Epoch 237/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.9944 - loss: 0.2224 - val_accuracy: 0.3750 - val_loss: 1.4331
# Epoch 238/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9760 - loss: 0.2463 - val_accuracy: 0.3750 - val_loss: 1.4321
# Epoch 239/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9944 - loss: 0.2298 - val_accuracy: 0.3750 - val_loss: 1.4300
# Epoch 240/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9860 - loss: 0.2288 - val_accuracy: 0.3750 - val_loss: 1.4471
# Epoch 241/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9860 - loss: 0.2278 - val_accuracy: 0.3750 - val_loss: 1.4448
# Epoch 242/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.9910 - loss: 0.2061 - val_accuracy: 0.3750 - val_loss: 1.4366
# Epoch 243/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9910 - loss: 0.2246 - val_accuracy: 0.3750 - val_loss: 1.4490
# Epoch 244/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.9760 - loss: 0.2434 - val_accuracy: 0.3750 - val_loss: 1.4536
# Epoch 245/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9760 - loss: 0.2091 - val_accuracy: 0.3750 - val_loss: 1.4454
# Epoch 246/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9860 - loss: 0.2114 - val_accuracy: 0.3750 - val_loss: 1.4593
# Epoch 247/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9760 - loss: 0.2162 - val_accuracy: 0.3750 - val_loss: 1.4656
# Epoch 248/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9910 - loss: 0.2000 - val_accuracy: 0.3750 - val_loss: 1.4661
# Epoch 249/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9910 - loss: 0.1817 - val_accuracy: 0.3750 - val_loss: 1.4620
# Epoch 250/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9910 - loss: 0.2060 - val_accuracy: 0.3750 - val_loss: 1.4686
# Epoch 251/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9860 - loss: 0.1880 - val_accuracy: 0.3750 - val_loss: 1.4854
# Epoch 252/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9760 - loss: 0.2149 - val_accuracy: 0.3750 - val_loss: 1.4829
# Epoch 253/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9860 - loss: 0.2019 - val_accuracy: 0.3750 - val_loss: 1.4852
# Epoch 254/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.9860 - loss: 0.1915 - val_accuracy: 0.3750 - val_loss: 1.4886
# Epoch 255/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9760 - loss: 0.2014 - val_accuracy: 0.3750 - val_loss: 1.4879
# Epoch 256/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 100ms/step - accuracy: 0.9860 - loss: 0.2005 - val_accuracy: 0.3750 - val_loss: 1.4808
# Epoch 257/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.9860 - loss: 0.1972 - val_accuracy: 0.3750 - val_loss: 1.4910
# Epoch 258/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - accuracy: 0.9860 - loss: 0.1842 - val_accuracy: 0.3750 - val_loss: 1.4954
# Epoch 259/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.9860 - loss: 0.1652 - val_accuracy: 0.3750 - val_loss: 1.4965
# Epoch 260/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 82ms/step - accuracy: 0.9760 - loss: 0.1815 - val_accuracy: 0.3750 - val_loss: 1.5009
# Epoch 261/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.9944 - loss: 0.1687 - val_accuracy: 0.3750 - val_loss: 1.5040
# Epoch 262/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9860 - loss: 0.1828 - val_accuracy: 0.3750 - val_loss: 1.5044
# Epoch 263/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9944 - loss: 0.1685 - val_accuracy: 0.3750 - val_loss: 1.5130
# Epoch 264/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9944 - loss: 0.1653 - val_accuracy: 0.3750 - val_loss: 1.5204
# Epoch 265/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9910 - loss: 0.1580 - val_accuracy: 0.3750 - val_loss: 1.5297
# Epoch 266/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9760 - loss: 0.1740 - val_accuracy: 0.3750 - val_loss: 1.5287
# Epoch 267/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.9860 - loss: 0.1745 - val_accuracy: 0.3750 - val_loss: 1.5312
# Epoch 268/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9944 - loss: 0.1522 - val_accuracy: 0.3750 - val_loss: 1.5320
# Epoch 269/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.9860 - loss: 0.1647 - val_accuracy: 0.3750 - val_loss: 1.5360
# Epoch 270/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9860 - loss: 0.1445 - val_accuracy: 0.3750 - val_loss: 1.5371
# Epoch 271/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9760 - loss: 0.1713 - val_accuracy: 0.3750 - val_loss: 1.5408
# Epoch 272/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9910 - loss: 0.1361 - val_accuracy: 0.3750 - val_loss: 1.5320
# Epoch 273/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9760 - loss: 0.1577 - val_accuracy: 0.3750 - val_loss: 1.5484
# Epoch 274/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9910 - loss: 0.1607 - val_accuracy: 0.3750 - val_loss: 1.5515
# Epoch 275/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9760 - loss: 0.1499 - val_accuracy: 0.3750 - val_loss: 1.5498
# Epoch 276/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9944 - loss: 0.1424 - val_accuracy: 0.3750 - val_loss: 1.5503
# Epoch 277/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9910 - loss: 0.1469 - val_accuracy: 0.3750 - val_loss: 1.5552
# Epoch 278/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.9760 - loss: 0.1477 - val_accuracy: 0.3750 - val_loss: 1.5587
# Epoch 279/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9760 - loss: 0.1570 - val_accuracy: 0.3750 - val_loss: 1.5618
# Epoch 280/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.9860 - loss: 0.1416 - val_accuracy: 0.3750 - val_loss: 1.5623
# Epoch 281/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9760 - loss: 0.1512 - val_accuracy: 0.3750 - val_loss: 1.5685
# Epoch 282/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.9860 - loss: 0.1453 - val_accuracy: 0.3750 - val_loss: 1.5680
# Epoch 283/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9860 - loss: 0.1534 - val_accuracy: 0.3750 - val_loss: 1.5854
# Epoch 284/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9910 - loss: 0.1298 - val_accuracy: 0.3750 - val_loss: 1.5788
# Epoch 285/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9910 - loss: 0.1234 - val_accuracy: 0.3750 - val_loss: 1.5767
# Epoch 286/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.9860 - loss: 0.1300 - val_accuracy: 0.3750 - val_loss: 1.5824
# Epoch 287/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9860 - loss: 0.1322 - val_accuracy: 0.3750 - val_loss: 1.5894
# Epoch 288/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9760 - loss: 0.1488 - val_accuracy: 0.3750 - val_loss: 1.6018
# Epoch 289/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9910 - loss: 0.1311 - val_accuracy: 0.3750 - val_loss: 1.6023
# Epoch 290/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9910 - loss: 0.1202 - val_accuracy: 0.3750 - val_loss: 1.6087
# Epoch 291/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 142ms/step - accuracy: 1.0000 - loss: 0.1390 - val_accuracy: 0.3750 - val_loss: 1.6078
# Epoch 292/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9910 - loss: 0.1282 - val_accuracy: 0.3750 - val_loss: 1.6062
# Epoch 293/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9944 - loss: 0.1090 - val_accuracy: 0.3750 - val_loss: 1.6152
# Epoch 294/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 1.0000 - loss: 0.1255 - val_accuracy: 0.3750 - val_loss: 1.6252
# Epoch 295/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 1.0000 - loss: 0.1243 - val_accuracy: 0.3750 - val_loss: 1.6282
# Epoch 296/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 1.0000 - loss: 0.1237 - val_accuracy: 0.3750 - val_loss: 1.6339
# Epoch 297/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 1.0000 - loss: 0.1298 - val_accuracy: 0.3750 - val_loss: 1.6270
# Epoch 298/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 1.0000 - loss: 0.1114 - val_accuracy: 0.3750 - val_loss: 1.6274
# Epoch 299/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 1.0000 - loss: 0.1283 - val_accuracy: 0.3750 - val_loss: 1.6334
# Epoch 300/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 1.0000 - loss: 0.1253 - val_accuracy: 0.3750 - val_loss: 1.6330

# %% [markdown]
# Which activations did you use in the middle layers? Why was softmax used in the last layer?

# %%
## Your answer:

# In the hidden layers we used ReLU activation because it helps introduce non-linearity while mitigating issues like the vanishing gradient, making it effective for deeper networks
# The softmax activation in the last layer converts the raw outputs into probabilities that sum to 1, which is ideal for multi-class classification tasks where each neuron corresponds to a class

# %% [markdown]
# Was it a good idea to train for 300 epochs? Should you train a bit more? Why or why not?

# %%
## Your answer:

# Training for 300 epochs can be a reasonable starting point,
# but whether it's ideal depends on the model's learning curves.
# If the validation loss has plateaued or starts increasing,
# training for more epochs may lead to overfitting.
# It's important to monitor both training and validation loss and accuracy to decide if additional epochs are beneficial.

# %% [markdown]
# Why is loss='categorical_crossentropy' and optimizer='sgd'? Would you want to change something? Why / Why not?

# %%
## Your answer:
# We use loss='categorical_crossentropy' because our task is multi-class classification and this loss function measures the performance of the model whose output is a probability distribution.
# The optimizer 'sgd' is a basic choice for gradient descent;
# however, optimizers like 'adam' are often preferred as they adapt the learning rate during training and tend to converge faster.
# Depending on the observed convergence behavior,
# switching to Adam might yield better results with less manual tuning.

# %% [markdown]
# Can you try getting the model's training history out and plotting the curves?

# %%
## Your code to plot training and validation curves in a single plot (Make changes in the model cell to be able to do this)

# Fit the model and capture the training history
history = keras_model.fit(preprocessor(X_train), y_train_ohe,
                           batch_size=20,
                           epochs=300,
                           validation_split=0.25,
                           verbose=0)  # Set verbose=0 to reduce output during training

# Plot training and validation curves
plt.figure(figsize=(12, 5))

# Plot Loss Curves
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title("Loss Curves")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()

# Plot Accuracy Curves
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title("Accuracy Curves")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()

plt.tight_layout()
plt.show()

# %%
#-- Generate predicted y values

# Predict probabilities for each class on the preprocessed test set
pred_probabilities = keras_model.predict(preprocessor(X_test))

#Note: Keras predict returns the predicted column index location for classification models
# Predict
prediction_column_index= np.argmax(pred_probabilities, axis=-1)

# Assuming y_train is a Pandas Series, convert it to a categorical type to extract class labels.
class_labels = y_train.astype('category').cat.categories

# extract correct prediction labels
prediction_labels = [class_labels[i] for i in prediction_column_index]

# Convert y_test to categorical labels for evaluation.
true_labels = y_test.astype('category')

## Write code to show model performance by comparing prediction_labels with true labels
print("Accuracy:", accuracy_score(true_labels, prediction_labels))
print("\nClassification Report:")
print(classification_report(true_labels, prediction_labels))
print("Confusion Matrix:")
print(confusion_matrix(true_labels, prediction_labels))
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# Accuracy: 0.5714285714285714
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Average       0.62      0.62      0.62         8
#         High       0.50      0.38      0.43         8
#          Low       0.45      0.62      0.53         8
#    Very High       0.78      0.78      0.78         9
#     Very Low       0.50      0.44      0.47         9
#
#     accuracy                           0.57        42
#    macro avg       0.57      0.57      0.57        42
# weighted avg       0.57      0.57      0.57        42
#
# Confusion Matrix:
# [[5 1 1 0 1]
#  [3 3 0 2 0]
#  [0 0 5 0 3]
#  [0 2 0 7 0]
#  [0 0 5 0 4]]

# %% [markdown]
# Implement regularization techniques such as Dropout and Batch Normalization to improve model generalization and observe change in performance. <br>
# Note: Observe the training and testing loss and accuracy.

# %%
# Your code here:

import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, BatchNormalization
from keras.utils import to_categorical
import matplotlib.pyplot as plt

# Count features in input data
feature_count = preprocessor(X_train).shape[1]

# Define the regularized Neural Network Model with Dropout and Batch Normalization
model_reg = Sequential()
# First hidden layer
model_reg.add(Dense(128, input_dim=feature_count, activation='relu'))
model_reg.add(BatchNormalization())
model_reg.add(Dropout(0.3))  # Dropout with 30% rate

# Second hidden layer
model_reg.add(Dense(64, activation='relu'))
model_reg.add(BatchNormalization())
model_reg.add(Dropout(0.3))

# Third hidden layer
model_reg.add(Dense(64, activation='relu'))
model_reg.add(BatchNormalization())
model_reg.add(Dropout(0.3))

# Fourth hidden layer
model_reg.add(Dense(32, activation='relu'))
model_reg.add(BatchNormalization())
model_reg.add(Dropout(0.3))

# Output layer: 5 neurons for 5 classes using softmax activation
model_reg.add(Dense(5, activation='softmax'))

# Compile the model using categorical crossentropy and Adam optimizer
model_reg.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Convert y_train to one-hot encoding for Keras
y_train_labels = y_train.astype('category').cat.codes
y_train_ohe = to_categorical(y_train_labels, num_classes=5)

# Fit the model and capture the training history
history_reg = model_reg.fit(preprocessor(X_train), y_train_ohe,
                            batch_size=20,
                            epochs=300,
                            validation_split=0.25,
                            verbose=1)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 7s 562ms/step - accuracy: 0.1563 - loss: 2.4713 - val_accuracy: 0.2500 - val_loss: 1.6004
# Epoch 2/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 198ms/step - accuracy: 0.4054 - loss: 1.7441 - val_accuracy: 0.2500 - val_loss: 1.6047
# Epoch 3/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 166ms/step - accuracy: 0.2677 - loss: 1.9376 - val_accuracy: 0.2917 - val_loss: 1.6073
# Epoch 4/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 300ms/step - accuracy: 0.2504 - loss: 1.9020 - val_accuracy: 0.2083 - val_loss: 1.6069
# Epoch 5/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 183ms/step - accuracy: 0.3642 - loss: 1.9057 - val_accuracy: 0.0833 - val_loss: 1.6021
# Epoch 6/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 174ms/step - accuracy: 0.2933 - loss: 1.8130 - val_accuracy: 0.2083 - val_loss: 1.5987
# Epoch 7/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 144ms/step - accuracy: 0.4615 - loss: 1.3428 - val_accuracy: 0.1667 - val_loss: 1.5869
# Epoch 8/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 217ms/step - accuracy: 0.3488 - loss: 1.7868 - val_accuracy: 0.1667 - val_loss: 1.5737
# Epoch 9/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 167ms/step - accuracy: 0.5082 - loss: 1.3263 - val_accuracy: 0.1667 - val_loss: 1.5599
# Epoch 10/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 191ms/step - accuracy: 0.3652 - loss: 1.4747 - val_accuracy: 0.1667 - val_loss: 1.5483
# Epoch 11/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.3946 - loss: 1.3594 - val_accuracy: 0.2083 - val_loss: 1.5379
# Epoch 12/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 106ms/step - accuracy: 0.5458 - loss: 1.3198 - val_accuracy: 0.2500 - val_loss: 1.5272
# Epoch 13/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step - accuracy: 0.3615 - loss: 1.6203 - val_accuracy: 0.2500 - val_loss: 1.5147
# Epoch 14/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.4463 - loss: 1.3308 - val_accuracy: 0.2500 - val_loss: 1.5046
# Epoch 15/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.4686 - loss: 1.2984 - val_accuracy: 0.2917 - val_loss: 1.4982
# Epoch 16/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.5641 - loss: 1.0129 - val_accuracy: 0.2917 - val_loss: 1.4912
# Epoch 17/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.4846 - loss: 1.2095 - val_accuracy: 0.2917 - val_loss: 1.4821
# Epoch 18/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.4599 - loss: 1.2481 - val_accuracy: 0.3750 - val_loss: 1.4697
# Epoch 19/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.5581 - loss: 1.0962 - val_accuracy: 0.3750 - val_loss: 1.4638
# Epoch 20/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.4663 - loss: 1.1035 - val_accuracy: 0.4167 - val_loss: 1.4569
# Epoch 21/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 276ms/step - accuracy: 0.4982 - loss: 1.1914 - val_accuracy: 0.3750 - val_loss: 1.4526
# Epoch 22/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 183ms/step - accuracy: 0.4809 - loss: 1.1340 - val_accuracy: 0.3750 - val_loss: 1.4467
# Epoch 23/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 102ms/step - accuracy: 0.5478 - loss: 1.1187 - val_accuracy: 0.3750 - val_loss: 1.4391
# Epoch 24/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 100ms/step - accuracy: 0.4682 - loss: 1.1529 - val_accuracy: 0.4167 - val_loss: 1.4324
# Epoch 25/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.5201 - loss: 1.1459 - val_accuracy: 0.4167 - val_loss: 1.4261
# Epoch 26/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.6146 - loss: 0.9306 - val_accuracy: 0.4167 - val_loss: 1.4219
# Epoch 27/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.4328 - loss: 1.2180 - val_accuracy: 0.4167 - val_loss: 1.4154
# Epoch 28/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.6060 - loss: 0.9879 - val_accuracy: 0.4167 - val_loss: 1.4136
# Epoch 29/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.5385 - loss: 0.9814 - val_accuracy: 0.4167 - val_loss: 1.4116
# Epoch 30/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.6108 - loss: 0.9704 - val_accuracy: 0.4167 - val_loss: 1.4092
# Epoch 31/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.5520 - loss: 1.1169 - val_accuracy: 0.4167 - val_loss: 1.4089
# Epoch 32/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.7107 - loss: 0.7780 - val_accuracy: 0.4167 - val_loss: 1.4042
# Epoch 33/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.6323 - loss: 0.9360 - val_accuracy: 0.4167 - val_loss: 1.4014
# Epoch 34/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.5258 - loss: 1.0090 - val_accuracy: 0.4167 - val_loss: 1.3968
# Epoch 35/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.5956 - loss: 0.9808 - val_accuracy: 0.4167 - val_loss: 1.3916
# Epoch 36/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.5681 - loss: 1.0089 - val_accuracy: 0.4167 - val_loss: 1.3878
# Epoch 37/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.7169 - loss: 0.7219 - val_accuracy: 0.4167 - val_loss: 1.3824
# Epoch 38/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.6219 - loss: 0.8554 - val_accuracy: 0.4167 - val_loss: 1.3780
# Epoch 39/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.5920 - loss: 0.8860 - val_accuracy: 0.4583 - val_loss: 1.3718
# Epoch 40/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.7184 - loss: 0.8152 - val_accuracy: 0.4583 - val_loss: 1.3629
# Epoch 41/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.6608 - loss: 0.7852 - val_accuracy: 0.5000 - val_loss: 1.3528
# Epoch 42/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.5716 - loss: 0.9282 - val_accuracy: 0.5000 - val_loss: 1.3445
# Epoch 43/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.7117 - loss: 0.7226 - val_accuracy: 0.4583 - val_loss: 1.3445
# Epoch 44/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.6385 - loss: 0.8993 - val_accuracy: 0.4583 - val_loss: 1.3476
# Epoch 45/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.6775 - loss: 0.7005 - val_accuracy: 0.4583 - val_loss: 1.3496
# Epoch 46/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.7373 - loss: 0.6939 - val_accuracy: 0.4167 - val_loss: 1.3517
# Epoch 47/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.7111 - loss: 0.6625 - val_accuracy: 0.3750 - val_loss: 1.3573
# Epoch 48/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.6634 - loss: 0.8750 - val_accuracy: 0.3750 - val_loss: 1.3658
# Epoch 49/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.7292 - loss: 0.6469 - val_accuracy: 0.3750 - val_loss: 1.3688
# Epoch 50/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.5923 - loss: 0.8647 - val_accuracy: 0.3750 - val_loss: 1.3752
# Epoch 51/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.7246 - loss: 0.6900 - val_accuracy: 0.3750 - val_loss: 1.3834
# Epoch 52/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.6652 - loss: 0.7579 - val_accuracy: 0.3750 - val_loss: 1.3947
# Epoch 53/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.7786 - loss: 0.6054 - val_accuracy: 0.3750 - val_loss: 1.4044
# Epoch 54/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.7330 - loss: 0.6636 - val_accuracy: 0.3333 - val_loss: 1.4116
# Epoch 55/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.7553 - loss: 0.6506 - val_accuracy: 0.3333 - val_loss: 1.4206
# Epoch 56/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.7386 - loss: 0.7276 - val_accuracy: 0.3750 - val_loss: 1.4234
# Epoch 57/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.7576 - loss: 0.6405 - val_accuracy: 0.3750 - val_loss: 1.4223
# Epoch 58/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.7915 - loss: 0.6302 - val_accuracy: 0.3750 - val_loss: 1.4241
# Epoch 59/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.7853 - loss: 0.6196 - val_accuracy: 0.3750 - val_loss: 1.4328
# Epoch 60/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.7696 - loss: 0.6743 - val_accuracy: 0.3750 - val_loss: 1.4466
# Epoch 61/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.7888 - loss: 0.6693 - val_accuracy: 0.3750 - val_loss: 1.4608
# Epoch 62/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.7755 - loss: 0.5908 - val_accuracy: 0.3750 - val_loss: 1.4727
# Epoch 63/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.8155 - loss: 0.5368 - val_accuracy: 0.3750 - val_loss: 1.4854
# Epoch 64/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.7123 - loss: 0.6504 - val_accuracy: 0.3750 - val_loss: 1.4977
# Epoch 65/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 112ms/step - accuracy: 0.7722 - loss: 0.5416 - val_accuracy: 0.3750 - val_loss: 1.5159
# Epoch 66/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.7945 - loss: 0.4951 - val_accuracy: 0.3750 - val_loss: 1.5387
# Epoch 67/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.7526 - loss: 0.5832 - val_accuracy: 0.3750 - val_loss: 1.5540
# Epoch 68/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 110ms/step - accuracy: 0.8118 - loss: 0.4599 - val_accuracy: 0.3750 - val_loss: 1.5549
# Epoch 69/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.8288 - loss: 0.5266 - val_accuracy: 0.3750 - val_loss: 1.5578
# Epoch 70/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - accuracy: 0.8860 - loss: 0.4557 - val_accuracy: 0.3750 - val_loss: 1.5674
# Epoch 71/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.8265 - loss: 0.5713 - val_accuracy: 0.4167 - val_loss: 1.5696
# Epoch 72/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.7400 - loss: 0.6922 - val_accuracy: 0.4167 - val_loss: 1.5725
# Epoch 73/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.7730 - loss: 0.5520 - val_accuracy: 0.4167 - val_loss: 1.5735
# Epoch 74/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.8553 - loss: 0.4091 - val_accuracy: 0.3750 - val_loss: 1.5746
# Epoch 75/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.7861 - loss: 0.5135 - val_accuracy: 0.3750 - val_loss: 1.5737
# Epoch 76/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.8487 - loss: 0.4651 - val_accuracy: 0.3750 - val_loss: 1.5744
# Epoch 77/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.7665 - loss: 0.5792 - val_accuracy: 0.3750 - val_loss: 1.5683
# Epoch 78/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.7386 - loss: 0.5824 - val_accuracy: 0.3750 - val_loss: 1.5780
# Epoch 79/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9089 - loss: 0.3910 - val_accuracy: 0.3750 - val_loss: 1.5851
# Epoch 80/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.8424 - loss: 0.4064 - val_accuracy: 0.3750 - val_loss: 1.5882
# Epoch 81/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.7672 - loss: 0.4890 - val_accuracy: 0.3750 - val_loss: 1.6026
# Epoch 82/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.8620 - loss: 0.5138 - val_accuracy: 0.3750 - val_loss: 1.6165
# Epoch 83/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.8224 - loss: 0.5019 - val_accuracy: 0.3750 - val_loss: 1.6409
# Epoch 84/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.8607 - loss: 0.4414 - val_accuracy: 0.3750 - val_loss: 1.6655
# Epoch 85/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.8530 - loss: 0.5903 - val_accuracy: 0.3750 - val_loss: 1.6748
# Epoch 86/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.8230 - loss: 0.4777 - val_accuracy: 0.3750 - val_loss: 1.6879
# Epoch 87/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.8570 - loss: 0.4005 - val_accuracy: 0.3750 - val_loss: 1.6966
# Epoch 88/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.8720 - loss: 0.4223 - val_accuracy: 0.3750 - val_loss: 1.7094
# Epoch 89/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.8753 - loss: 0.4026 - val_accuracy: 0.3750 - val_loss: 1.7248
# Epoch 90/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9245 - loss: 0.2911 - val_accuracy: 0.3750 - val_loss: 1.7389
# Epoch 91/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.8995 - loss: 0.3735 - val_accuracy: 0.3750 - val_loss: 1.7498
# Epoch 92/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.8770 - loss: 0.3954 - val_accuracy: 0.3750 - val_loss: 1.7594
# Epoch 93/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9435 - loss: 0.2576 - val_accuracy: 0.3750 - val_loss: 1.7692
# Epoch 94/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.8095 - loss: 0.4228 - val_accuracy: 0.3750 - val_loss: 1.7714
# Epoch 95/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.8826 - loss: 0.2838 - val_accuracy: 0.3750 - val_loss: 1.7821
# Epoch 96/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9189 - loss: 0.3123 - val_accuracy: 0.3750 - val_loss: 1.8086
# Epoch 97/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.8641 - loss: 0.3600 - val_accuracy: 0.2917 - val_loss: 1.8352
# Epoch 98/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.8441 - loss: 0.3596 - val_accuracy: 0.2917 - val_loss: 1.8515
# Epoch 99/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.8284 - loss: 0.4642 - val_accuracy: 0.2917 - val_loss: 1.8599
# Epoch 100/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 109ms/step - accuracy: 0.9095 - loss: 0.3014 - val_accuracy: 0.2917 - val_loss: 1.8757
# Epoch 101/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 201ms/step - accuracy: 0.9199 - loss: 0.2782 - val_accuracy: 0.2917 - val_loss: 1.8757
# Epoch 102/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 145ms/step - accuracy: 0.9110 - loss: 0.3107 - val_accuracy: 0.2917 - val_loss: 1.8853
# Epoch 103/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.8893 - loss: 0.2923 - val_accuracy: 0.2917 - val_loss: 1.8935
# Epoch 104/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.9379 - loss: 0.2961 - val_accuracy: 0.2917 - val_loss: 1.9006
# Epoch 105/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 91ms/step - accuracy: 0.9475 - loss: 0.2342 - val_accuracy: 0.2917 - val_loss: 1.8941
# Epoch 106/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - accuracy: 0.9189 - loss: 0.3175 - val_accuracy: 0.3333 - val_loss: 1.8969
# Epoch 107/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.8403 - loss: 0.5132 - val_accuracy: 0.3750 - val_loss: 1.9108
# Epoch 108/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.8866 - loss: 0.3386 - val_accuracy: 0.3750 - val_loss: 1.9208
# Epoch 109/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.8893 - loss: 0.3443 - val_accuracy: 0.3750 - val_loss: 1.9293
# Epoch 110/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.8624 - loss: 0.4473 - val_accuracy: 0.3750 - val_loss: 1.9494
# Epoch 111/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9429 - loss: 0.2478 - val_accuracy: 0.3750 - val_loss: 1.9691
# Epoch 112/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.8643 - loss: 0.4052 - val_accuracy: 0.3750 - val_loss: 1.9754
# Epoch 113/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9508 - loss: 0.1872 - val_accuracy: 0.3750 - val_loss: 2.0043
# Epoch 114/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9475 - loss: 0.2953 - val_accuracy: 0.3333 - val_loss: 2.0223
# Epoch 115/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9029 - loss: 0.3560 - val_accuracy: 0.3333 - val_loss: 2.0521
# Epoch 116/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.8624 - loss: 0.3433 - val_accuracy: 0.3333 - val_loss: 2.0779
# Epoch 117/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9591 - loss: 0.2241 - val_accuracy: 0.3333 - val_loss: 2.0950
# Epoch 118/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.8630 - loss: 0.4561 - val_accuracy: 0.3333 - val_loss: 2.1216
# Epoch 119/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9568 - loss: 0.2465 - val_accuracy: 0.3750 - val_loss: 2.1459
# Epoch 120/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9479 - loss: 0.2307 - val_accuracy: 0.3750 - val_loss: 2.1696
# Epoch 121/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9183 - loss: 0.2148 - val_accuracy: 0.3750 - val_loss: 2.1924
# Epoch 122/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.8906 - loss: 0.2997 - val_accuracy: 0.3750 - val_loss: 2.2300
# Epoch 123/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9468 - loss: 0.2572 - val_accuracy: 0.3750 - val_loss: 2.2525
# Epoch 124/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9235 - loss: 0.1887 - val_accuracy: 0.3333 - val_loss: 2.2758
# Epoch 125/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9172 - loss: 0.2871 - val_accuracy: 0.3750 - val_loss: 2.3105
# Epoch 126/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.8989 - loss: 0.2630 - val_accuracy: 0.3750 - val_loss: 2.3327
# Epoch 127/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9279 - loss: 0.2036 - val_accuracy: 0.3750 - val_loss: 2.3432
# Epoch 128/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.9152 - loss: 0.2487 - val_accuracy: 0.3750 - val_loss: 2.3460
# Epoch 129/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9268 - loss: 0.2190 - val_accuracy: 0.3750 - val_loss: 2.3473
# Epoch 130/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9106 - loss: 0.2888 - val_accuracy: 0.3750 - val_loss: 2.3518
# Epoch 131/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9564 - loss: 0.1845 - val_accuracy: 0.3750 - val_loss: 2.3700
# Epoch 132/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9910 - loss: 0.1675 - val_accuracy: 0.3750 - val_loss: 2.3948
# Epoch 133/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9295 - loss: 0.2571 - val_accuracy: 0.3750 - val_loss: 2.4253
# Epoch 134/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9195 - loss: 0.2495 - val_accuracy: 0.3750 - val_loss: 2.4619
# Epoch 135/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9229 - loss: 0.2656 - val_accuracy: 0.3750 - val_loss: 2.4939
# Epoch 136/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9341 - loss: 0.1896 - val_accuracy: 0.3750 - val_loss: 2.5231
# Epoch 137/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9591 - loss: 0.1951 - val_accuracy: 0.3750 - val_loss: 2.5399
# Epoch 138/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9295 - loss: 0.2773 - val_accuracy: 0.3750 - val_loss: 2.5430
# Epoch 139/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9525 - loss: 0.1986 - val_accuracy: 0.3750 - val_loss: 2.5417
# Epoch 140/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.9614 - loss: 0.1998 - val_accuracy: 0.3333 - val_loss: 2.5714
# Epoch 141/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9329 - loss: 0.2798 - val_accuracy: 0.3333 - val_loss: 2.6039
# Epoch 142/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9681 - loss: 0.1528 - val_accuracy: 0.3333 - val_loss: 2.6077
# Epoch 143/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9635 - loss: 0.2151 - val_accuracy: 0.3333 - val_loss: 2.6318
# Epoch 144/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 107ms/step - accuracy: 0.9531 - loss: 0.2162 - val_accuracy: 0.3333 - val_loss: 2.6441
# Epoch 145/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.9425 - loss: 0.2248 - val_accuracy: 0.3333 - val_loss: 2.6790
# Epoch 146/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - accuracy: 0.8949 - loss: 0.3273 - val_accuracy: 0.3333 - val_loss: 2.7190
# Epoch 147/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 120ms/step - accuracy: 0.9362 - loss: 0.2562 - val_accuracy: 0.3333 - val_loss: 2.7551
# Epoch 148/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9295 - loss: 0.2108 - val_accuracy: 0.3333 - val_loss: 2.7466
# Epoch 149/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.9441 - loss: 0.1633 - val_accuracy: 0.3333 - val_loss: 2.7458
# Epoch 150/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9256 - loss: 0.2233 - val_accuracy: 0.3333 - val_loss: 2.7627
# Epoch 151/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.9152 - loss: 0.2937 - val_accuracy: 0.3333 - val_loss: 2.7763
# Epoch 152/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.9185 - loss: 0.2414 - val_accuracy: 0.3333 - val_loss: 2.7864
# Epoch 153/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 0.1392 - val_accuracy: 0.3333 - val_loss: 2.7902
# Epoch 154/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9239 - loss: 0.1885 - val_accuracy: 0.3333 - val_loss: 2.7964
# Epoch 155/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.8743 - loss: 0.3338 - val_accuracy: 0.3333 - val_loss: 2.8055
# Epoch 156/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.9302 - loss: 0.1871 - val_accuracy: 0.3333 - val_loss: 2.7955
# Epoch 157/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9675 - loss: 0.1702 - val_accuracy: 0.3333 - val_loss: 2.7899
# Epoch 158/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9714 - loss: 0.1385 - val_accuracy: 0.3750 - val_loss: 2.7904
# Epoch 159/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.8841 - loss: 0.3625 - val_accuracy: 0.3750 - val_loss: 2.8218
# Epoch 160/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.9681 - loss: 0.1401 - val_accuracy: 0.3333 - val_loss: 2.8669
# Epoch 161/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9564 - loss: 0.1839 - val_accuracy: 0.2917 - val_loss: 2.8982
# Epoch 162/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9441 - loss: 0.2046 - val_accuracy: 0.2917 - val_loss: 2.9314
# Epoch 163/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9062 - loss: 0.3549 - val_accuracy: 0.3333 - val_loss: 2.9442
# Epoch 164/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.9944 - loss: 0.1076 - val_accuracy: 0.3333 - val_loss: 2.9533
# Epoch 165/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.8307 - loss: 0.3684 - val_accuracy: 0.3333 - val_loss: 2.9604
# Epoch 166/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9581 - loss: 0.2228 - val_accuracy: 0.2917 - val_loss: 2.9469
# Epoch 167/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9798 - loss: 0.1575 - val_accuracy: 0.2917 - val_loss: 2.9363
# Epoch 168/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9771 - loss: 0.1457 - val_accuracy: 0.3333 - val_loss: 2.9091
# Epoch 169/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9402 - loss: 0.2187 - val_accuracy: 0.3333 - val_loss: 2.8720
# Epoch 170/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9748 - loss: 0.1400 - val_accuracy: 0.3750 - val_loss: 2.8579
# Epoch 171/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9771 - loss: 0.1358 - val_accuracy: 0.3750 - val_loss: 2.8431
# Epoch 172/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9910 - loss: 0.0826 - val_accuracy: 0.3750 - val_loss: 2.8164
# Epoch 173/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.8983 - loss: 0.2979 - val_accuracy: 0.3750 - val_loss: 2.8149
# Epoch 174/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9352 - loss: 0.2261 - val_accuracy: 0.3750 - val_loss: 2.8340
# Epoch 175/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9325 - loss: 0.1583 - val_accuracy: 0.3750 - val_loss: 2.8369
# Epoch 176/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9860 - loss: 0.1375 - val_accuracy: 0.3750 - val_loss: 2.8400
# Epoch 177/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9944 - loss: 0.0946 - val_accuracy: 0.3750 - val_loss: 2.8404
# Epoch 178/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9887 - loss: 0.1298 - val_accuracy: 0.3333 - val_loss: 2.8427
# Epoch 179/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9502 - loss: 0.2008 - val_accuracy: 0.3333 - val_loss: 2.8421
# Epoch 180/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9531 - loss: 0.1522 - val_accuracy: 0.3750 - val_loss: 2.8690
# Epoch 181/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9381 - loss: 0.1696 - val_accuracy: 0.3750 - val_loss: 2.9127
# Epoch 182/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9854 - loss: 0.1346 - val_accuracy: 0.3750 - val_loss: 2.9352
# Epoch 183/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.8995 - loss: 0.3525 - val_accuracy: 0.3750 - val_loss: 2.9315
# Epoch 184/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9798 - loss: 0.0853 - val_accuracy: 0.3750 - val_loss: 2.9247
# Epoch 185/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9944 - loss: 0.1257 - val_accuracy: 0.3750 - val_loss: 2.9133
# Epoch 186/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.9302 - loss: 0.2436 - val_accuracy: 0.3750 - val_loss: 2.8954
# Epoch 187/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.9352 - loss: 0.1852 - val_accuracy: 0.3333 - val_loss: 2.8795
# Epoch 188/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - accuracy: 0.9241 - loss: 0.3132 - val_accuracy: 0.3333 - val_loss: 2.8702
# Epoch 189/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.9910 - loss: 0.0904 - val_accuracy: 0.3333 - val_loss: 2.8683
# Epoch 190/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 107ms/step - accuracy: 0.9012 - loss: 0.4255 - val_accuracy: 0.3333 - val_loss: 2.8833
# Epoch 191/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.9558 - loss: 0.1617 - val_accuracy: 0.3333 - val_loss: 2.8877
# Epoch 192/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.9425 - loss: 0.1642 - val_accuracy: 0.3333 - val_loss: 2.9017
# Epoch 193/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.9621 - loss: 0.1124 - val_accuracy: 0.3333 - val_loss: 2.8990
# Epoch 194/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - accuracy: 0.9671 - loss: 0.1248 - val_accuracy: 0.3333 - val_loss: 2.8915
# Epoch 195/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9748 - loss: 0.1310 - val_accuracy: 0.3333 - val_loss: 2.8863
# Epoch 196/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9804 - loss: 0.1153 - val_accuracy: 0.3333 - val_loss: 2.8591
# Epoch 197/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9760 - loss: 0.0941 - val_accuracy: 0.3333 - val_loss: 2.8322
# Epoch 198/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9385 - loss: 0.1632 - val_accuracy: 0.3333 - val_loss: 2.8159
# Epoch 199/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9748 - loss: 0.1061 - val_accuracy: 0.3333 - val_loss: 2.8183
# Epoch 200/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9648 - loss: 0.1188 - val_accuracy: 0.3333 - val_loss: 2.8398
# Epoch 201/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9944 - loss: 0.0641 - val_accuracy: 0.3333 - val_loss: 2.8550
# Epoch 202/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9944 - loss: 0.1099 - val_accuracy: 0.3333 - val_loss: 2.8470
# Epoch 203/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9910 - loss: 0.0908 - val_accuracy: 0.3333 - val_loss: 2.8377
# Epoch 204/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9281 - loss: 0.2017 - val_accuracy: 0.3750 - val_loss: 2.8656
# Epoch 205/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9910 - loss: 0.0609 - val_accuracy: 0.3750 - val_loss: 2.8754
# Epoch 206/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9368 - loss: 0.1940 - val_accuracy: 0.3750 - val_loss: 2.8977
# Epoch 207/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9760 - loss: 0.1279 - val_accuracy: 0.3333 - val_loss: 2.8990
# Epoch 208/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9860 - loss: 0.0824 - val_accuracy: 0.3333 - val_loss: 2.9006
# Epoch 209/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9268 - loss: 0.1777 - val_accuracy: 0.3333 - val_loss: 2.9099
# Epoch 210/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9664 - loss: 0.1343 - val_accuracy: 0.3333 - val_loss: 2.9213
# Epoch 211/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9129 - loss: 0.1870 - val_accuracy: 0.3333 - val_loss: 2.9195
# Epoch 212/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9910 - loss: 0.0935 - val_accuracy: 0.3333 - val_loss: 2.9418
# Epoch 213/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 0.1145 - val_accuracy: 0.3333 - val_loss: 2.9644
# Epoch 214/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9860 - loss: 0.1225 - val_accuracy: 0.3333 - val_loss: 2.9870
# Epoch 215/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9704 - loss: 0.1579 - val_accuracy: 0.3333 - val_loss: 2.9687
# Epoch 216/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9887 - loss: 0.0971 - val_accuracy: 0.3333 - val_loss: 2.9508
# Epoch 217/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9804 - loss: 0.0815 - val_accuracy: 0.3333 - val_loss: 2.9216
# Epoch 218/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9225 - loss: 0.1783 - val_accuracy: 0.3333 - val_loss: 2.9177
# Epoch 219/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9306 - loss: 0.1341 - val_accuracy: 0.3333 - val_loss: 2.9122
# Epoch 220/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9771 - loss: 0.1184 - val_accuracy: 0.3333 - val_loss: 2.9063
# Epoch 221/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9748 - loss: 0.1159 - val_accuracy: 0.3333 - val_loss: 2.9138
# Epoch 222/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9691 - loss: 0.1067 - val_accuracy: 0.3333 - val_loss: 2.9210
# Epoch 223/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9525 - loss: 0.1416 - val_accuracy: 0.3333 - val_loss: 2.9349
# Epoch 224/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9944 - loss: 0.1112 - val_accuracy: 0.3333 - val_loss: 2.9602
# Epoch 225/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9564 - loss: 0.1144 - val_accuracy: 0.3333 - val_loss: 2.9659
# Epoch 226/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9860 - loss: 0.0976 - val_accuracy: 0.3333 - val_loss: 2.9532
# Epoch 227/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9464 - loss: 0.1462 - val_accuracy: 0.3333 - val_loss: 2.9505
# Epoch 228/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.9671 - loss: 0.1408 - val_accuracy: 0.3333 - val_loss: 2.9611
# Epoch 229/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - accuracy: 0.9760 - loss: 0.0967 - val_accuracy: 0.3333 - val_loss: 2.9825
# Epoch 230/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 116ms/step - accuracy: 0.9564 - loss: 0.1638 - val_accuracy: 0.3333 - val_loss: 3.0127
# Epoch 231/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 83ms/step - accuracy: 0.9464 - loss: 0.1434 - val_accuracy: 0.3333 - val_loss: 3.0118
# Epoch 232/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.9375 - loss: 0.1232 - val_accuracy: 0.3333 - val_loss: 3.0102
# Epoch 233/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 1.0000 - loss: 0.0631 - val_accuracy: 0.3333 - val_loss: 3.0071
# Epoch 234/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9564 - loss: 0.1581 - val_accuracy: 0.3333 - val_loss: 3.0110
# Epoch 235/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9760 - loss: 0.0946 - val_accuracy: 0.3333 - val_loss: 3.0043
# Epoch 236/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9395 - loss: 0.1425 - val_accuracy: 0.3333 - val_loss: 2.9831
# Epoch 237/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9521 - loss: 0.2024 - val_accuracy: 0.3333 - val_loss: 2.9564
# Epoch 238/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.9564 - loss: 0.1047 - val_accuracy: 0.3750 - val_loss: 2.9664
# Epoch 239/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9525 - loss: 0.1223 - val_accuracy: 0.3750 - val_loss: 2.9887
# Epoch 240/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9860 - loss: 0.0792 - val_accuracy: 0.3750 - val_loss: 3.0065
# Epoch 241/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 0.0712 - val_accuracy: 0.3750 - val_loss: 3.0243
# Epoch 242/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9804 - loss: 0.0600 - val_accuracy: 0.3750 - val_loss: 3.0332
# Epoch 243/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9854 - loss: 0.0700 - val_accuracy: 0.3750 - val_loss: 3.0511
# Epoch 244/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9854 - loss: 0.0849 - val_accuracy: 0.3750 - val_loss: 3.0668
# Epoch 245/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.9760 - loss: 0.0755 - val_accuracy: 0.3750 - val_loss: 3.0824
# Epoch 246/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9910 - loss: 0.0734 - val_accuracy: 0.3750 - val_loss: 3.1044
# Epoch 247/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9910 - loss: 0.0492 - val_accuracy: 0.3750 - val_loss: 3.1032
# Epoch 248/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9910 - loss: 0.0721 - val_accuracy: 0.3750 - val_loss: 3.0986
# Epoch 249/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.9291 - loss: 0.1812 - val_accuracy: 0.3750 - val_loss: 3.1013
# Epoch 250/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9771 - loss: 0.1155 - val_accuracy: 0.3750 - val_loss: 3.1158
# Epoch 251/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9721 - loss: 0.0544 - val_accuracy: 0.3750 - val_loss: 3.1462
# Epoch 252/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9760 - loss: 0.0898 - val_accuracy: 0.3750 - val_loss: 3.1623
# Epoch 253/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9771 - loss: 0.1172 - val_accuracy: 0.3750 - val_loss: 3.1671
# Epoch 254/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9525 - loss: 0.1360 - val_accuracy: 0.3750 - val_loss: 3.1750
# Epoch 255/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9671 - loss: 0.1081 - val_accuracy: 0.3750 - val_loss: 3.1946
# Epoch 256/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9760 - loss: 0.0760 - val_accuracy: 0.3333 - val_loss: 3.2064
# Epoch 257/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 1.0000 - loss: 0.0604 - val_accuracy: 0.3333 - val_loss: 3.2196
# Epoch 258/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9860 - loss: 0.0491 - val_accuracy: 0.3333 - val_loss: 3.2200
# Epoch 259/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9854 - loss: 0.1040 - val_accuracy: 0.3333 - val_loss: 3.2319
# Epoch 260/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9944 - loss: 0.0934 - val_accuracy: 0.3333 - val_loss: 3.2567
# Epoch 261/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9944 - loss: 0.0488 - val_accuracy: 0.3333 - val_loss: 3.3104
# Epoch 262/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 1.0000 - loss: 0.1028 - val_accuracy: 0.3333 - val_loss: 3.3159
# Epoch 263/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 109ms/step - accuracy: 0.9944 - loss: 0.0686 - val_accuracy: 0.3333 - val_loss: 3.3213
# Epoch 264/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9910 - loss: 0.1205 - val_accuracy: 0.3333 - val_loss: 3.3042
# Epoch 265/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.9804 - loss: 0.0976 - val_accuracy: 0.3333 - val_loss: 3.3288
# Epoch 266/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9648 - loss: 0.0917 - val_accuracy: 0.3333 - val_loss: 3.3899
# Epoch 267/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.9318 - loss: 0.1544 - val_accuracy: 0.3333 - val_loss: 3.4356
# Epoch 268/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9804 - loss: 0.0817 - val_accuracy: 0.3333 - val_loss: 3.4724
# Epoch 269/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 108ms/step - accuracy: 0.9910 - loss: 0.0802 - val_accuracy: 0.3750 - val_loss: 3.5226
# Epoch 270/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.9760 - loss: 0.1547 - val_accuracy: 0.3750 - val_loss: 3.5667
# Epoch 271/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.9944 - loss: 0.0306 - val_accuracy: 0.3750 - val_loss: 3.6023
# Epoch 272/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.9860 - loss: 0.0727 - val_accuracy: 0.3750 - val_loss: 3.6388
# Epoch 273/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.9531 - loss: 0.1134 - val_accuracy: 0.3750 - val_loss: 3.6712
# Epoch 274/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.9798 - loss: 0.0546 - val_accuracy: 0.3750 - val_loss: 3.6654
# Epoch 275/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 0.9910 - loss: 0.0624 - val_accuracy: 0.3750 - val_loss: 3.6173
# Epoch 276/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.9860 - loss: 0.0505 - val_accuracy: 0.3750 - val_loss: 3.5547
# Epoch 277/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.9521 - loss: 0.0973 - val_accuracy: 0.3750 - val_loss: 3.5015
# Epoch 278/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9681 - loss: 0.1142 - val_accuracy: 0.3750 - val_loss: 3.4410
# Epoch 279/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9771 - loss: 0.0607 - val_accuracy: 0.3750 - val_loss: 3.3773
# Epoch 280/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9614 - loss: 0.0886 - val_accuracy: 0.3750 - val_loss: 3.3407
# Epoch 281/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9760 - loss: 0.0598 - val_accuracy: 0.3750 - val_loss: 3.3022
# Epoch 282/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9760 - loss: 0.0888 - val_accuracy: 0.3750 - val_loss: 3.2758
# Epoch 283/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9860 - loss: 0.0775 - val_accuracy: 0.3750 - val_loss: 3.2585
# Epoch 284/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9671 - loss: 0.0776 - val_accuracy: 0.3750 - val_loss: 3.2477
# Epoch 285/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.9614 - loss: 0.1112 - val_accuracy: 0.3750 - val_loss: 3.2346
# Epoch 286/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9860 - loss: 0.0776 - val_accuracy: 0.3750 - val_loss: 3.2272
# Epoch 287/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 1.0000 - loss: 0.0660 - val_accuracy: 0.3750 - val_loss: 3.2483
# Epoch 288/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9887 - loss: 0.0663 - val_accuracy: 0.3750 - val_loss: 3.2681
# Epoch 289/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9944 - loss: 0.0678 - val_accuracy: 0.3750 - val_loss: 3.2623
# Epoch 290/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 0.0324 - val_accuracy: 0.3750 - val_loss: 3.2495
# Epoch 291/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9860 - loss: 0.0871 - val_accuracy: 0.3750 - val_loss: 3.2418
# Epoch 292/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 0.0273 - val_accuracy: 0.3750 - val_loss: 3.2413
# Epoch 293/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9910 - loss: 0.0541 - val_accuracy: 0.3750 - val_loss: 3.2335
# Epoch 294/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 1.0000 - loss: 0.0326 - val_accuracy: 0.3750 - val_loss: 3.2233
# Epoch 295/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9944 - loss: 0.0600 - val_accuracy: 0.3750 - val_loss: 3.2265
# Epoch 296/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9798 - loss: 0.0771 - val_accuracy: 0.3333 - val_loss: 3.2320
# Epoch 297/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9748 - loss: 0.0752 - val_accuracy: 0.3333 - val_loss: 3.2450
# Epoch 298/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9910 - loss: 0.0342 - val_accuracy: 0.3333 - val_loss: 3.2542
# Epoch 299/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 1.0000 - loss: 0.0405 - val_accuracy: 0.3333 - val_loss: 3.2636
# Epoch 300/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9860 - loss: 0.0703 - val_accuracy: 0.3333 - val_loss: 3.2880

# %%
# Fit the model and capture the training history in history_reg
history_reg = keras_model.fit(preprocessor(X_train), y_train_ohe,
                              batch_size=20,
                              epochs=300,
                              validation_split=0.25,
                              verbose=0)  # Set verbose=0 to reduce output during training

# Plot training and validation curves in two subplots
plt.figure(figsize=(12, 5))

# Plot Loss Curves
plt.subplot(1, 2, 1)
plt.plot(history_reg.history['loss'], label='Training Loss')
plt.plot(history_reg.history['val_loss'], label='Validation Loss')
plt.title("Loss Curves")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()

# Plot Accuracy Curves
plt.subplot(1, 2, 2)
plt.plot(history_reg.history['accuracy'], label='Training Accuracy')
plt.plot(history_reg.history['val_accuracy'], label='Validation Accuracy')
plt.title("Accuracy Curves")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()

plt.tight_layout()
plt.show()

# %%
# Your comments about the change in performance

# %% [markdown]
# Experiment with different activation functions (ReLU, LeakyReLU, Tanh, Sigmoid) to observe their impact on model performance.

# %%
# Model using ReLU activation (baseline)
from keras.models import Sequential
from keras.layers import Dense
from keras.utils import to_categorical

# Count features in input data
feature_count = preprocessor(X_train).shape[1]

# Build the model
relu_model = Sequential()
relu_model.add(Dense(128, input_dim=feature_count, activation='relu'))
relu_model.add(Dense(64, activation='relu'))
relu_model.add(Dense(64, activation='relu'))
relu_model.add(Dense(32, activation='relu'))
relu_model.add(Dense(5, activation='softmax'))  # 5 neurons for 5 classes

# Compile the model
relu_model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Convert y_train to one-hot encoding
y_train_labels = y_train.astype('category').cat.codes
y_train_ohe = to_categorical(y_train_labels, num_classes=5)

# Train the model
history_relu = relu_model.fit(preprocessor(X_train), y_train_ohe,
                              batch_size=20,
                              epochs=300,
                              validation_split=0.25,
                              verbose=0)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# Model using LeakyReLU activation
from keras.models import Sequential
from keras.layers import Dense, LeakyReLU

leaky_model = Sequential()
leaky_model.add(Dense(128, input_dim=feature_count))
leaky_model.add(LeakyReLU(alpha=0.1))
leaky_model.add(Dense(64))
leaky_model.add(LeakyReLU(alpha=0.1))
leaky_model.add(Dense(64))
leaky_model.add(LeakyReLU(alpha=0.1))
leaky_model.add(Dense(32))
leaky_model.add(LeakyReLU(alpha=0.1))
leaky_model.add(Dense(5, activation='softmax'))

leaky_model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

history_leaky = leaky_model.fit(preprocessor(X_train), y_train_ohe,
                                batch_size=20,
                                epochs=300,
                                validation_split=0.25,
                                verbose=0)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/activations/leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(

# %%
# Model using Tanh activation
from keras.models import Sequential
from keras.layers import Dense

tanh_model = Sequential()
tanh_model.add(Dense(128, input_dim=feature_count, activation='tanh'))
tanh_model.add(Dense(64, activation='tanh'))
tanh_model.add(Dense(64, activation='tanh'))
tanh_model.add(Dense(32, activation='tanh'))
tanh_model.add(Dense(5, activation='softmax'))

tanh_model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

history_tanh = tanh_model.fit(preprocessor(X_train), y_train_ohe,
                              batch_size=20,
                              epochs=300,
                              validation_split=0.25,
                              verbose=0)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# Model using Sigmoid activation
from keras.models import Sequential
from keras.layers import Dense

sigmoid_model = Sequential()
sigmoid_model.add(Dense(128, input_dim=feature_count, activation='sigmoid'))
sigmoid_model.add(Dense(64, activation='sigmoid'))
sigmoid_model.add(Dense(64, activation='sigmoid'))
sigmoid_model.add(Dense(32, activation='sigmoid'))
sigmoid_model.add(Dense(5, activation='softmax'))

sigmoid_model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

history_sigmoid = sigmoid_model.fit(preprocessor(X_train), y_train_ohe,
                                    batch_size=20,
                                    epochs=300,
                                    validation_split=0.25,
                                    verbose=0)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
import matplotlib.pyplot as plt

epochs = range(1, len(history_relu.history['loss']) + 1)

fig, axs = plt.subplots(2, 2, figsize=(14, 10))

# ReLU subplot
ax = axs[0, 0]
ax.plot(epochs, history_relu.history['loss'], label='Train Loss', color='red')
ax.plot(epochs, history_relu.history['val_loss'], label='Val Loss', color='orange')
ax.set_xlabel('Epoch')
ax.set_ylabel('Loss', color='red')
ax2 = ax.twinx()
ax2.plot(epochs, history_relu.history['accuracy'], label='Train Acc', color='blue')
ax2.plot(epochs, history_relu.history['val_accuracy'], label='Val Acc', color='cyan')
ax2.set_ylabel('Accuracy', color='blue')
ax.set_title('ReLU')
ax.legend(loc='upper left')
ax2.legend(loc='upper right')

# LeakyReLU subplot
ax = axs[0, 1]
ax.plot(epochs, history_leaky.history['loss'], label='Train Loss', color='red')
ax.plot(epochs, history_leaky.history['val_loss'], label='Val Loss', color='orange')
ax.set_xlabel('Epoch')
ax.set_ylabel('Loss', color='red')
ax2 = ax.twinx()
ax2.plot(epochs, history_leaky.history['accuracy'], label='Train Acc', color='blue')
ax2.plot(epochs, history_leaky.history['val_accuracy'], label='Val Acc', color='cyan')
ax2.set_ylabel('Accuracy', color='blue')
ax.set_title('LeakyReLU')
ax.legend(loc='upper left')
ax2.legend(loc='upper right')

# Tanh subplot
ax = axs[1, 0]
ax.plot(epochs, history_tanh.history['loss'], label='Train Loss', color='red')
ax.plot(epochs, history_tanh.history['val_loss'], label='Val Loss', color='orange')
ax.set_xlabel('Epoch')
ax.set_ylabel('Loss', color='red')
ax2 = ax.twinx()
ax2.plot(epochs, history_tanh.history['accuracy'], label='Train Acc', color='blue')
ax2.plot(epochs, history_tanh.history['val_accuracy'], label='Val Acc', color='cyan')
ax2.set_ylabel('Accuracy', color='blue')
ax.set_title('Tanh')
ax.legend(loc='upper left')
ax2.legend(loc='upper right')

# Sigmoid subplot
ax = axs[1, 1]
ax.plot(epochs, history_sigmoid.history['loss'], label='Train Loss', color='red')
ax.plot(epochs, history_sigmoid.history['val_loss'], label='Val Loss', color='orange')
ax.set_xlabel('Epoch')
ax.set_ylabel('Loss', color='red')
ax2 = ax.twinx()
ax2.plot(epochs, history_sigmoid.history['accuracy'], label='Train Acc', color='blue')
ax2.plot(epochs, history_sigmoid.history['val_accuracy'], label='Val Acc', color='cyan')
ax2.set_ylabel('Accuracy', color='blue')
ax.set_title('Sigmoid')
ax.legend(loc='upper left')
ax2.legend(loc='upper right')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 8. Explainability - SHAP Feature Importance
#
# To better understand our model's predictions, we will use **SHAP (SHapley Additive exPlanations)** to analyze feature importance.
#
# ### 🔹 How SHAP Works?
# - SHAP assigns each feature a **contribution score** for every prediction.
# - Uses **Shapley values** (from game theory) to fairly distribute importance across features.
#
# We will now apply SHAP to visualize and interpret our model’s feature contributions.

# %%
# Import necessary libraries
import shap
import matplotlib.pyplot as plt

# Initialize SHAP explainer
# Define an explainer that will help us interpret the model's decisions
# (Hint: Use shap.Explainer with the trained model and X_test data)

# Ensure SHAP works with RandomForestClassifier
explainer = shap.TreeExplainer(model_2)

# Transform X_test using preprocessor to ensure it's fully numeric
X_test_sample = np.array(preprocess.transform(X_test).toarray(), dtype=np.float64)[:100]

# Compute SHAP values
shap_values = explainer.shap_values(X_test_sample)

# Plot SHAP summary plot
# This plot will show which features have the most impact on predictions
plt.figure(figsize=(10, 6))
shap.summary_plot(shap_values, X_test_sample, feature_names=X_test.columns) ## Pass the required parameters to create a summary plot

# Your cell should output a SHAP summary plot showing the most important features.
# Plot SHAP bar chart for feature importance
plt.figure(figsize=(10, 6))
shap.summary_plot(shap_values, X_test_sample, plot_type="bar", feature_names=X_test.columns)

# %% [markdown]
# <h3> Experimentation

# %%
## You are encouraged to try more experimentation and any other models by adding more code cells to this notebook:

## You can also try to import any new dataset pertaining to countries, merge it, and see if it helps the predictions.
## If it does not, try to explain why it wasn't helpful by exploring variable relationships.

# %%
# Try model_4

import shap
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# Ensure SHAP works with KNeighborsClassifier
X_train_transformed = preprocessor(X_train)
X_test_transformed = preprocessor(X_test)

# Use KernelExplainer for non-tree models
explainer = shap.KernelExplainer(model_4.predict_proba, X_train_transformed[:100])

# Compute SHAP values on a subset of test data
X_test_sample = X_test_transformed[:100]
shap_values = explainer.shap_values(X_test_sample)

# Plot SHAP summary plot
plt.figure(figsize=(10, 6))
shap.summary_plot(shap_values, X_test_sample, feature_names=X_test.columns)

# Plot SHAP bar chart for feature importance
plt.figure(figsize=(10, 6))
shap.summary_plot(shap_values, X_test_sample, plot_type="bar", feature_names=X_test.columns)
# Out:
#   0%|          | 0/42 [00:00<?, ?it/s]

# %% [markdown]
# Deep learning models are often considered 'black boxes' due to their complexity. Explore methods such as SHAP (SHapley Additive exPlanations) to explain your model's predictions. After applying one of these methods, do you feel it provides a clear and sufficient explanation of how your model makes decisions? How easy or difficult is it to justify your model's predictions using these techniques?

# %%
## Your Code and Answer:

# %% [markdown]
# ## 9. Submission of final report and clean code to github
#
# [This is a final project you display on your GitHub to the World]
#
# **Instructions**
# - Make a new notebook, visualize any plots you found relevant
# - Reproduce the code you used for the best models and display results
# - Write what insights you found useful and what behaviours were observed
# - Make it in a style of a clean, succint report (within the .ipynb)
# - Upload this final report notebook to a new repository in your personal github account
# - Remember to paste the link of your final repo at the top of this notebook where asked
