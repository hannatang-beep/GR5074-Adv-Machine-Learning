# %% [markdown]
# <a href="https://colab.research.google.com/github/hannatang-beep/GR5074-Adv-Machine-Learning/blob/main/Group1_World_Happiness_Classification_Competition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # World Happiness Classification Competition

# %% [markdown]
# ## Group 1
# ## Yutong Quan(yq2397), Han He(hh3098), Hanna Tang(ht2668).

# %% [markdown]
# In this project, we firstly load the datasets and merge them to create a unified dataset for analysis. Next, preprocess the data by using Sklearn’s ColumnTransformer to ensure proper handling of categorical and numerical features. We also write and save the preprocessor function for future use. After the preprocessing, we fit the model on the transformed data and save both the preprocessor function and the trained model for reproducibility. Finally, generate predictions using the preprocessed X_test data and submit the predictions as the final output.

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# Load the dataset
whr_df = pd.read_csv('https://raw.githubusercontent.com/hannatang-beep/GR5074-Adv-Machine-Learning/refs/heads/main/data/WHR_2023.csv')

# Inspect the first few rows to understand the structure
whr_df.head()
# Out:
#        country                        region  happiness_score  gdp_per_capita  \
# 0      Finland                Western Europe            7.804           1.888
# 1      Denmark                Western Europe            7.586           1.949
# 2      Iceland                Western Europe            7.530           1.926
# 3       Israel  Middle East and North Africa            7.473           1.833
# 4  Netherlands                Western Europe            7.403           1.942
#
#    social_support  healthy_life_expectancy  freedom_to_make_life_choices  \
# 0           1.585                    0.535                         0.772
# 1           1.548                    0.537                         0.734
# 2           1.620                    0.559                         0.738
# 3           1.521                    0.577                         0.569
# 4           1.488                    0.545                         0.672
#
#    generosity  perceptions_of_corruption
# 0       0.126                      0.535
# 1       0.208                      0.525
# 2       0.250                      0.187
# 3       0.124                      0.158
# 4       0.251                      0.394

# %%
# Convert the regression target ('happiness_score') into classification labels
# We'll use quartiles to create 4 happiness categories: Very Low, Low, High, Very High

# Define quartiles
whr_df['happiness_category'] = pd.qcut(whr_df['happiness_score'],
                                       q=5,
                                       labels=['Very Low', 'Low','Average', 'High', 'Very High'])

# Select features and target
X = whr_df.drop(columns=['happiness_score', 'happiness_category'])
y = whr_df['happiness_category']

# Split into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, stratify=y)

# Convert y_train and y_test to numerical labels
y_train_labels = y_train.astype('category').cat.codes
y_test_labels = y_test.astype('category').cat.codes

# %% [markdown]
# y_train.astype('category') is the pre-process to convert the categorical happiness labels into numerical codes;
# .cat.codes - This accesses the numerical codes that pandas assigns to each unique category value.
# y_train_labels: Contains numerical equivalents, typically starting from 0: for this case: 'Very Low' → 0, 'Low' → 1, 'Average' → 2, 'High' → 3, 'Very High' → 4

# %%
# Truncated and cleaned up region data to merge
countrydata=pd.read_csv("https://raw.githubusercontent.com/hannatang-beep/GR5074-Adv-Machine-Learning/refs/heads/main/data/newcountryvars.csv")
countrydata.head()
# Out:
#   country_name  population  population_below_poverty_line       hdi  \
# 0        India  1339180127                           21.9  0.623559
# 1      Nigeria   190886311                           70.0  0.527105
# 2       Mexico   129163276                           46.2  0.761683
# 3     Pakistan   197015955                           29.5  0.550354
# 4   Bangladesh   164669751                           31.5  0.578824
#
#    life_expectancy  expected_years_of_schooling  mean_years_of_schooling  \
# 0           68.322                    11.696590                 6.298834
# 1           53.057                     9.970482                 6.000000
# 2           76.972                    13.299090                 8.554985
# 3           66.365                     8.106910                 5.089460
# 4           71.985                    10.178706                 5.241577
#
#             gni
# 0   5663.474799
# 1   5442.901264
# 2  16383.106680
# 3   5031.173074
# 4   3341.490722

# %%
# Merge in new data to X_train and X_test by taking "country" from first table and "country_name" from 2nd table.

# Merge the new country variables with X_train
X_train = X_train.merge(
    countrydata,
    left_on='country',
    right_on='country_name',
    how='left'
)

# Merge the new country variables with X_test
X_test = X_test.merge(
    countrydata,
    left_on='country',
    right_on='country_name',
    how='left'
)

# %%
# Check the common countries
common_countries = set(X_train['country']).intersection(set(countrydata['country_name']))
print(f"\nNumber of common countries in both datasets: {len(common_countries)}")
print(f"Total countries in training set: {X_train['country'].nunique()}")
print(f"Total countries in country dataset: {countrydata['country_name'].nunique()}")
# Out:
# Number of common countries in both datasets: 89
# Total countries in training set: 95
# Total countries in country dataset: 174

# %%
X_train.head()
# Out:
#       country                              region  gdp_per_capita  \
# 0  Madagascar                  Sub-Saharan Africa           0.632
# 1  Mauritania                  Sub-Saharan Africa           1.099
# 2    Mongolia                           East Asia           1.379
# 3  Tajikistan  Commonwealth of Independent States           0.972
# 4     Ukraine          Central and Eastern Europe           1.358
#
#    social_support  healthy_life_expectancy  freedom_to_make_life_choices  \
# 0           0.779                    0.178                         0.187
# 1           0.764                    0.244                         0.320
# 2           1.494                    0.244                         0.425
# 3           1.248                    0.291                         0.599
# 4           1.354                    0.355                         0.551
#
#    generosity  perceptions_of_corruption country_name  population  \
# 0       0.177                      0.134   Madagascar  25570895.0
# 1       0.130                      0.195   Mauritania   4420184.0
# 2       0.239                      0.058     Mongolia   3075647.0
# 3       0.104                      0.292   Tajikistan   8921343.0
# 4       0.265                      0.016      Ukraine  44222947.0
#
#    population_below_poverty_line       hdi  life_expectancy  \
# 0                           70.7  0.512149           65.515
# 1                           31.0  0.513106           63.239
# 2                           21.6  0.734832           69.806
# 3                           31.5  0.627472           69.582
# 4                           24.1  0.743049           71.129
#
#    expected_years_of_schooling  mean_years_of_schooling           gni
# 0                     10.34614                 6.145955   1319.699397
# 1                      8.46379                 4.266000   3527.264154
# 2                     14.84552                 9.750000  10449.207270
# 3                     11.26186                10.355820   2600.585607
# 4                     15.30672                11.340000   7361.011228

# %%
# Check the data type of X_train
print(X_train.dtypes)
# Out:
# country                           object
# region                            object
# gdp_per_capita                   float64
# social_support                   float64
# healthy_life_expectancy          float64
# freedom_to_make_life_choices     float64
# generosity                       float64
# perceptions_of_corruption        float64
# country_name                      object
# population                       float64
# population_below_poverty_line    float64
# hdi                              float64
# life_expectancy                  float64
# expected_years_of_schooling      float64
# mean_years_of_schooling          float64
# gni                              float64
# dtype: object

# %% [markdown]
# The result shows the data types of each column in X_train DataFrame after merging with the country data.
# String columns: country, region, country_name
# Numerical features: gdp_per_capita, population, population_below_poverty_line, gni, hdi, life_expectancy, expected_years_of_schooling, mean_years_of_schooling, social_support, healthy_life_expectancy, freedom_to_make_life_choices, generosity, perceptions_of_corruption.

# %%
# Check the number and percentage of missing values in the table per column

missing_values = X_train.isnull().sum()

# Calculate missing values
total_rows = len(X_train)
missing_percentage = (missing_values / total_rows) * 100

# Create missing values summary
missing_summary = pd.DataFrame({
    'Missing Values': missing_values,
    'Percentage (%)': missing_percentage
})

missing_summary = missing_summary.sort_values('Missing Values', ascending=False)

print(missing_summary)
# Out:
#                                Missing Values  Percentage (%)
# population_below_poverty_line              16       16.842105
# life_expectancy                             7        7.368421
# expected_years_of_schooling                 7        7.368421
# mean_years_of_schooling                     7        7.368421
# gni                                         7        7.368421
# country_name                                6        6.315789
# population                                  6        6.315789
# hdi                                         6        6.315789
# country                                     0        0.000000
# region                                      0        0.000000
# gdp_per_capita                              0        0.000000
# social_support                              0        0.000000
# healthy_life_expectancy                     0        0.000000
# freedom_to_make_life_choices                0        0.000000
# generosity                                  0        0.000000
# perceptions_of_corruption                   0        0.000000

# %%
# Plot the frequency distribution / histogram of important numerical features

import matplotlib.pyplot as plt
import seaborn as sns

# List of important numerical features to plot
important_features = ['gdp_per_capita', 'healthy_life_expectancy',
                      'social_support', 'freedom_to_make_life_choices',
                      'perceptions_of_corruption', 'hdi']

# Create a figure with multiple subplots
fig, axes = plt.subplots(2, 3, figsize=(18, 10))
axes = axes.flatten()

# Plot histograms for each feature
for i, feature in enumerate(important_features):
    if i < len(axes) and feature in X_train.columns:
        sns.histplot(X_train[feature], kde=True, ax=axes[i])
        axes[i].set_title(f'Distribution of {feature}')
        axes[i].set_xlabel(feature)
        axes[i].set_ylabel('Frequency')

plt.tight_layout()
plt.show()

# %%
# Plot the categorical variables and their distribution
# Set figure size and style
plt.figure(figsize=(14, 10))
sns.set_style("whitegrid")

# region
plt.subplot(2, 1, 1)
region_counts = X_train['region'].value_counts().sort_values(ascending=False)
sns.barplot(x=region_counts.index, y=region_counts.values)
plt.title('Distribution of Countries by Region', fontsize=15)
plt.ylabel('Count', fontsize=12)
plt.xticks(rotation=45, ha='right')
plt.tight_layout(pad=3.0)

# happiness
plt.subplot(2, 1, 2)
happiness_counts = y_train.value_counts().sort_values(ascending=False)
sns.barplot(x=happiness_counts.index, y=happiness_counts.values, palette='viridis')
plt.title('Distribution of Happiness Categories', fontsize=15)
plt.ylabel('Count', fontsize=12)
plt.xlabel('Happiness Category', fontsize=12)
plt.tight_layout()

plt.show()
# Out:
# /var/folders/hn/lsv9xwmj4c38wnf5dg9xjslc0000gn/T/ipykernel_92280/811391434.py:18: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=happiness_counts.index, y=happiness_counts.values, palette='viridis')

# %% [markdown]
# ## Correlation Analysis

# %%
import numpy as np
# 1. Calculate correlation matrices

numeric_columns = X_train.select_dtypes(include=[np.number]).columns

# Calculate correlation matrices
pearson_corr = X_train[numeric_columns].corr(method='pearson')
spearman_corr = X_train[numeric_columns].corr(method='spearman')

# Print Pearson correlations
print("Top Pearson Correlations:")
pearson_upper = pearson_corr.where(np.triu(np.ones(pearson_corr.shape), k=1).astype(bool))
pearson_sorted = pearson_upper.stack().sort_values(ascending=False)
print(pearson_sorted.head(10))  # Top 10 positive correlations
print(pearson_sorted.tail(10))  # Top 10 negative correlations
# Out:
# Top Pearson Correlations:
# healthy_life_expectancy      life_expectancy                0.959434
# hdi                          expected_years_of_schooling    0.939177
#                              mean_years_of_schooling        0.934324
#                              life_expectancy                0.932439
# healthy_life_expectancy      hdi                            0.929456
# gdp_per_capita               hdi                            0.902386
# expected_years_of_schooling  mean_years_of_schooling        0.880690
# gdp_per_capita               healthy_life_expectancy        0.860164
# social_support               hdi                            0.855297
# life_expectancy              expected_years_of_schooling    0.852332
# dtype: float64
# perceptions_of_corruption      population_below_poverty_line   -0.181277
# freedom_to_make_life_choices   population_below_poverty_line   -0.476459
# population_below_poverty_line  gni                             -0.537597
#                                mean_years_of_schooling         -0.579371
#                                expected_years_of_schooling     -0.582770
# social_support                 population_below_poverty_line   -0.605304
# gdp_per_capita                 population_below_poverty_line   -0.620790
# population_below_poverty_line  hdi                             -0.683361
# healthy_life_expectancy        population_below_poverty_line   -0.716390
# population_below_poverty_line  life_expectancy                 -0.719110
# dtype: float64

# %% [markdown]
# The strongest positive Pearson correlations (close to 1) indicate positive relationship between variables.
# Healthy Life Expectancy & Life Expectancy (0.959): Countries with higher life expectancy also tend to have higher healthy life expectancy.
# HDI & Expected Years of Schooling (0.939): Higher Human Development Index (HDI) is strongly associated with more expected schooling years.
# GDP per Capita & HDI (0.902): Wealthier countries (higher GDP per capita) tend to have higher HDI.
# The strongest negative Pearson correlations (close to -1) indicate inverse relationships. For example:
# Population Below Poverty Line & Life Expectancy (-0.719): Higher poverty rates are associated with lower life expectancy.
# GDP per Capita & Population Below Poverty Line (-0.621): Wealthier countries tend to have lower poverty rates.

# %%
# Print Spearman correlations
print("\nTop Spearman Correlations:")
spearman_upper = spearman_corr.where(np.triu(np.ones(spearman_corr.shape), k=1).astype(bool))
spearman_sorted = spearman_upper.stack().sort_values(ascending=False)
print(spearman_sorted.head(10))  # Top 10 positive correlations
print(spearman_sorted.tail(10))  # Top 10 negative correlations
# Out:
# Top Spearman Correlations:
# hdi                      gni                            0.969057
# gdp_per_capita           gni                            0.966186
# healthy_life_expectancy  life_expectancy                0.956933
# gdp_per_capita           hdi                            0.947752
# hdi                      expected_years_of_schooling    0.943715
#                          life_expectancy                0.940364
#                          mean_years_of_schooling        0.922035
# healthy_life_expectancy  hdi                            0.920871
# life_expectancy          gni                            0.902200
# gdp_per_capita           healthy_life_expectancy        0.892963
# dtype: float64
# social_support                 population                      -0.357605
# freedom_to_make_life_choices   population_below_poverty_line   -0.476760
# population_below_poverty_line  expected_years_of_schooling     -0.612283
# social_support                 population_below_poverty_line   -0.624048
# population_below_poverty_line  mean_years_of_schooling         -0.628192
# gdp_per_capita                 population_below_poverty_line   -0.650409
# population_below_poverty_line  gni                             -0.662375
#                                hdi                             -0.671239
#                                life_expectancy                 -0.677277
# healthy_life_expectancy        population_below_poverty_line   -0.682434
# dtype: float64

# %% [markdown]
# The results are similar to Pearson but show slight differences in rankings.
# HDI & GNI (0.969): Countries with higher Gross National Income (GNI) tend to have higher HDI.
# GDP per Capita & Healthy Life Expectancy (0.893): Higher GDP per capita is associated with longer healthy life expectancy.
# Population Below Poverty Line & Life Expectancy (-0.677): Similar to Pearson, high poverty rates correlate with shorter life expectancy.

# %%
from sklearn.preprocessing import StandardScaler
import seaborn as sns

# correlation table
def correlation_table(X, y, target_name='Happiness'):
    correlations = {}
    for column in X.select_dtypes(include=[np.number]).columns:
        corr = np.corrcoef(X[column], y)[0, 1]
        correlations[column] = corr

    corr_df = pd.DataFrame({
        'Feature': list(correlations.keys()),
        'Correlation': list(correlations.values())
    })
    corr_df = corr_df.sort_values('Correlation', ascending=False)

    return corr_df

#  correlation heatmap
def plot_heatmap(X):
    numeric_X = X.select_dtypes(include=[np.number])

    corr = numeric_X.corr()

    plt.figure(figsize=(10, 8))
    sns.heatmap(corr, annot=True, cmap='coolwarm', fmt='.2f')
    plt.title('Correlation Heatmap')
    plt.tight_layout()
    plt.show()

# Bivariate plots with target
def plot_top_relationships(X, y, target_name='Happiness', n_features=5):
    corr_table = correlation_table(X, y, target_name)
    top_features = corr_table.iloc[:n_features, 0].tolist()

    plt.figure(figsize=(12, 10))
    for i, feature in enumerate(top_features):
        plt.subplot(n_features, 1, i+1)
        plt.scatter(X[feature], y, alpha=0.6)
        plt.xlabel(feature)
        plt.ylabel(target_name)
        plt.title(f'{feature} vs {target_name}')

    plt.tight_layout()
    plt.show()

# %%
# 1. Show correlation table
corr_table = correlation_table(X_train, y_train_labels, 'Happiness')
print("Correlation with Happiness:")
print(corr_table)
# Out:
# Correlation with Happiness:
#                           Feature  Correlation
# 0                  gdp_per_capita     0.809400
# 1                  social_support     0.787159
# 2         healthy_life_expectancy     0.752381
# 3    freedom_to_make_life_choices     0.581430
# 5       perceptions_of_corruption     0.470842
# 4                      generosity    -0.012036
# 6                      population          NaN
# 7   population_below_poverty_line          NaN
# 8                             hdi          NaN
# 9                 life_expectancy          NaN
# 10    expected_years_of_schooling          NaN
# 11        mean_years_of_schooling          NaN
# 12                            gni          NaN

# %%
# 2. Plot correlation heatmap
plot_heatmap(X_train)

# %% [markdown]
# HDI is highly correlated with many variables (especially healthy life expectancy at 0.93), suggesting multicollinearity
# #Strong correlations between: GDP per capita and HDI (0.90); Healthy life expectancy and life expectancy (0.96); Expected years of schooling and mean years of schooling (0.88)

# %%
# 3. Plot top 5 features against target
plot_top_relationships(X_train, y_train_labels, 'Happiness', n_features=5)

# %% [markdown]
# Economic factors (GDP per capita), social support, and health are the strongest predictors of happiness.
# Corruption perception and personal freedom also matter but to a lesser extent.
# Generosity appears to have no direct correlation, suggesting that cultural or reporting biases might influence the data.
# Some key variables (education, HDI, poverty rate) were not included in the analysis, possibly due to missing or incompatible data.

# %%
# detect outliers using box plots and the IQR method to identify potential data anomalies.

def detect_outliers_simple(data, columns=None):

    if columns is None:
        columns = data.select_dtypes(include=[np.number]).columns.tolist()[:5]  # Limit to 5 features

    # 1. Box plots - visual detection
    plt.figure(figsize=(12, 8))
    sns.boxplot(data=data[columns])
    plt.title('Box Plots for Outlier Detection')
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()

    # 2. IQR method - simple statistical approach
    print("Outliers detected using IQR method (beyond ±1.5*IQR):")
    for column in columns:
        Q1 = data[column].quantile(0.25)
        Q3 = data[column].quantile(0.75)
        IQR = Q3 - Q1

        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR

        outliers = data[(data[column] < lower_bound) | (data[column] > upper_bound)]

        print(f"{column}: {len(outliers)} outliers ({len(outliers)/len(data)*100:.1f}%)")

        if len(outliers) > 0 and len(outliers) < 10:
            print(f"   Outlier values: {sorted(outliers[column].tolist())}")
            print(f"   Countries: {sorted(outliers['country'].tolist()) if 'country' in outliers.columns else 'N/A'}")

        print(f"   Normal range: [{lower_bound:.3f}, {upper_bound:.3f}]")
        print()


important_features = ['gdp_per_capita', 'social_support', 'healthy_life_expectancy',
                     'freedom_to_make_life_choices', 'generosity']

# Detect outliers
detect_outliers_simple(X_train, columns=important_features)
# Out:
# Outliers detected using IQR method (beyond ±1.5*IQR):
# gdp_per_capita: 1 outliers (1.1%)
#    Outlier values: [0.0]
#    Countries: ['Venezuela']
#    Normal range: [0.001, 2.898]
#
# social_support: 2 outliers (2.1%)
#    Outlier values: [0.0, 0.327]
#    Countries: ['Afghanistan', 'Comoros']
#    Normal range: [0.332, 2.014]
#
# healthy_life_expectancy: 0 outliers (0.0%)
#    Normal range: [-0.140, 0.892]
#
# freedom_to_make_life_choices: 3 outliers (3.2%)
#    Outlier values: [0.0, 0.117, 0.125]
#    Countries: ['Afghanistan', 'Comoros', 'Turkiye']
#    Normal range: [0.152, 0.956]
#
# generosity: 1 outliers (1.1%)
#    Outlier values: [0.422]
#    Countries: ['Indonesia']
#    Normal range: [-0.045, 0.357]

# %% [markdown]
# Venezuela is an outlier for GDP per capita
# Afghanistan and Comoros are outliers for social support and freedom
# Indonesia is an outlier for generosity

# %% [markdown]
# # Feature Engineering

# %%
# Apply log transformations to normalize skewed data and improve model stability.

# Separate numeric columns
numeric_train = X_train.select_dtypes(include=['number'])
numeric_test = X_test.select_dtypes(include=['number'])

# Calculate skewness for numeric variables
skew_train = numeric_train.skew()
skew_test = numeric_test.skew()

print("Skewness of each variable in X_train:")
print(skew_train)

# Filter variables with absolute skewness greater than 1
print("\nVariables with absolute skewness > 1 (high skewness):")
high_skew_train = skew_train[skew_train.abs() > 1]

print("\nVariables in X_train with absolute skewness > 1 (high skewness):")
print(high_skew_train)
# Out:
# Skewness of each variable in X_train:
# gdp_per_capita                  -0.547790
# social_support                  -0.954425
# healthy_life_expectancy         -0.367545
# freedom_to_make_life_choices    -0.970893
# generosity                       0.555203
# perceptions_of_corruption        1.600420
# population                       6.058979
# population_below_poverty_line    1.074529
# hdi                             -0.453412
# life_expectancy                 -0.632233
# expected_years_of_schooling     -0.206557
# mean_years_of_schooling         -0.437315
# gni                              1.270302
# dtype: float64
#
# Variables with absolute skewness > 1 (high skewness):
#
# Variables in X_train with absolute skewness > 1 (high skewness):
# perceptions_of_corruption        1.600420
# population                       6.058979
# population_below_poverty_line    1.074529
# gni                              1.270302
# dtype: float64

# %% [markdown]
# Perceptions of Corruption (1.60): Right-skewed, meaning most countries have lower corruption perception scores, but a few have very high ones.
# Population (6.06): Extremely right-skewed, likely due to a few countries (e.g., China, India) having massively larger populations than others.
# Population Below Poverty Line (1.07): Right-skewed, indicating most countries have lower poverty rates, but a few have very high rates.
# Gross National Income (GNI) (1.27): Right-skewed, suggesting a few countries have significantly higher incomes compared to the rest.

# %%
# Define the list of skewed variables
skewed_variables = ['population', 'gni', 'perceptions_of_corruption']

# Apply log transformation to skewed variables
for var in skewed_variables:
    if var in X_train.columns and var in X_test.columns:
        X_train[var + '_log'] = np.log1p(X_train[var])
        X_test[var + '_log'] = np.log1p(X_test[var])

        print(f"{var}_log skewness: {X_train[var + '_log'].skew():.3f}")
# Out:
# population_log skewness: 0.173
# gni_log skewness: -0.414
# perceptions_of_corruption_log skewness: 1.393

# %% [markdown]
# After applying log transformations, the skewness values for highly skewed variables have reduced, but some still exhibit noticeable asymmetry. Log transformation effectively normalized Population and GNI, making them more suitable for modeling.

# %%
# Create one simple interaction term between the two most important features
# From the correlation results, the two most important features are gdp_per_capita and social_support

# Create the interaction
X_train['gdp_social_interaction'] = X_train['gdp_per_capita'] * X_train['social_support']
X_test['gdp_social_interaction'] = X_test['gdp_per_capita'] * X_test['social_support']

# Quick plot to see relationship with happiness
plt.figure(figsize=(8, 6))
plt.scatter(X_train['gdp_social_interaction'], y_train)
plt.xlabel('GDP × Social Support')
plt.ylabel('Happiness Category')
plt.title('Effect of GDP and Social Support Interaction on Happiness')
plt.show()

# Check correlation with target
correlation = np.corrcoef(X_train['gdp_social_interaction'], y_train_labels)[0, 1]
print(f"Correlation between GDP × Social Support and Happiness: {correlation:.4f}")
# Out:
# Correlation between GDP × Social Support and Happiness: 0.8691

# %% [markdown]
# As the interaction value (GDP × Social Support) increases, happiness categories tend to be higher.

# %% [markdown]
# # Preprocess data using Sklearn Column Transformer/ Write and Save Preprocessor function

# %%
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer, make_column_transformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder

# Create the preprocessing pipelines for both numeric and categorical data.

numeric_features = X_train.select_dtypes(include=['number']).columns.tolist()
categorical_features = ['country', 'region'] #separate numeric and categorical features to apply different transformations to each type.

numeric_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='constant', fill_value=0)), # replace missing values with 0 using SimpleImputer(strategy='constant', fill_value=0).
    ('scaler', StandardScaler())]) # standardize features using StandardScaler(), which transforms each feature to have mean=0 and standard deviation=1.
## This scaling is crucial because features like GDP and population have vastly different scales, which could cause some variables to dominate in distance-based algorithms or gradient-based optimization.

# Replacing missing values with Modal value and then one hot encoding.
categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')), # Replace missing values with the most frequent value using SimpleImputer(strategy='most_frequent').
    ('onehot', OneHotEncoder(handle_unknown='ignore'))
])
# Convert categorical variables into numeric form using OneHotEncoder(handle_unknown='ignore').
# The handle_unknown='ignore' parameter ensures our pipeline doesn't break if new categories appear in the test set.

##Pipeline Construction:
#We organize these operations into separate pipelines for each data type. -> This ensures transformations are applied in the correct order.

##Combining Transformers:
#ColumnTransformer applies each pipeline to the appropriate columns. -> This creates a unified preprocessing workflow that handles mixed data types.

# final preprocessor object set up with ColumnTransformer
preprocessor = ColumnTransformer(transformers=[
    ('num', numeric_transformer, numeric_features),
     ('cat', categorical_transformer, categorical_features)])

#Fit preprocessor object
preprocess=preprocessor.fit(X_train) #fit the preprocessor on training data, learning parameters like means and standard deviations.
#We then transform both training and test data consistently.

# %%
# Write function to transform data with preprocessor

def preprocessor(data):
    data.drop(['country', 'region'], axis=1)
    preprocessed_data=preprocess.transform(data)
    return preprocessed_data

# %% [markdown]
# Preprocessor object is the ColumnTransformer that defines the transformation steps for numeric and categorical data.
# Preprocess object is the fitted version of that transformer (i.e., it has learned the necessary parameters from the training data).
# Preprocessor function is a user-defined wrapper that first drops unneeded columns (like 'country' and 'region') and then applies the fitted transformation.
# Preprocessed_data is the resulting output after transforming the input data with the preprocessor function, which is ready for modeling.

# %%
# check shape of X data after preprocessing it using our new function
preprocessor(X_train).shape
# Out:
# (95, 122)

# %% [markdown]
# # Fit model on preprocessed data and save preprocessor function and model

# %%
# Preprocess the training and testing data using the preprocessor function

X_train_preprocessed = preprocessor(X_train)
X_test_preprocessed = preprocessor(X_test)

# %%
from sklearn.ensemble import RandomForestClassifier

## Define a Random Forest Model, fit it, and score it
model_1 = RandomForestClassifier(n_estimators=100, random_state=42)

# Fit the model on the preprocessed training data and corresponding labels
model_1.fit(X_train_preprocessed, y_train_labels)

# Score the model on the preprocessed test set
score = model_1.score(X_test_preprocessed, y_test_labels)
print("Random Forest Model 1 Test Score:", score)
# Out:
# Random Forest Model 1 Test Score: 0.5952380952380952

# %% [markdown]
# # Generate predictions from X_test data and compare it with true labels in Y_test

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# Generate predicted values (Model 1)
prediction_labels_1 = model_1.predict(X_test_preprocessed)

# Calculate accuracy
accuracy_1 = accuracy_score(y_test_labels, prediction_labels_1)
print("Model 1 Accuracy:", accuracy_1)

# Print classification report
print("Classification Report (Model 1):")
print(classification_report(y_test_labels, prediction_labels_1))

# Print confusion matrix
print("Confusion Matrix (Model 1):")
print(confusion_matrix(y_test_labels, prediction_labels_1))
# Out:
# Model 1 Accuracy: 0.5952380952380952
# Classification Report (Model 1):
#               precision    recall  f1-score   support
#
#            0       0.57      0.44      0.50         9
#            1       0.40      0.50      0.44         8
#            2       0.60      0.75      0.67         8
#            3       0.62      0.62      0.62         8
#            4       0.86      0.67      0.75         9
#
#     accuracy                           0.60        42
#    macro avg       0.61      0.60      0.60        42
# weighted avg       0.62      0.60      0.60        42
#
# Confusion Matrix (Model 1):
# [[4 5 0 0 0]
#  [3 4 1 0 0]
#  [0 1 6 1 0]
#  [0 0 2 5 1]
#  [0 0 1 2 6]]

# %% [markdown]
# # Repeat the process with different parameters to improve the accuracy

# %%
# Train model 2 using same preprocessor
from sklearn.ensemble import RandomForestClassifier

## Make a new model with changed parameters to improve the score

model_2 = RandomForestClassifier(
    n_estimators=500,   # Increased the number of trees to reduce variance
    max_depth=15,   # Limited max_depth to prevent overfitting
    min_samples_split=10,   # Increased min_samples_split to ensure splits occur only with sufficient data
    random_state=42
)

# Fit the model using the preprocessed training data
model_2.fit(X_train_preprocessed, y_train_labels)
# Out:
# RandomForestClassifier(max_depth=15, min_samples_split=10, n_estimators=500,
#                        random_state=42)

# %%
#Evaluate Model 2:

#-- Generate predicted y values (Model 2)
prediction_labels_2 = model_2.predict(X_test_preprocessed)

# Calculate accuracy
accuracy_2 = accuracy_score(y_test_labels, prediction_labels_2)
print("Model 2 Accuracy:", accuracy_2)

# Print classification report
print("Classification Report:")
print(classification_report(y_test_labels, prediction_labels_2))

# Print confusion matrix
print("Confusion Matrix:")
print(confusion_matrix(y_test_labels, prediction_labels_2))
# Out:
# Model 2 Accuracy: 0.5952380952380952
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.57      0.44      0.50         9
#            1       0.45      0.62      0.53         8
#            2       0.60      0.75      0.67         8
#            3       0.57      0.50      0.53         8
#            4       0.86      0.67      0.75         9
#
#     accuracy                           0.60        42
#    macro avg       0.61      0.60      0.60        42
# weighted avg       0.62      0.60      0.60        42
#
# Confusion Matrix:
# [[4 5 0 0 0]
#  [3 5 0 0 0]
#  [0 1 6 1 0]
#  [0 0 3 4 1]
#  [0 0 1 2 6]]

# %% [markdown]
# The current improvement is barely noticed. However, further tuning may help, but manually testing random values can be inefficient and I believe we should not spend time working on that.
# Instead, using automated hyperparameter optimization methods like GridSearchCV with cross-validation can systematically explore the parameter space and often yield better results.

# %%
# Submit a third model using GridSearchCV

from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
import numpy as np

# Use np.arange to create a sequence of numbers for each parameter's space you think should be searched
param_grid = {
    'n_estimators': np.arange(100, 301, 50),
    'max_depth': np.arange(5, 21, 5),
    'min_samples_split': np.arange(2, 7)
}

# Read GridSearchCV docs and create an object with RandomForestClassifier as the model
gridmodel = GridSearchCV(RandomForestClassifier(random_state=42),
                         param_grid,
                         cv=5,
                         scoring='accuracy',
                         n_jobs=-1)

#use model methods to fit score and predict model:
gridmodel.fit(X_train_preprocessed, y_train_labels)

#extract best score and parameter by calling objects "best_score_" and "best_params_"
print("best mean cross-validation score: {:.3f}".format(gridmodel.best_score_))
print("best parameters: {}".format(gridmodel.best_params_))
# Out:
# best mean cross-validation score: 0.568
# best parameters: {'max_depth': 10, 'min_samples_split': 4, 'n_estimators': 150}

# %%
# Submit Model 3:

from sklearn.model_selection import cross_val_score

#-- Generate predicted values
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# Use the best estimator from GridSearchCV as our final model
model_3 = gridmodel.best_estimator_

# Generate predicted values on the preprocessed test set
prediction_labels_3 = model_3.predict(X_test_preprocessed)

## Write code to show model performance by comparing prediction_labels with true labels

accuracy_3 = accuracy_score(y_test_labels, prediction_labels_3)
print("Model 3 Accuracy:", accuracy_3)
print("\nClassification Report:")
print(classification_report(y_test_labels, prediction_labels_3))
print("Confusion Matrix:")
print(confusion_matrix(y_test_labels, prediction_labels_3))

cv_scores = cross_val_score(model_3, X_train_preprocessed, y_train_labels, cv=5)
print(f"\nCV scores: {cv_scores}")
print(f"Average CV score: {cv_scores.mean():.4f} (±{cv_scores.std():.4f})")
# Out:
# Model 3 Accuracy: 0.5952380952380952
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.57      0.44      0.50         9
#            1       0.40      0.50      0.44         8
#            2       0.60      0.75      0.67         8
#            3       0.62      0.62      0.62         8
#            4       0.86      0.67      0.75         9
#
#     accuracy                           0.60        42
#    macro avg       0.61      0.60      0.60        42
# weighted avg       0.62      0.60      0.60        42
#
# Confusion Matrix:
# [[4 5 0 0 0]
#  [3 4 1 0 0]
#  [0 1 6 1 0]
#  [0 0 2 5 1]
#  [0 0 1 2 6]]
#
# CV scores: [0.52631579 0.47368421 0.47368421 0.73684211 0.63157895]
# Average CV score: 0.5684 (±0.1021)

# %%
# Submit a model 4 using KNN
from sklearn.neighbors import KNeighborsClassifier

# Find the best K using GridSearchCV
k_range = range(1, 21)
knn_param_grid = {
    'n_neighbors': k_range,
    'weights': ['uniform', 'distance'],
    'metric': ['euclidean', 'manhattan']
}

knn_grid = GridSearchCV(
    KNeighborsClassifier(),
    knn_param_grid,
    cv=5,
    scoring='accuracy',
    n_jobs=-1
)

knn_grid.fit(X_train_preprocessed, y_train_labels)

# Get the best KNN model
model_4 = knn_grid.best_estimator_
print(f"\nBest KNN params: {knn_grid.best_params_}")
print(f"Best KNN CV score: {knn_grid.best_score_:.4f}")

#-- Generate predicted values
prediction_labels_4 = model_4.predict(X_test_preprocessed)

## Write code to show model performance by comparing prediction_labels with true labels
accuracy = accuracy_score(y_test_labels, prediction_labels_4)
print("KNN Model Accuracy:", accuracy)
print("\nClassification Report:")
print(classification_report(y_test_labels, prediction_labels_4))
print("Confusion Matrix:")
print(confusion_matrix(y_test_labels, prediction_labels_4))
# Out:
# Best KNN params: {'metric': 'euclidean', 'n_neighbors': 14, 'weights': 'uniform'}
# Best KNN CV score: 0.5684
# KNN Model Accuracy: 0.5952380952380952
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.75      0.33      0.46         9
#            1       0.44      0.50      0.47         8
#            2       0.44      0.88      0.58         8
#            3       0.67      0.50      0.57         8
#            4       1.00      0.78      0.88         9
#
#     accuracy                           0.60        42
#    macro avg       0.66      0.60      0.59        42
# weighted avg       0.67      0.60      0.60        42
#
# Confusion Matrix:
# [[3 5 1 0 0]
#  [1 4 3 0 0]
#  [0 0 7 1 0]
#  [0 0 4 4 0]
#  [0 0 1 1 7]]

# %%
# model 5
# Find the best parameters for GradientBoostingClassifier using GridSearchCV
from sklearn.ensemble import GradientBoostingClassifier
gbc_param_grid = {
    'n_estimators': [50, 100, 200],
    'learning_rate': [0.01, 0.1, 0.2],
    'max_depth': [3, 5, 7],
    'min_samples_split': [2, 5, 10]
}

gbc_grid = GridSearchCV(
    GradientBoostingClassifier(),
    gbc_param_grid,
    cv=5,
    scoring='accuracy',
    n_jobs=-1
)

gbc_grid.fit(X_train_preprocessed, y_train_labels)

# Get the best GBC model
model_5 = gbc_grid.best_estimator_
print(f"\nBest GBC params: {gbc_grid.best_params_}")
print(f"Best GBC CV score: {gbc_grid.best_score_:.4f}")

# Generate predicted values
prediction_labels_5 = model_5.predict(X_test_preprocessed)

# Write code to show model performance by comparing prediction_labels with true labels
accuracy = accuracy_score(y_test_labels, prediction_labels_5)
print("GBC Model Accuracy:", accuracy)
print("\nClassification Report:")
print(classification_report(y_test_labels, prediction_labels_5))
print("Confusion Matrix:")
print(confusion_matrix(y_test_labels, prediction_labels_5))
# Out:
# Best GBC params: {'learning_rate': 0.2, 'max_depth': 5, 'min_samples_split': 5, 'n_estimators': 200}
# Best GBC CV score: 0.5789
# GBC Model Accuracy: 0.5238095238095238
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.50      0.33      0.40         9
#            1       0.31      0.50      0.38         8
#            2       0.44      0.50      0.47         8
#            3       0.71      0.62      0.67         8
#            4       0.86      0.67      0.75         9
#
#     accuracy                           0.52        42
#    macro avg       0.56      0.53      0.53        42
# weighted avg       0.57      0.52      0.54        42
#
# Confusion Matrix:
# [[3 5 0 1 0]
#  [3 4 1 0 0]
#  [0 4 4 0 0]
#  [0 0 2 5 1]
#  [0 0 2 1 6]]

# %% [markdown]
# In our experiment, we performed parameter tuning for both KNN and GBC classifiers.
# For KNN, we used GridSearchCV to explore three key parameters: n_neighbors (14), weights ('uniform'), and distance metrics ('euclidean').
# For GBC, we explored four key parameters: n_estimators (100), learning_rate (0.2), max_depth (5), and min_samples_split (5).
# We used 5-fold cross-validation for both models to evaluate the performance of different parameter combinations.
# Here, KNN performs better than GBC model.

# %% [markdown]
# # Basic Deep Learning

# %%
# Now experiment with deep learning models:
import keras
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.utils import to_categorical

#count features in input data
feature_count = preprocessor(X_train).shape[1]

## Define a Neural Network Model with 5 layers 128->64->64->32->16
keras_model = Sequential()
keras_model.add(Dense(128, input_dim=feature_count, activation='relu'))
keras_model.add(Dense(64, activation='relu'))
keras_model.add(Dense(64, activation='relu'))
keras_model.add(Dense(32, activation='relu'))
keras_model.add(Dense(16, activation='relu'))


#Use Softmax activation in last layer.
keras_model.add(Dense(5, activation='softmax'))

# Compile model
keras_model.compile(loss='categorical_crossentropy', optimizer='sgd', metrics=['accuracy'])
## We use loss='categorical_crossentropy' because our task is multi-class classification and this loss function measures the performance of the model whose output is a probability distribution.
# The optimizer 'sgd' is a basic choice for gradient descent
# However, optimizers like 'adam' are often preferred as they adapt the learning rate during training and tend to converge faster.
# Depending on the observed convergence behavior, switching to Adam might yield better results with less manual tuning.

# Convert y_train numerical labels to one-hot encoding.
y_train_ohe = to_categorical(y_train_labels, num_classes=5)

# Fitting the NN to the Training set
keras_model.fit(preprocessor(X_train), y_train_ohe, ## Note that keras models require a one-hot-encoded y_train object
               batch_size = 20,
               epochs = 300, validation_split=0.25)
# Out:
# Epoch 1/300
# /opt/anaconda3/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.1234 - loss: 1.5960 - val_accuracy: 0.1667 - val_loss: 1.6059
# Epoch 2/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.2128 - loss: 1.5862 - val_accuracy: 0.1250 - val_loss: 1.6012
# Epoch 3/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.2851 - loss: 1.5627 - val_accuracy: 0.1250 - val_loss: 1.5971
# Epoch 4/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.2128 - loss: 1.5580 - val_accuracy: 0.1250 - val_loss: 1.5938
# Epoch 5/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.1795 - loss: 1.5535 - val_accuracy: 0.1250 - val_loss: 1.5896
# Epoch 6/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.2308 - loss: 1.5332 - val_accuracy: 0.1250 - val_loss: 1.5863
# Epoch 7/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.2170 - loss: 1.5408 - val_accuracy: 0.1250 - val_loss: 1.5828
# Epoch 8/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.2856 - loss: 1.4997 - val_accuracy: 0.1250 - val_loss: 1.5799
# Epoch 9/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.2929 - loss: 1.5059 - val_accuracy: 0.1250 - val_loss: 1.5778
# Epoch 10/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.3608 - loss: 1.4748 - val_accuracy: 0.1250 - val_loss: 1.5749
# Epoch 11/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.3292 - loss: 1.4879 - val_accuracy: 0.1250 - val_loss: 1.5725
# Epoch 12/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.3731 - loss: 1.4477 - val_accuracy: 0.1250 - val_loss: 1.5706
# Epoch 13/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.3465 - loss: 1.4435 - val_accuracy: 0.1250 - val_loss: 1.5699
# Epoch 14/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.4211 - loss: 1.4295 - val_accuracy: 0.1667 - val_loss: 1.5670
# Epoch 15/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.3638 - loss: 1.4310 - val_accuracy: 0.1667 - val_loss: 1.5650
# Epoch 16/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.4071 - loss: 1.4226 - val_accuracy: 0.1667 - val_loss: 1.5619
# Epoch 17/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.3754 - loss: 1.4086 - val_accuracy: 0.2083 - val_loss: 1.5606
# Epoch 18/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.3811 - loss: 1.3668 - val_accuracy: 0.2083 - val_loss: 1.5600
# Epoch 19/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.4411 - loss: 1.3190 - val_accuracy: 0.2083 - val_loss: 1.5585
# Epoch 20/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.3821 - loss: 1.3580 - val_accuracy: 0.2500 - val_loss: 1.5586
# Epoch 21/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.3954 - loss: 1.3772 - val_accuracy: 0.2500 - val_loss: 1.5576
# Epoch 22/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.4421 - loss: 1.3432 - val_accuracy: 0.2500 - val_loss: 1.5566
# Epoch 23/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.4050 - loss: 1.3284 - val_accuracy: 0.2500 - val_loss: 1.5547
# Epoch 24/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.4167 - loss: 1.2875 - val_accuracy: 0.2500 - val_loss: 1.5540
# Epoch 25/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.4284 - loss: 1.3364 - val_accuracy: 0.2500 - val_loss: 1.5539
# Epoch 26/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.4217 - loss: 1.3617 - val_accuracy: 0.2917 - val_loss: 1.5541
# Epoch 27/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.3617 - loss: 1.3318 - val_accuracy: 0.2917 - val_loss: 1.5535
# Epoch 28/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.3963 - loss: 1.3508 - val_accuracy: 0.2500 - val_loss: 1.5522
# Epoch 29/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.4296 - loss: 1.3564 - val_accuracy: 0.2500 - val_loss: 1.5524
# Epoch 30/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.4619 - loss: 1.2986 - val_accuracy: 0.2500 - val_loss: 1.5546
# Epoch 31/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.4699 - loss: 1.3114 - val_accuracy: 0.2500 - val_loss: 1.5533
# Epoch 32/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.4865 - loss: 1.2717 - val_accuracy: 0.2500 - val_loss: 1.5503
# Epoch 33/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5065 - loss: 1.2545 - val_accuracy: 0.2500 - val_loss: 1.5437
# Epoch 34/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5632 - loss: 1.2259 - val_accuracy: 0.2500 - val_loss: 1.5404
# Epoch 35/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.4922 - loss: 1.2582 - val_accuracy: 0.2500 - val_loss: 1.5408
# Epoch 36/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.4588 - loss: 1.2882 - val_accuracy: 0.2500 - val_loss: 1.5390
# Epoch 37/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5562 - loss: 1.2150 - val_accuracy: 0.2500 - val_loss: 1.5371
# Epoch 38/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.4645 - loss: 1.2996 - val_accuracy: 0.2500 - val_loss: 1.5428
# Epoch 39/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5412 - loss: 1.2320 - val_accuracy: 0.2500 - val_loss: 1.5406
# Epoch 40/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5162 - loss: 1.2494 - val_accuracy: 0.2500 - val_loss: 1.5405
# Epoch 41/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5078 - loss: 1.2427 - val_accuracy: 0.2500 - val_loss: 1.5400
# Epoch 42/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5012 - loss: 1.2042 - val_accuracy: 0.2500 - val_loss: 1.5370
# Epoch 43/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.4695 - loss: 1.2337 - val_accuracy: 0.2500 - val_loss: 1.5424
# Epoch 44/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.4578 - loss: 1.2582 - val_accuracy: 0.2500 - val_loss: 1.5436
# Epoch 45/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5078 - loss: 1.2135 - val_accuracy: 0.2500 - val_loss: 1.5411
# Epoch 46/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.4578 - loss: 1.2531 - val_accuracy: 0.2500 - val_loss: 1.5359
# Epoch 47/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.4662 - loss: 1.2149 - val_accuracy: 0.2500 - val_loss: 1.5372
# Epoch 48/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5368 - loss: 1.2529 - val_accuracy: 0.2500 - val_loss: 1.5340
# Epoch 49/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6018 - loss: 1.2120 - val_accuracy: 0.2500 - val_loss: 1.5366
# Epoch 50/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5185 - loss: 1.1922 - val_accuracy: 0.2500 - val_loss: 1.5320
# Epoch 51/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5268 - loss: 1.1914 - val_accuracy: 0.2917 - val_loss: 1.5342
# Epoch 52/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.4885 - loss: 1.2177 - val_accuracy: 0.2917 - val_loss: 1.5336
# Epoch 53/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.4601 - loss: 1.2065 - val_accuracy: 0.2917 - val_loss: 1.5340
# Epoch 54/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5201 - loss: 1.1469 - val_accuracy: 0.2917 - val_loss: 1.5272
# Epoch 55/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5118 - loss: 1.1767 - val_accuracy: 0.2917 - val_loss: 1.5257
# Epoch 56/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5668 - loss: 1.1550 - val_accuracy: 0.2917 - val_loss: 1.5255
# Epoch 57/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.4951 - loss: 1.1891 - val_accuracy: 0.2917 - val_loss: 1.5290
# Epoch 58/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.4985 - loss: 1.1586 - val_accuracy: 0.2917 - val_loss: 1.5313
# Epoch 59/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5535 - loss: 1.1158 - val_accuracy: 0.3333 - val_loss: 1.5256
# Epoch 60/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.4735 - loss: 1.2325 - val_accuracy: 0.3333 - val_loss: 1.5303
# Epoch 61/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.4585 - loss: 1.2066 - val_accuracy: 0.3333 - val_loss: 1.5355
# Epoch 62/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.4951 - loss: 1.1449 - val_accuracy: 0.2917 - val_loss: 1.5296
# Epoch 63/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5318 - loss: 1.1053 - val_accuracy: 0.3750 - val_loss: 1.5222
# Epoch 64/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.4908 - loss: 1.2053 - val_accuracy: 0.3750 - val_loss: 1.5270
# Epoch 65/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.4701 - loss: 1.1247 - val_accuracy: 0.3750 - val_loss: 1.5192
# Epoch 66/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5708 - loss: 1.0859 - val_accuracy: 0.3750 - val_loss: 1.5208
# Epoch 67/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.4758 - loss: 1.1238 - val_accuracy: 0.3750 - val_loss: 1.5258
# Epoch 68/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5608 - loss: 1.0802 - val_accuracy: 0.3750 - val_loss: 1.5254
# Epoch 69/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5191 - loss: 1.1159 - val_accuracy: 0.3750 - val_loss: 1.5258
# Epoch 70/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5458 - loss: 1.0699 - val_accuracy: 0.3750 - val_loss: 1.5277
# Epoch 71/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.4974 - loss: 1.0947 - val_accuracy: 0.3750 - val_loss: 1.5231
# Epoch 72/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5858 - loss: 1.0412 - val_accuracy: 0.3750 - val_loss: 1.5110
# Epoch 73/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5604 - loss: 1.1051 - val_accuracy: 0.4167 - val_loss: 1.5134
# Epoch 74/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5131 - loss: 1.0732 - val_accuracy: 0.3750 - val_loss: 1.5180
# Epoch 75/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5397 - loss: 1.1223 - val_accuracy: 0.3750 - val_loss: 1.5248
# Epoch 76/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5697 - loss: 1.0790 - val_accuracy: 0.3750 - val_loss: 1.5223
# Epoch 77/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6187 - loss: 1.0171 - val_accuracy: 0.3750 - val_loss: 1.5246
# Epoch 78/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5181 - loss: 1.0552 - val_accuracy: 0.4167 - val_loss: 1.5179
# Epoch 79/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5597 - loss: 1.0538 - val_accuracy: 0.4167 - val_loss: 1.5139
# Epoch 80/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5604 - loss: 1.0427 - val_accuracy: 0.4167 - val_loss: 1.5216
# Epoch 81/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5231 - loss: 1.1045 - val_accuracy: 0.4167 - val_loss: 1.5199
# Epoch 82/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5114 - loss: 1.0470 - val_accuracy: 0.4167 - val_loss: 1.5250
# Epoch 83/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5408 - loss: 1.0422 - val_accuracy: 0.4167 - val_loss: 1.5144
# Epoch 84/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5514 - loss: 1.0357 - val_accuracy: 0.4167 - val_loss: 1.5156
# Epoch 85/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5414 - loss: 1.0591 - val_accuracy: 0.4167 - val_loss: 1.5055
# Epoch 86/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5720 - loss: 1.0202 - val_accuracy: 0.4167 - val_loss: 1.5015
# Epoch 87/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5731 - loss: 1.0412 - val_accuracy: 0.4167 - val_loss: 1.4979
# Epoch 88/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5937 - loss: 0.9928 - val_accuracy: 0.4167 - val_loss: 1.4981
# Epoch 89/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5531 - loss: 1.0252 - val_accuracy: 0.4167 - val_loss: 1.5044
# Epoch 90/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5547 - loss: 1.0109 - val_accuracy: 0.4167 - val_loss: 1.4993
# Epoch 91/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5087 - loss: 1.0366 - val_accuracy: 0.4167 - val_loss: 1.4930
# Epoch 92/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5514 - loss: 0.9843 - val_accuracy: 0.4167 - val_loss: 1.4981
# Epoch 93/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5187 - loss: 1.0032 - val_accuracy: 0.4167 - val_loss: 1.4906
# Epoch 94/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5410 - loss: 1.0043 - val_accuracy: 0.4167 - val_loss: 1.4998
# Epoch 95/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5520 - loss: 0.9437 - val_accuracy: 0.4167 - val_loss: 1.5007
# Epoch 96/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5137 - loss: 0.9943 - val_accuracy: 0.4167 - val_loss: 1.5032
# Epoch 97/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.5220 - loss: 0.9845 - val_accuracy: 0.4167 - val_loss: 1.5106
# Epoch 98/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5720 - loss: 0.9443 - val_accuracy: 0.4167 - val_loss: 1.5019
# Epoch 99/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5554 - loss: 0.9310 - val_accuracy: 0.4167 - val_loss: 1.5003
# Epoch 100/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5227 - loss: 1.0073 - val_accuracy: 0.4167 - val_loss: 1.5025
# Epoch 101/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5460 - loss: 0.9834 - val_accuracy: 0.4167 - val_loss: 1.5078
# Epoch 102/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5837 - loss: 0.8899 - val_accuracy: 0.4167 - val_loss: 1.4864
# Epoch 103/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5454 - loss: 0.9375 - val_accuracy: 0.4167 - val_loss: 1.4836
# Epoch 104/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.5937 - loss: 0.8915 - val_accuracy: 0.4167 - val_loss: 1.4848
# Epoch 105/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6127 - loss: 0.9036 - val_accuracy: 0.4167 - val_loss: 1.5019
# Epoch 106/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5883 - loss: 0.9107 - val_accuracy: 0.4167 - val_loss: 1.4943
# Epoch 107/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6243 - loss: 0.8504 - val_accuracy: 0.4167 - val_loss: 1.4946
# Epoch 108/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5933 - loss: 0.9250 - val_accuracy: 0.4167 - val_loss: 1.4875
# Epoch 109/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6406 - loss: 0.8431 - val_accuracy: 0.4167 - val_loss: 1.4744
# Epoch 110/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6483 - loss: 0.8160 - val_accuracy: 0.4167 - val_loss: 1.4717
# Epoch 111/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6089 - loss: 0.8946 - val_accuracy: 0.4167 - val_loss: 1.4774
# Epoch 112/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6083 - loss: 0.9048 - val_accuracy: 0.4167 - val_loss: 1.4858
# Epoch 113/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5316 - loss: 0.8919 - val_accuracy: 0.4167 - val_loss: 1.4864
# Epoch 114/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6606 - loss: 0.8342 - val_accuracy: 0.4167 - val_loss: 1.4785
# Epoch 115/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5789 - loss: 0.8530 - val_accuracy: 0.4167 - val_loss: 1.4873
# Epoch 116/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5989 - loss: 0.8482 - val_accuracy: 0.4167 - val_loss: 1.4843
# Epoch 117/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5739 - loss: 0.9041 - val_accuracy: 0.4583 - val_loss: 1.4801
# Epoch 118/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6419 - loss: 0.8617 - val_accuracy: 0.4583 - val_loss: 1.4806
# Epoch 119/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5792 - loss: 0.8819 - val_accuracy: 0.4583 - val_loss: 1.4825
# Epoch 120/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6688 - loss: 0.8444 - val_accuracy: 0.4583 - val_loss: 1.5077
# Epoch 121/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5635 - loss: 0.8860 - val_accuracy: 0.4583 - val_loss: 1.4967
# Epoch 122/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6831 - loss: 0.8059 - val_accuracy: 0.4583 - val_loss: 1.4966
# Epoch 123/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6592 - loss: 0.8242 - val_accuracy: 0.5000 - val_loss: 1.4685
# Epoch 124/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7221 - loss: 0.7985 - val_accuracy: 0.5000 - val_loss: 1.4917
# Epoch 125/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6631 - loss: 0.7987 - val_accuracy: 0.5417 - val_loss: 1.4829
# Epoch 126/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6431 - loss: 0.7949 - val_accuracy: 0.5417 - val_loss: 1.4891
# Epoch 127/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6481 - loss: 0.8062 - val_accuracy: 0.5417 - val_loss: 1.4788
# Epoch 128/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.6315 - loss: 0.8046 - val_accuracy: 0.5417 - val_loss: 1.4636
# Epoch 129/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6631 - loss: 0.7990 - val_accuracy: 0.5417 - val_loss: 1.4683
# Epoch 130/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6594 - loss: 0.8311 - val_accuracy: 0.5417 - val_loss: 1.4897
# Epoch 131/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6881 - loss: 0.7682 - val_accuracy: 0.5417 - val_loss: 1.4817
# Epoch 132/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6677 - loss: 0.7834 - val_accuracy: 0.5417 - val_loss: 1.4955
# Epoch 133/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6944 - loss: 0.8011 - val_accuracy: 0.5417 - val_loss: 1.5094
# Epoch 134/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6844 - loss: 0.7482 - val_accuracy: 0.5417 - val_loss: 1.4841
# Epoch 135/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6550 - loss: 0.7750 - val_accuracy: 0.5417 - val_loss: 1.4790
# Epoch 136/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6711 - loss: 0.7787 - val_accuracy: 0.5417 - val_loss: 1.4969
# Epoch 137/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7284 - loss: 0.7332 - val_accuracy: 0.5417 - val_loss: 1.4953
# Epoch 138/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6984 - loss: 0.8010 - val_accuracy: 0.5417 - val_loss: 1.4981
# Epoch 139/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7284 - loss: 0.7309 - val_accuracy: 0.5417 - val_loss: 1.4716
# Epoch 140/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7530 - loss: 0.6873 - val_accuracy: 0.5417 - val_loss: 1.5048
# Epoch 141/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7213 - loss: 0.7656 - val_accuracy: 0.5417 - val_loss: 1.5228
# Epoch 142/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7540 - loss: 0.7490 - val_accuracy: 0.5417 - val_loss: 1.5464
# Epoch 143/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6880 - loss: 0.7355 - val_accuracy: 0.5417 - val_loss: 1.5113
# Epoch 144/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.7696 - loss: 0.7187 - val_accuracy: 0.5417 - val_loss: 1.4790
# Epoch 145/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7453 - loss: 0.7398 - val_accuracy: 0.5417 - val_loss: 1.4905
# Epoch 146/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7463 - loss: 0.7000 - val_accuracy: 0.5417 - val_loss: 1.5007
# Epoch 147/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7353 - loss: 0.7689 - val_accuracy: 0.5417 - val_loss: 1.5011
# Epoch 148/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7030 - loss: 0.7403 - val_accuracy: 0.5417 - val_loss: 1.5392
# Epoch 149/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7136 - loss: 0.7201 - val_accuracy: 0.5417 - val_loss: 1.5342
# Epoch 150/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7886 - loss: 0.6680 - val_accuracy: 0.5417 - val_loss: 1.5296
# Epoch 151/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7226 - loss: 0.7375 - val_accuracy: 0.5417 - val_loss: 1.5244
# Epoch 152/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7459 - loss: 0.7153 - val_accuracy: 0.5417 - val_loss: 1.5384
# Epoch 153/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7876 - loss: 0.6618 - val_accuracy: 0.5417 - val_loss: 1.5490
# Epoch 154/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7642 - loss: 0.6525 - val_accuracy: 0.5417 - val_loss: 1.5336
# Epoch 155/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7876 - loss: 0.6449 - val_accuracy: 0.5417 - val_loss: 1.5458
# Epoch 156/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7492 - loss: 0.6760 - val_accuracy: 0.5417 - val_loss: 1.5492
# Epoch 157/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7626 - loss: 0.6830 - val_accuracy: 0.5417 - val_loss: 1.5229
# Epoch 158/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7876 - loss: 0.6399 - val_accuracy: 0.5417 - val_loss: 1.5444
# Epoch 159/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8015 - loss: 0.6530 - val_accuracy: 0.5417 - val_loss: 1.5308
# Epoch 160/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8009 - loss: 0.6226 - val_accuracy: 0.5417 - val_loss: 1.5550
# Epoch 161/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7865 - loss: 0.6415 - val_accuracy: 0.5417 - val_loss: 1.5491
# Epoch 162/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7982 - loss: 0.6359 - val_accuracy: 0.5417 - val_loss: 1.5494
# Epoch 163/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7915 - loss: 0.5974 - val_accuracy: 0.5417 - val_loss: 1.5406
# Epoch 164/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7865 - loss: 0.6379 - val_accuracy: 0.5417 - val_loss: 1.5219
# Epoch 165/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7842 - loss: 0.6149 - val_accuracy: 0.5417 - val_loss: 1.5290
# Epoch 166/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7492 - loss: 0.6353 - val_accuracy: 0.5417 - val_loss: 1.5777
# Epoch 167/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7759 - loss: 0.6135 - val_accuracy: 0.5417 - val_loss: 1.5549
# Epoch 168/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7636 - loss: 0.6208 - val_accuracy: 0.5417 - val_loss: 1.5671
# Epoch 169/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7303 - loss: 0.6406 - val_accuracy: 0.5417 - val_loss: 1.5878
# Epoch 170/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7636 - loss: 0.6196 - val_accuracy: 0.5417 - val_loss: 1.6018
# Epoch 171/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7653 - loss: 0.5937 - val_accuracy: 0.5417 - val_loss: 1.6088
# Epoch 172/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.7253 - loss: 0.6129 - val_accuracy: 0.5417 - val_loss: 1.6242
# Epoch 173/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7636 - loss: 0.5895 - val_accuracy: 0.5417 - val_loss: 1.6436
# Epoch 174/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7353 - loss: 0.6018 - val_accuracy: 0.5417 - val_loss: 1.6228
# Epoch 175/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7536 - loss: 0.6036 - val_accuracy: 0.5417 - val_loss: 1.6429
# Epoch 176/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7603 - loss: 0.5740 - val_accuracy: 0.5417 - val_loss: 1.6093
# Epoch 177/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7569 - loss: 0.6248 - val_accuracy: 0.5417 - val_loss: 1.6408
# Epoch 178/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6886 - loss: 0.6140 - val_accuracy: 0.5417 - val_loss: 1.6346
# Epoch 179/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7203 - loss: 0.5789 - val_accuracy: 0.5417 - val_loss: 1.6093
# Epoch 180/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7269 - loss: 0.6154 - val_accuracy: 0.5417 - val_loss: 1.6221
# Epoch 181/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7536 - loss: 0.5636 - val_accuracy: 0.5417 - val_loss: 1.6232
# Epoch 182/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7392 - loss: 0.6057 - val_accuracy: 0.5417 - val_loss: 1.6709
# Epoch 183/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7226 - loss: 0.6051 - val_accuracy: 0.5417 - val_loss: 1.7136
# Epoch 184/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7992 - loss: 0.5394 - val_accuracy: 0.5417 - val_loss: 1.7067
# Epoch 185/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7999 - loss: 0.5590 - val_accuracy: 0.5417 - val_loss: 1.6634
# Epoch 186/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7609 - loss: 0.5522 - val_accuracy: 0.5417 - val_loss: 1.6428
# Epoch 187/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7619 - loss: 0.5351 - val_accuracy: 0.5417 - val_loss: 1.6500
# Epoch 188/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7726 - loss: 0.5462 - val_accuracy: 0.5417 - val_loss: 1.6124
# Epoch 189/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7792 - loss: 0.5679 - val_accuracy: 0.5417 - val_loss: 1.7107
# Epoch 190/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7782 - loss: 0.5415 - val_accuracy: 0.5417 - val_loss: 1.6844
# Epoch 191/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7603 - loss: 0.5273 - val_accuracy: 0.5833 - val_loss: 1.7488
# Epoch 192/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8205 - loss: 0.5166 - val_accuracy: 0.5417 - val_loss: 1.7463
# Epoch 193/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7949 - loss: 0.5121 - val_accuracy: 0.5417 - val_loss: 1.7272
# Epoch 194/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7299 - loss: 0.5578 - val_accuracy: 0.5417 - val_loss: 1.7823
# Epoch 195/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7572 - loss: 0.5542 - val_accuracy: 0.5417 - val_loss: 1.7397
# Epoch 196/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7432 - loss: 0.5479 - val_accuracy: 0.5417 - val_loss: 1.7469
# Epoch 197/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7582 - loss: 0.5455 - val_accuracy: 0.5417 - val_loss: 1.7581
# Epoch 198/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8032 - loss: 0.4802 - val_accuracy: 0.5417 - val_loss: 1.7829
# Epoch 199/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7365 - loss: 0.5524 - val_accuracy: 0.5417 - val_loss: 1.7822
# Epoch 200/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7649 - loss: 0.5013 - val_accuracy: 0.5417 - val_loss: 1.7555
# Epoch 201/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7682 - loss: 0.5054 - val_accuracy: 0.5417 - val_loss: 1.7848
# Epoch 202/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7932 - loss: 0.5047 - val_accuracy: 0.5417 - val_loss: 1.7665
# Epoch 203/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7999 - loss: 0.4880 - val_accuracy: 0.5833 - val_loss: 1.7890
# Epoch 204/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7432 - loss: 0.5294 - val_accuracy: 0.5833 - val_loss: 1.8481
# Epoch 205/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8238 - loss: 0.4718 - val_accuracy: 0.5833 - val_loss: 1.7947
# Epoch 206/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7772 - loss: 0.4956 - val_accuracy: 0.5833 - val_loss: 1.7783
# Epoch 207/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7988 - loss: 0.4821 - val_accuracy: 0.5417 - val_loss: 1.8188
# Epoch 208/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7788 - loss: 0.5056 - val_accuracy: 0.5417 - val_loss: 1.8977
# Epoch 209/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8032 - loss: 0.4794 - val_accuracy: 0.5417 - val_loss: 1.8372
# Epoch 210/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7365 - loss: 0.5086 - val_accuracy: 0.5417 - val_loss: 1.9240
# Epoch 211/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7782 - loss: 0.4870 - val_accuracy: 0.5833 - val_loss: 1.8799
# Epoch 212/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7832 - loss: 0.4854 - val_accuracy: 0.5833 - val_loss: 1.9273
# Epoch 213/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7872 - loss: 0.4677 - val_accuracy: 0.5833 - val_loss: 1.8537
# Epoch 214/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8055 - loss: 0.4576 - val_accuracy: 0.5833 - val_loss: 1.8263
# Epoch 215/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8022 - loss: 0.4484 - val_accuracy: 0.5833 - val_loss: 1.9400
# Epoch 216/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8178 - loss: 0.4555 - val_accuracy: 0.5833 - val_loss: 1.9308
# Epoch 217/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7995 - loss: 0.4695 - val_accuracy: 0.5833 - val_loss: 1.9948
# Epoch 218/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8018 - loss: 0.4871 - val_accuracy: 0.5833 - val_loss: 1.9109
# Epoch 219/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7922 - loss: 0.4726 - val_accuracy: 0.5833 - val_loss: 1.9068
# Epoch 220/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7828 - loss: 0.4648 - val_accuracy: 0.5833 - val_loss: 1.9296
# Epoch 221/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8188 - loss: 0.4514 - val_accuracy: 0.5833 - val_loss: 1.9440
# Epoch 222/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8051 - loss: 0.4661 - val_accuracy: 0.5833 - val_loss: 1.9258
# Epoch 223/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8151 - loss: 0.4578 - val_accuracy: 0.5833 - val_loss: 1.9137
# Epoch 224/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8074 - loss: 0.4754 - val_accuracy: 0.5833 - val_loss: 1.9868
# Epoch 225/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8334 - loss: 0.4136 - val_accuracy: 0.5833 - val_loss: 1.9799
# Epoch 226/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7795 - loss: 0.4516 - val_accuracy: 0.5833 - val_loss: 2.0195
# Epoch 227/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7961 - loss: 0.4403 - val_accuracy: 0.5833 - val_loss: 1.9999
# Epoch 228/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8268 - loss: 0.4461 - val_accuracy: 0.5833 - val_loss: 1.9829
# Epoch 229/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8607 - loss: 0.4314 - val_accuracy: 0.5833 - val_loss: 2.0652
# Epoch 230/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8068 - loss: 0.4318 - val_accuracy: 0.5833 - val_loss: 2.0714
# Epoch 231/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8601 - loss: 0.4133 - val_accuracy: 0.5833 - val_loss: 2.0274
# Epoch 232/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8107 - loss: 0.4433 - val_accuracy: 0.5833 - val_loss: 2.1298
# Epoch 233/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7534 - loss: 0.4697 - val_accuracy: 0.5833 - val_loss: 2.0463
# Epoch 234/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7918 - loss: 0.4312 - val_accuracy: 0.5833 - val_loss: 2.1150
# Epoch 235/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8051 - loss: 0.4239 - val_accuracy: 0.5833 - val_loss: 2.0356
# Epoch 236/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8001 - loss: 0.4373 - val_accuracy: 0.5833 - val_loss: 2.0672
# Epoch 237/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8124 - loss: 0.4356 - val_accuracy: 0.5833 - val_loss: 2.0835
# Epoch 238/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8328 - loss: 0.4156 - val_accuracy: 0.5833 - val_loss: 2.0982
# Epoch 239/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8351 - loss: 0.4156 - val_accuracy: 0.5833 - val_loss: 2.1022
# Epoch 240/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8580 - loss: 0.4109 - val_accuracy: 0.5833 - val_loss: 2.1415
# Epoch 241/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8347 - loss: 0.4370 - val_accuracy: 0.5833 - val_loss: 2.1560
# Epoch 242/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8564 - loss: 0.3897 - val_accuracy: 0.5833 - val_loss: 2.2301
# Epoch 243/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7718 - loss: 0.4348 - val_accuracy: 0.5833 - val_loss: 2.1967
# Epoch 244/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.8168 - loss: 0.4037 - val_accuracy: 0.5833 - val_loss: 2.1794
# Epoch 245/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8807 - loss: 0.3885 - val_accuracy: 0.5000 - val_loss: 2.1482
# Epoch 246/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8780 - loss: 0.3967 - val_accuracy: 0.5000 - val_loss: 2.1969
# Epoch 247/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8470 - loss: 0.4060 - val_accuracy: 0.5833 - val_loss: 2.2181
# Epoch 248/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8197 - loss: 0.3925 - val_accuracy: 0.5833 - val_loss: 2.2790
# Epoch 249/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8007 - loss: 0.4131 - val_accuracy: 0.5833 - val_loss: 2.2445
# Epoch 250/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8291 - loss: 0.3655 - val_accuracy: 0.5833 - val_loss: 2.2148
# Epoch 251/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7857 - loss: 0.4282 - val_accuracy: 0.5833 - val_loss: 2.2843
# Epoch 252/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8391 - loss: 0.3800 - val_accuracy: 0.5833 - val_loss: 2.3482
# Epoch 253/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8324 - loss: 0.4109 - val_accuracy: 0.5417 - val_loss: 2.3255
# Epoch 254/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8530 - loss: 0.3742 - val_accuracy: 0.5417 - val_loss: 2.3026
# Epoch 255/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8214 - loss: 0.3768 - val_accuracy: 0.5000 - val_loss: 2.2833
# Epoch 256/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8760 - loss: 0.3645 - val_accuracy: 0.5833 - val_loss: 2.2702
# Epoch 257/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8197 - loss: 0.3894 - val_accuracy: 0.5833 - val_loss: 2.2933
# Epoch 258/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8324 - loss: 0.3828 - val_accuracy: 0.5417 - val_loss: 2.3451
# Epoch 259/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8603 - loss: 0.3633 - val_accuracy: 0.5417 - val_loss: 2.3898
# Epoch 260/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8497 - loss: 0.3620 - val_accuracy: 0.5000 - val_loss: 2.2830
# Epoch 261/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8676 - loss: 0.3571 - val_accuracy: 0.5417 - val_loss: 2.3093
# Epoch 262/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8414 - loss: 0.3665 - val_accuracy: 0.5833 - val_loss: 2.3731
# Epoch 263/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8564 - loss: 0.3628 - val_accuracy: 0.5833 - val_loss: 2.3790
# Epoch 264/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8547 - loss: 0.3825 - val_accuracy: 0.5833 - val_loss: 2.4183
# Epoch 265/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8364 - loss: 0.3714 - val_accuracy: 0.5417 - val_loss: 2.4710
# Epoch 266/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8307 - loss: 0.3654 - val_accuracy: 0.5417 - val_loss: 2.4488
# Epoch 267/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8530 - loss: 0.3342 - val_accuracy: 0.5833 - val_loss: 2.3990
# Epoch 268/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8747 - loss: 0.3312 - val_accuracy: 0.5000 - val_loss: 2.4328
# Epoch 269/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8364 - loss: 0.3627 - val_accuracy: 0.5000 - val_loss: 2.4657
# Epoch 270/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8680 - loss: 0.3450 - val_accuracy: 0.4583 - val_loss: 2.5321
# Epoch 271/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8783 - loss: 0.3557 - val_accuracy: 0.5417 - val_loss: 2.4875
# Epoch 272/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8730 - loss: 0.3277 - val_accuracy: 0.5000 - val_loss: 2.4778
# Epoch 273/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8833 - loss: 0.3405 - val_accuracy: 0.5000 - val_loss: 2.5048
# Epoch 274/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8397 - loss: 0.3338 - val_accuracy: 0.5417 - val_loss: 2.5379
# Epoch 275/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8630 - loss: 0.3470 - val_accuracy: 0.5417 - val_loss: 2.5873
# Epoch 276/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8537 - loss: 0.3336 - val_accuracy: 0.5417 - val_loss: 2.5766
# Epoch 277/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8370 - loss: 0.3621 - val_accuracy: 0.5417 - val_loss: 2.5932
# Epoch 278/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.8803 - loss: 0.3216 - val_accuracy: 0.4583 - val_loss: 2.6022
# Epoch 279/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8876 - loss: 0.3254 - val_accuracy: 0.5417 - val_loss: 2.5607
# Epoch 280/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8737 - loss: 0.3162 - val_accuracy: 0.5417 - val_loss: 2.6447
# Epoch 281/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9047 - loss: 0.2797 - val_accuracy: 0.5417 - val_loss: 2.6424
# Epoch 282/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8860 - loss: 0.3172 - val_accuracy: 0.5417 - val_loss: 2.6097
# Epoch 283/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8437 - loss: 0.3125 - val_accuracy: 0.5417 - val_loss: 2.6527
# Epoch 284/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8887 - loss: 0.3112 - val_accuracy: 0.5417 - val_loss: 2.6663
# Epoch 285/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8676 - loss: 0.3166 - val_accuracy: 0.5417 - val_loss: 2.7177
# Epoch 286/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8226 - loss: 0.3377 - val_accuracy: 0.5417 - val_loss: 2.7399
# Epoch 287/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8570 - loss: 0.3175 - val_accuracy: 0.5000 - val_loss: 2.7008
# Epoch 288/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9037 - loss: 0.3023 - val_accuracy: 0.5000 - val_loss: 2.7361
# Epoch 289/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8922 - loss: 0.3099 - val_accuracy: 0.4583 - val_loss: 2.6924
# Epoch 290/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8787 - loss: 0.2885 - val_accuracy: 0.4583 - val_loss: 2.7095
# Epoch 291/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8660 - loss: 0.3132 - val_accuracy: 0.4583 - val_loss: 2.7397
# Epoch 292/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8560 - loss: 0.3330 - val_accuracy: 0.4583 - val_loss: 2.7532
# Epoch 293/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8976 - loss: 0.3163 - val_accuracy: 0.5000 - val_loss: 2.8270
# Epoch 294/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9256 - loss: 0.3018 - val_accuracy: 0.4583 - val_loss: 2.8434
# Epoch 295/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9145 - loss: 0.2672 - val_accuracy: 0.5417 - val_loss: 2.8203
# Epoch 296/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8453 - loss: 0.3132 - val_accuracy: 0.5417 - val_loss: 2.8158
# Epoch 297/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8476 - loss: 0.3147 - val_accuracy: 0.4583 - val_loss: 2.8670
# Epoch 298/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8976 - loss: 0.2971 - val_accuracy: 0.5000 - val_loss: 2.8260
# Epoch 299/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9043 - loss: 0.2783 - val_accuracy: 0.4583 - val_loss: 2.8532
# Epoch 300/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8906 - loss: 0.3027 - val_accuracy: 0.4583 - val_loss: 2.8206

# %% [markdown]
# In the hidden layers we used ReLU activation because it helps introduce non-linearity while mitigating issues like the vanishing gradient, making it effective for deeper networks
# The softmax activation in the last layer converts the raw outputs into probabilities that sum to 1, which is ideal for multi-class classification tasks where each neuron corresponds to a class

# %% [markdown]
# Training for 300 epochs can be a reasonable starting point, but whether it's ideal depends on the model's learning curves.
# If the validation loss has plateaued or starts increasing, training for more epochs may lead to overfitting.
# It's important to monitor both training and validation loss and accuracy to decide if additional epochs are beneficial.

# %%
# Fit the model and capture the training history
history = keras_model.fit(preprocessor(X_train), y_train_ohe,
                           batch_size=20,
                           epochs=300,
                           validation_split=0.25,
                           verbose=0)  # Set verbose=0 to reduce output during training

# Plot training and validation curves
plt.figure(figsize=(12, 5))

# Plot Loss Curves
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title("Loss Curves")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()

# Plot Accuracy Curves
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title("Accuracy Curves")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()

plt.tight_layout()
plt.show()

# %%
#-- Generate predicted y values

# Predict probabilities for each class on the preprocessed test set
pred_probabilities = keras_model.predict(preprocessor(X_test))

#Note: Keras predict returns the predicted column index location for classification models
# Predict
prediction_column_index= np.argmax(pred_probabilities, axis=-1)

# Assuming y_train is a Pandas Series, convert it to a categorical type to extract class labels.
class_labels = y_train.astype('category').cat.categories

# extract correct prediction labels
prediction_labels = [class_labels[i] for i in prediction_column_index]

# Convert y_test to categorical labels for evaluation.
true_labels = y_test.astype('category')

## model performance by comparing prediction_labels with true labels
print("Accuracy:", accuracy_score(true_labels, prediction_labels))
print("\nClassification Report:")
print(classification_report(true_labels, prediction_labels))
print("Confusion Matrix:")
print(confusion_matrix(true_labels, prediction_labels))
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Accuracy: 0.5714285714285714
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Average       0.67      0.50      0.57         8
#         High       0.50      0.75      0.60         8
#          Low       0.33      0.38      0.35         8
#    Very High       0.78      0.78      0.78         9
#     Very Low       0.67      0.44      0.53         9
#
#     accuracy                           0.57        42
#    macro avg       0.59      0.57      0.57        42
# weighted avg       0.60      0.57      0.57        42
#
# Confusion Matrix:
# [[4 3 1 0 0]
#  [0 6 0 2 0]
#  [2 1 3 0 2]
#  [0 2 0 7 0]
#  [0 0 5 0 4]]

# %%
# Implement regularization techniques such as Dropout and Batch Normalization to improve model generalization and observe change in performance.

import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, BatchNormalization
from keras.utils import to_categorical
import matplotlib.pyplot as plt
# Count features in input data
feature_count = preprocessor(X_train).shape[1]

# Define the regularized Neural Network Model with Dropout and Batch Normalization
model_reg = Sequential()
# First hidden layer
model_reg.add(Dense(128, input_dim=feature_count, activation='relu'))
model_reg.add(BatchNormalization())
model_reg.add(Dropout(0.3))  # Dropout with 30% rate

# Second hidden layer
model_reg.add(Dense(64, activation='relu'))
model_reg.add(BatchNormalization())
model_reg.add(Dropout(0.3))

# Third hidden layer
model_reg.add(Dense(64, activation='relu'))
model_reg.add(BatchNormalization())
model_reg.add(Dropout(0.3))

# Fourth hidden layer
model_reg.add(Dense(32, activation='relu'))
model_reg.add(BatchNormalization())
model_reg.add(Dropout(0.3))

# Output layer: 5 neurons for 5 classes using softmax activation
model_reg.add(Dense(5, activation='softmax'))

# Compile the model using categorical crossentropy and Adam optimizer
model_reg.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Convert y_train to one-hot encoding for Keras
y_train_labels = y_train.astype('category').cat.codes
y_train_ohe = to_categorical(y_train_labels, num_classes=5)

# Fit the model and capture the training history
history_reg = model_reg.fit(preprocessor(X_train), y_train_ohe,
                            batch_size=20,
                            epochs=300,
                            validation_split=0.25,
                            verbose=1)
# Out:
# Epoch 1/300
# /opt/anaconda3/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.1885 - loss: 2.5004 - val_accuracy: 0.2917 - val_loss: 1.6084
# Epoch 2/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.1966 - loss: 2.4230 - val_accuracy: 0.3333 - val_loss: 1.6011
# Epoch 3/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.2587 - loss: 1.9523 - val_accuracy: 0.3750 - val_loss: 1.5911
# Epoch 4/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.2191 - loss: 2.2108 - val_accuracy: 0.4583 - val_loss: 1.5778
# Epoch 5/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.2627 - loss: 2.0021 - val_accuracy: 0.5833 - val_loss: 1.5648
# Epoch 6/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.4361 - loss: 1.6449 - val_accuracy: 0.5417 - val_loss: 1.5491
# Epoch 7/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.3502 - loss: 1.6156 - val_accuracy: 0.5417 - val_loss: 1.5368
# Epoch 8/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.4313 - loss: 1.5731 - val_accuracy: 0.5417 - val_loss: 1.5229
# Epoch 9/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.3269 - loss: 1.5131 - val_accuracy: 0.4583 - val_loss: 1.5126
# Epoch 10/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.4011 - loss: 1.3812 - val_accuracy: 0.4583 - val_loss: 1.5012
# Epoch 11/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.3788 - loss: 1.5635 - val_accuracy: 0.5000 - val_loss: 1.4880
# Epoch 12/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5268 - loss: 1.0918 - val_accuracy: 0.5000 - val_loss: 1.4769
# Epoch 13/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.3002 - loss: 1.4743 - val_accuracy: 0.5000 - val_loss: 1.4689
# Epoch 14/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5201 - loss: 1.2868 - val_accuracy: 0.5000 - val_loss: 1.4614
# Epoch 15/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.4069 - loss: 1.5350 - val_accuracy: 0.5000 - val_loss: 1.4539
# Epoch 16/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.3448 - loss: 1.7279 - val_accuracy: 0.4583 - val_loss: 1.4479
# Epoch 17/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.4250 - loss: 1.2618 - val_accuracy: 0.4583 - val_loss: 1.4433
# Epoch 18/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5547 - loss: 1.0774 - val_accuracy: 0.4583 - val_loss: 1.4394
# Epoch 19/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5481 - loss: 1.0380 - val_accuracy: 0.4167 - val_loss: 1.4380
# Epoch 20/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5437 - loss: 1.0426 - val_accuracy: 0.4167 - val_loss: 1.4377
# Epoch 21/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.4465 - loss: 1.3690 - val_accuracy: 0.3750 - val_loss: 1.4392
# Epoch 22/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.4882 - loss: 1.3402 - val_accuracy: 0.3750 - val_loss: 1.4425
# Epoch 23/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5760 - loss: 1.0759 - val_accuracy: 0.3750 - val_loss: 1.4459
# Epoch 24/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6798 - loss: 1.0325 - val_accuracy: 0.3750 - val_loss: 1.4472
# Epoch 25/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5637 - loss: 1.2756 - val_accuracy: 0.3750 - val_loss: 1.4466
# Epoch 26/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.4978 - loss: 1.1314 - val_accuracy: 0.3750 - val_loss: 1.4496
# Epoch 27/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6775 - loss: 1.0841 - val_accuracy: 0.3750 - val_loss: 1.4534
# Epoch 28/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5777 - loss: 1.0692 - val_accuracy: 0.3750 - val_loss: 1.4512
# Epoch 29/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6262 - loss: 0.9754 - val_accuracy: 0.3750 - val_loss: 1.4518
# Epoch 30/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.6108 - loss: 0.8914 - val_accuracy: 0.3750 - val_loss: 1.4524
# Epoch 31/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5370 - loss: 1.0246 - val_accuracy: 0.3750 - val_loss: 1.4510
# Epoch 32/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5727 - loss: 0.9850 - val_accuracy: 0.3750 - val_loss: 1.4500
# Epoch 33/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6481 - loss: 1.0385 - val_accuracy: 0.4167 - val_loss: 1.4479
# Epoch 34/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6850 - loss: 0.8278 - val_accuracy: 0.4167 - val_loss: 1.4438
# Epoch 35/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6854 - loss: 0.7884 - val_accuracy: 0.3750 - val_loss: 1.4350
# Epoch 36/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5719 - loss: 1.1235 - val_accuracy: 0.3750 - val_loss: 1.4270
# Epoch 37/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.4399 - loss: 1.2052 - val_accuracy: 0.3750 - val_loss: 1.4178
# Epoch 38/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7013 - loss: 0.8778 - val_accuracy: 0.3750 - val_loss: 1.4087
# Epoch 39/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5731 - loss: 0.9602 - val_accuracy: 0.3750 - val_loss: 1.4066
# Epoch 40/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7163 - loss: 0.6852 - val_accuracy: 0.3750 - val_loss: 1.4186
# Epoch 41/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6354 - loss: 0.7950 - val_accuracy: 0.3750 - val_loss: 1.4309
# Epoch 42/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6831 - loss: 0.7224 - val_accuracy: 0.3750 - val_loss: 1.4379
# Epoch 43/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5177 - loss: 1.1901 - val_accuracy: 0.3750 - val_loss: 1.4368
# Epoch 44/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6289 - loss: 0.8731 - val_accuracy: 0.3750 - val_loss: 1.4345
# Epoch 45/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.7250 - loss: 0.7413 - val_accuracy: 0.3750 - val_loss: 1.4418
# Epoch 46/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5819 - loss: 0.8827 - val_accuracy: 0.3750 - val_loss: 1.4484
# Epoch 47/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8088 - loss: 0.6304 - val_accuracy: 0.3750 - val_loss: 1.4592
# Epoch 48/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6156 - loss: 0.7656 - val_accuracy: 0.3750 - val_loss: 1.4710
# Epoch 49/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6638 - loss: 0.7909 - val_accuracy: 0.3750 - val_loss: 1.4816
# Epoch 50/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6842 - loss: 0.8171 - val_accuracy: 0.3750 - val_loss: 1.4960
# Epoch 51/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6888 - loss: 0.8300 - val_accuracy: 0.3750 - val_loss: 1.5211
# Epoch 52/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6717 - loss: 0.7540 - val_accuracy: 0.3750 - val_loss: 1.5309
# Epoch 53/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6850 - loss: 0.8475 - val_accuracy: 0.3750 - val_loss: 1.5405
# Epoch 54/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5979 - loss: 0.9376 - val_accuracy: 0.3750 - val_loss: 1.5605
# Epoch 55/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7603 - loss: 0.7930 - val_accuracy: 0.3750 - val_loss: 1.5852
# Epoch 56/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7169 - loss: 0.6605 - val_accuracy: 0.3333 - val_loss: 1.5905
# Epoch 57/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7538 - loss: 0.6266 - val_accuracy: 0.3333 - val_loss: 1.5853
# Epoch 58/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7415 - loss: 0.6738 - val_accuracy: 0.3333 - val_loss: 1.5783
# Epoch 59/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7749 - loss: 0.7586 - val_accuracy: 0.3333 - val_loss: 1.5757
# Epoch 60/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8061 - loss: 0.5705 - val_accuracy: 0.3750 - val_loss: 1.5752
# Epoch 61/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7144 - loss: 0.8859 - val_accuracy: 0.3750 - val_loss: 1.5759
# Epoch 62/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7036 - loss: 0.7385 - val_accuracy: 0.3750 - val_loss: 1.5703
# Epoch 63/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6727 - loss: 0.7181 - val_accuracy: 0.3750 - val_loss: 1.5674
# Epoch 64/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8624 - loss: 0.5407 - val_accuracy: 0.4167 - val_loss: 1.5686
# Epoch 65/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7686 - loss: 0.6124 - val_accuracy: 0.4167 - val_loss: 1.5745
# Epoch 66/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8238 - loss: 0.6078 - val_accuracy: 0.4167 - val_loss: 1.5734
# Epoch 67/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.7755 - loss: 0.6292 - val_accuracy: 0.3750 - val_loss: 1.5759
# Epoch 68/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7459 - loss: 0.5329 - val_accuracy: 0.3750 - val_loss: 1.5781
# Epoch 69/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7150 - loss: 0.7153 - val_accuracy: 0.3750 - val_loss: 1.5793
# Epoch 70/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8474 - loss: 0.5604 - val_accuracy: 0.3750 - val_loss: 1.5854
# Epoch 71/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7788 - loss: 0.7197 - val_accuracy: 0.3750 - val_loss: 1.5948
# Epoch 72/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8457 - loss: 0.5199 - val_accuracy: 0.3750 - val_loss: 1.6036
# Epoch 73/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8324 - loss: 0.6548 - val_accuracy: 0.3750 - val_loss: 1.6058
# Epoch 74/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8983 - loss: 0.4629 - val_accuracy: 0.3750 - val_loss: 1.6110
# Epoch 75/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7888 - loss: 0.6277 - val_accuracy: 0.3750 - val_loss: 1.6255
# Epoch 76/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8430 - loss: 0.4268 - val_accuracy: 0.3750 - val_loss: 1.6341
# Epoch 77/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7915 - loss: 0.6089 - val_accuracy: 0.3750 - val_loss: 1.6495
# Epoch 78/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8497 - loss: 0.4309 - val_accuracy: 0.3333 - val_loss: 1.6734
# Epoch 79/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8138 - loss: 0.4831 - val_accuracy: 0.3333 - val_loss: 1.6969
# Epoch 80/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8011 - loss: 0.5412 - val_accuracy: 0.3333 - val_loss: 1.7221
# Epoch 81/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8370 - loss: 0.5051 - val_accuracy: 0.3333 - val_loss: 1.7398
# Epoch 82/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9095 - loss: 0.3694 - val_accuracy: 0.3750 - val_loss: 1.7566
# Epoch 83/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8845 - loss: 0.4234 - val_accuracy: 0.3750 - val_loss: 1.7738
# Epoch 84/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8630 - loss: 0.3919 - val_accuracy: 0.3750 - val_loss: 1.7933
# Epoch 85/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8576 - loss: 0.4058 - val_accuracy: 0.3750 - val_loss: 1.8065
# Epoch 86/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8230 - loss: 0.5468 - val_accuracy: 0.3333 - val_loss: 1.8225
# Epoch 87/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8153 - loss: 0.5147 - val_accuracy: 0.3333 - val_loss: 1.8403
# Epoch 88/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8726 - loss: 0.3813 - val_accuracy: 0.3333 - val_loss: 1.8449
# Epoch 89/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8810 - loss: 0.3736 - val_accuracy: 0.3333 - val_loss: 1.8661
# Epoch 90/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8856 - loss: 0.4308 - val_accuracy: 0.3333 - val_loss: 1.8888
# Epoch 91/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8380 - loss: 0.5216 - val_accuracy: 0.3333 - val_loss: 1.9141
# Epoch 92/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.8726 - loss: 0.3905 - val_accuracy: 0.2917 - val_loss: 1.9408
# Epoch 93/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8128 - loss: 0.4785 - val_accuracy: 0.2917 - val_loss: 1.9595
# Epoch 94/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8047 - loss: 0.6058 - val_accuracy: 0.2917 - val_loss: 1.9966
# Epoch 95/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8687 - loss: 0.3317 - val_accuracy: 0.3333 - val_loss: 2.0160
# Epoch 96/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8670 - loss: 0.4086 - val_accuracy: 0.3333 - val_loss: 2.0166
# Epoch 97/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9045 - loss: 0.3336 - val_accuracy: 0.3333 - val_loss: 2.0110
# Epoch 98/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8318 - loss: 0.4089 - val_accuracy: 0.3333 - val_loss: 2.0040
# Epoch 99/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8268 - loss: 0.4627 - val_accuracy: 0.3333 - val_loss: 2.0283
# Epoch 100/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8607 - loss: 0.4908 - val_accuracy: 0.3333 - val_loss: 2.0535
# Epoch 101/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9485 - loss: 0.3104 - val_accuracy: 0.3333 - val_loss: 2.0829
# Epoch 102/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9172 - loss: 0.3455 - val_accuracy: 0.3333 - val_loss: 2.0954
# Epoch 103/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9279 - loss: 0.2863 - val_accuracy: 0.3333 - val_loss: 2.0828
# Epoch 104/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9302 - loss: 0.2991 - val_accuracy: 0.3333 - val_loss: 2.0613
# Epoch 105/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8647 - loss: 0.3930 - val_accuracy: 0.3333 - val_loss: 2.0650
# Epoch 106/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9568 - loss: 0.2195 - val_accuracy: 0.3333 - val_loss: 2.0470
# Epoch 107/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7622 - loss: 0.6480 - val_accuracy: 0.3750 - val_loss: 2.0354
# Epoch 108/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8797 - loss: 0.3540 - val_accuracy: 0.3333 - val_loss: 2.0513
# Epoch 109/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8716 - loss: 0.3309 - val_accuracy: 0.3750 - val_loss: 2.0717
# Epoch 110/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9245 - loss: 0.3304 - val_accuracy: 0.3333 - val_loss: 2.0882
# Epoch 111/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9418 - loss: 0.2829 - val_accuracy: 0.3333 - val_loss: 2.1019
# Epoch 112/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8783 - loss: 0.3097 - val_accuracy: 0.3750 - val_loss: 2.0967
# Epoch 113/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7636 - loss: 0.4641 - val_accuracy: 0.3750 - val_loss: 2.0839
# Epoch 114/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9291 - loss: 0.2402 - val_accuracy: 0.3750 - val_loss: 2.0822
# Epoch 115/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8587 - loss: 0.3511 - val_accuracy: 0.3750 - val_loss: 2.0970
# Epoch 116/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9141 - loss: 0.2829 - val_accuracy: 0.3750 - val_loss: 2.1169
# Epoch 117/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9152 - loss: 0.3580 - val_accuracy: 0.3750 - val_loss: 2.1405
# Epoch 118/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9229 - loss: 0.2193 - val_accuracy: 0.3333 - val_loss: 2.1718
# Epoch 119/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8916 - loss: 0.3850 - val_accuracy: 0.3333 - val_loss: 2.1962
# Epoch 120/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9345 - loss: 0.2532 - val_accuracy: 0.2917 - val_loss: 2.2113
# Epoch 121/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.8910 - loss: 0.2723 - val_accuracy: 0.2917 - val_loss: 2.2276
# Epoch 122/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9156 - loss: 0.3096 - val_accuracy: 0.2917 - val_loss: 2.2371
# Epoch 123/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8526 - loss: 0.3635 - val_accuracy: 0.2917 - val_loss: 2.2596
# Epoch 124/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8826 - loss: 0.3731 - val_accuracy: 0.2917 - val_loss: 2.2869
# Epoch 125/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9704 - loss: 0.1659 - val_accuracy: 0.2917 - val_loss: 2.2977
# Epoch 126/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9279 - loss: 0.2228 - val_accuracy: 0.2917 - val_loss: 2.2897
# Epoch 127/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9341 - loss: 0.1830 - val_accuracy: 0.2917 - val_loss: 2.2774
# Epoch 128/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9372 - loss: 0.1942 - val_accuracy: 0.2917 - val_loss: 2.2683
# Epoch 129/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9139 - loss: 0.3762 - val_accuracy: 0.3333 - val_loss: 2.2658
# Epoch 130/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8760 - loss: 0.3795 - val_accuracy: 0.3333 - val_loss: 2.2496
# Epoch 131/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9162 - loss: 0.2975 - val_accuracy: 0.3333 - val_loss: 2.2535
# Epoch 132/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9418 - loss: 0.2494 - val_accuracy: 0.3333 - val_loss: 2.2541
# Epoch 133/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9418 - loss: 0.2848 - val_accuracy: 0.3333 - val_loss: 2.2635
# Epoch 134/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9083 - loss: 0.2732 - val_accuracy: 0.3333 - val_loss: 2.2621
# Epoch 135/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9145 - loss: 0.2805 - val_accuracy: 0.3333 - val_loss: 2.2574
# Epoch 136/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8653 - loss: 0.3509 - val_accuracy: 0.3333 - val_loss: 2.2744
# Epoch 137/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9704 - loss: 0.1555 - val_accuracy: 0.2917 - val_loss: 2.3029
# Epoch 138/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9322 - loss: 0.2751 - val_accuracy: 0.3333 - val_loss: 2.3420
# Epoch 139/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9602 - loss: 0.1765 - val_accuracy: 0.3333 - val_loss: 2.3725
# Epoch 140/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9658 - loss: 0.1843 - val_accuracy: 0.3333 - val_loss: 2.4104
# Epoch 141/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9475 - loss: 0.1920 - val_accuracy: 0.3333 - val_loss: 2.4531
# Epoch 142/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9614 - loss: 0.2260 - val_accuracy: 0.3333 - val_loss: 2.4786
# Epoch 143/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9441 - loss: 0.2112 - val_accuracy: 0.3333 - val_loss: 2.4848
# Epoch 144/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9222 - loss: 0.2511 - val_accuracy: 0.3333 - val_loss: 2.4930
# Epoch 145/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9235 - loss: 0.2751 - val_accuracy: 0.3333 - val_loss: 2.4945
# Epoch 146/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9531 - loss: 0.1604 - val_accuracy: 0.3333 - val_loss: 2.4970
# Epoch 147/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9262 - loss: 0.1960 - val_accuracy: 0.3750 - val_loss: 2.5090
# Epoch 148/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9385 - loss: 0.2824 - val_accuracy: 0.3750 - val_loss: 2.5202
# Epoch 149/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9614 - loss: 0.1665 - val_accuracy: 0.2917 - val_loss: 2.5340
# Epoch 150/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9714 - loss: 0.1405 - val_accuracy: 0.2917 - val_loss: 2.5495
# Epoch 151/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9541 - loss: 0.1742 - val_accuracy: 0.2917 - val_loss: 2.5606
# Epoch 152/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9381 - loss: 0.1214 - val_accuracy: 0.2917 - val_loss: 2.5612
# Epoch 153/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9168 - loss: 0.2688 - val_accuracy: 0.2917 - val_loss: 2.5667
# Epoch 154/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8676 - loss: 0.3326 - val_accuracy: 0.3333 - val_loss: 2.5763
# Epoch 155/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9281 - loss: 0.2338 - val_accuracy: 0.3333 - val_loss: 2.5949
# Epoch 156/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9302 - loss: 0.2851 - val_accuracy: 0.3333 - val_loss: 2.6030
# Epoch 157/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9558 - loss: 0.2749 - val_accuracy: 0.3333 - val_loss: 2.6078
# Epoch 158/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8939 - loss: 0.2038 - val_accuracy: 0.3333 - val_loss: 2.6285
# Epoch 159/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9621 - loss: 0.1490 - val_accuracy: 0.3333 - val_loss: 2.6584
# Epoch 160/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9731 - loss: 0.1295 - val_accuracy: 0.3333 - val_loss: 2.6759
# Epoch 161/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9860 - loss: 0.1305 - val_accuracy: 0.3333 - val_loss: 2.6867
# Epoch 162/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9591 - loss: 0.1499 - val_accuracy: 0.3333 - val_loss: 2.7092
# Epoch 163/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9475 - loss: 0.1771 - val_accuracy: 0.3333 - val_loss: 2.7416
# Epoch 164/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8906 - loss: 0.2717 - val_accuracy: 0.3333 - val_loss: 2.7836
# Epoch 165/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9212 - loss: 0.2770 - val_accuracy: 0.2917 - val_loss: 2.8126
# Epoch 166/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9860 - loss: 0.1394 - val_accuracy: 0.2917 - val_loss: 2.8333
# Epoch 167/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9714 - loss: 0.1320 - val_accuracy: 0.2917 - val_loss: 2.8544
# Epoch 168/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9631 - loss: 0.1562 - val_accuracy: 0.2500 - val_loss: 2.8565
# Epoch 169/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9821 - loss: 0.1647 - val_accuracy: 0.2500 - val_loss: 2.8569
# Epoch 170/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8902 - loss: 0.3843 - val_accuracy: 0.2917 - val_loss: 2.8695
# Epoch 171/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9860 - loss: 0.0946 - val_accuracy: 0.2500 - val_loss: 2.8808
# Epoch 172/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9648 - loss: 0.1471 - val_accuracy: 0.2500 - val_loss: 2.8815
# Epoch 173/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9521 - loss: 0.1225 - val_accuracy: 0.2500 - val_loss: 2.8659
# Epoch 174/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9564 - loss: 0.1428 - val_accuracy: 0.2500 - val_loss: 2.8590
# Epoch 175/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9385 - loss: 0.2102 - val_accuracy: 0.2917 - val_loss: 2.8643
# Epoch 176/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9658 - loss: 0.2135 - val_accuracy: 0.2917 - val_loss: 2.8860
# Epoch 177/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9664 - loss: 0.1773 - val_accuracy: 0.2917 - val_loss: 2.9091
# Epoch 178/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9485 - loss: 0.2227 - val_accuracy: 0.2917 - val_loss: 2.9188
# Epoch 179/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9435 - loss: 0.2171 - val_accuracy: 0.2917 - val_loss: 2.9434
# Epoch 180/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8526 - loss: 0.4666 - val_accuracy: 0.2917 - val_loss: 2.9369
# Epoch 181/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9112 - loss: 0.1850 - val_accuracy: 0.2917 - val_loss: 2.9233
# Epoch 182/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9581 - loss: 0.1962 - val_accuracy: 0.2917 - val_loss: 2.9044
# Epoch 183/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9860 - loss: 0.1284 - val_accuracy: 0.2500 - val_loss: 2.8879
# Epoch 184/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9352 - loss: 0.2816 - val_accuracy: 0.2500 - val_loss: 2.9027
# Epoch 185/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9464 - loss: 0.1224 - val_accuracy: 0.2500 - val_loss: 2.9136
# Epoch 186/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9731 - loss: 0.1481 - val_accuracy: 0.2500 - val_loss: 2.9054
# Epoch 187/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9391 - loss: 0.2257 - val_accuracy: 0.2500 - val_loss: 2.8968
# Epoch 188/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9079 - loss: 0.1599 - val_accuracy: 0.2500 - val_loss: 2.9177
# Epoch 189/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9760 - loss: 0.1363 - val_accuracy: 0.2500 - val_loss: 2.9529
# Epoch 190/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9502 - loss: 0.1338 - val_accuracy: 0.2500 - val_loss: 2.9832
# Epoch 191/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9704 - loss: 0.1279 - val_accuracy: 0.2500 - val_loss: 2.9956
# Epoch 192/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9621 - loss: 0.1113 - val_accuracy: 0.2500 - val_loss: 3.0129
# Epoch 193/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0912 - val_accuracy: 0.2500 - val_loss: 3.0300
# Epoch 194/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9235 - loss: 0.1789 - val_accuracy: 0.2500 - val_loss: 3.0368
# Epoch 195/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.0867 - val_accuracy: 0.2500 - val_loss: 3.0564
# Epoch 196/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9095 - loss: 0.1992 - val_accuracy: 0.2500 - val_loss: 3.0937
# Epoch 197/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9191 - loss: 0.1830 - val_accuracy: 0.2500 - val_loss: 3.1436
# Epoch 198/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9854 - loss: 0.1101 - val_accuracy: 0.2500 - val_loss: 3.1658
# Epoch 199/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9375 - loss: 0.1910 - val_accuracy: 0.2500 - val_loss: 3.1869
# Epoch 200/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9564 - loss: 0.1475 - val_accuracy: 0.2500 - val_loss: 3.1806
# Epoch 201/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9721 - loss: 0.1030 - val_accuracy: 0.2500 - val_loss: 3.1657
# Epoch 202/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9731 - loss: 0.0933 - val_accuracy: 0.2500 - val_loss: 3.1503
# Epoch 203/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9468 - loss: 0.1989 - val_accuracy: 0.2500 - val_loss: 3.1512
# Epoch 204/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9445 - loss: 0.2198 - val_accuracy: 0.2500 - val_loss: 3.1534
# Epoch 205/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9431 - loss: 0.2234 - val_accuracy: 0.2500 - val_loss: 3.1402
# Epoch 206/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9475 - loss: 0.1368 - val_accuracy: 0.2500 - val_loss: 3.1460
# Epoch 207/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.0807 - val_accuracy: 0.2083 - val_loss: 3.1483
# Epoch 208/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9521 - loss: 0.1177 - val_accuracy: 0.2083 - val_loss: 3.1460
# Epoch 209/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9564 - loss: 0.2773 - val_accuracy: 0.2083 - val_loss: 3.1719
# Epoch 210/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9418 - loss: 0.1663 - val_accuracy: 0.2083 - val_loss: 3.1818
# Epoch 211/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9910 - loss: 0.0524 - val_accuracy: 0.2083 - val_loss: 3.1808
# Epoch 212/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.0600 - val_accuracy: 0.2083 - val_loss: 3.1882
# Epoch 213/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9552 - loss: 0.1152 - val_accuracy: 0.2083 - val_loss: 3.1864
# Epoch 214/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9760 - loss: 0.1069 - val_accuracy: 0.2083 - val_loss: 3.1843
# Epoch 215/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.0497 - val_accuracy: 0.2083 - val_loss: 3.1824
# Epoch 216/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9910 - loss: 0.0769 - val_accuracy: 0.2083 - val_loss: 3.2024
# Epoch 217/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0705 - val_accuracy: 0.2083 - val_loss: 3.2271
# Epoch 218/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9721 - loss: 0.1113 - val_accuracy: 0.2083 - val_loss: 3.2532
# Epoch 219/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9681 - loss: 0.1116 - val_accuracy: 0.2083 - val_loss: 3.2857
# Epoch 220/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9910 - loss: 0.0677 - val_accuracy: 0.2083 - val_loss: 3.3158
# Epoch 221/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9285 - loss: 0.2378 - val_accuracy: 0.2083 - val_loss: 3.3053
# Epoch 222/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9944 - loss: 0.0500 - val_accuracy: 0.2083 - val_loss: 3.2628
# Epoch 223/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9860 - loss: 0.0744 - val_accuracy: 0.2083 - val_loss: 3.2271
# Epoch 224/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9760 - loss: 0.0753 - val_accuracy: 0.1667 - val_loss: 3.2033
# Epoch 225/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9564 - loss: 0.1453 - val_accuracy: 0.1667 - val_loss: 3.1865
# Epoch 226/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9760 - loss: 0.0638 - val_accuracy: 0.1667 - val_loss: 3.1796
# Epoch 227/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9452 - loss: 0.1616 - val_accuracy: 0.1667 - val_loss: 3.1669
# Epoch 228/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9535 - loss: 0.1328 - val_accuracy: 0.2083 - val_loss: 3.1504
# Epoch 229/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9760 - loss: 0.0734 - val_accuracy: 0.1667 - val_loss: 3.1468
# Epoch 230/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.0682 - val_accuracy: 0.1667 - val_loss: 3.1502
# Epoch 231/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9860 - loss: 0.0438 - val_accuracy: 0.1667 - val_loss: 3.1597
# Epoch 232/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9887 - loss: 0.0770 - val_accuracy: 0.2083 - val_loss: 3.1677
# Epoch 233/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9821 - loss: 0.0624 - val_accuracy: 0.2083 - val_loss: 3.1542
# Epoch 234/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9252 - loss: 0.2068 - val_accuracy: 0.2083 - val_loss: 3.1464
# Epoch 235/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0560 - val_accuracy: 0.2083 - val_loss: 3.1457
# Epoch 236/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9860 - loss: 0.0941 - val_accuracy: 0.2083 - val_loss: 3.1540
# Epoch 237/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9681 - loss: 0.1873 - val_accuracy: 0.2083 - val_loss: 3.1538
# Epoch 238/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0592 - val_accuracy: 0.2083 - val_loss: 3.1538
# Epoch 239/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9521 - loss: 0.0882 - val_accuracy: 0.2083 - val_loss: 3.1579
# Epoch 240/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9831 - loss: 0.0667 - val_accuracy: 0.2083 - val_loss: 3.1876
# Epoch 241/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0508 - val_accuracy: 0.2500 - val_loss: 3.2512
# Epoch 242/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9821 - loss: 0.1367 - val_accuracy: 0.2500 - val_loss: 3.2777
# Epoch 243/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9621 - loss: 0.0767 - val_accuracy: 0.2500 - val_loss: 3.2792
# Epoch 244/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9671 - loss: 0.0946 - val_accuracy: 0.2500 - val_loss: 3.2948
# Epoch 245/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.0447 - val_accuracy: 0.2917 - val_loss: 3.3057
# Epoch 246/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9721 - loss: 0.0814 - val_accuracy: 0.2917 - val_loss: 3.2930
# Epoch 247/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.0621 - val_accuracy: 0.2917 - val_loss: 3.2731
# Epoch 248/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9944 - loss: 0.0847 - val_accuracy: 0.2917 - val_loss: 3.2738
# Epoch 249/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0490 - val_accuracy: 0.2917 - val_loss: 3.2733
# Epoch 250/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9714 - loss: 0.0643 - val_accuracy: 0.2917 - val_loss: 3.2624
# Epoch 251/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9481 - loss: 0.1338 - val_accuracy: 0.2917 - val_loss: 3.2712
# Epoch 252/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9804 - loss: 0.1373 - val_accuracy: 0.2917 - val_loss: 3.2735
# Epoch 253/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9944 - loss: 0.0955 - val_accuracy: 0.2917 - val_loss: 3.2619
# Epoch 254/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 0.0777 - val_accuracy: 0.2917 - val_loss: 3.2654
# Epoch 255/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9860 - loss: 0.0883 - val_accuracy: 0.2500 - val_loss: 3.2756
# Epoch 256/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9910 - loss: 0.0702 - val_accuracy: 0.2500 - val_loss: 3.2836
# Epoch 257/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9804 - loss: 0.0969 - val_accuracy: 0.2500 - val_loss: 3.2928
# Epoch 258/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8912 - loss: 0.1791 - val_accuracy: 0.2500 - val_loss: 3.3113
# Epoch 259/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9764 - loss: 0.0719 - val_accuracy: 0.2500 - val_loss: 3.3342
# Epoch 260/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9591 - loss: 0.0866 - val_accuracy: 0.2917 - val_loss: 3.3876
# Epoch 261/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0654 - val_accuracy: 0.2917 - val_loss: 3.4182
# Epoch 262/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9429 - loss: 0.1858 - val_accuracy: 0.2917 - val_loss: 3.4462
# Epoch 263/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9512 - loss: 0.1996 - val_accuracy: 0.2917 - val_loss: 3.4480
# Epoch 264/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9631 - loss: 0.1066 - val_accuracy: 0.2917 - val_loss: 3.4227
# Epoch 265/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9771 - loss: 0.0980 - val_accuracy: 0.2917 - val_loss: 3.4149
# Epoch 266/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9944 - loss: 0.0906 - val_accuracy: 0.2917 - val_loss: 3.4306
# Epoch 267/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9760 - loss: 0.1202 - val_accuracy: 0.2917 - val_loss: 3.4125
# Epoch 268/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9495 - loss: 0.1677 - val_accuracy: 0.2500 - val_loss: 3.4171
# Epoch 269/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9804 - loss: 0.0914 - val_accuracy: 0.2500 - val_loss: 3.4076
# Epoch 270/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0550 - val_accuracy: 0.2500 - val_loss: 3.3916
# Epoch 271/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9564 - loss: 0.1378 - val_accuracy: 0.2500 - val_loss: 3.3994
# Epoch 272/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9944 - loss: 0.0577 - val_accuracy: 0.2917 - val_loss: 3.4225
# Epoch 273/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9944 - loss: 0.0751 - val_accuracy: 0.2917 - val_loss: 3.4152
# Epoch 274/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9508 - loss: 0.1098 - val_accuracy: 0.2917 - val_loss: 3.4573
# Epoch 275/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.0461 - val_accuracy: 0.2917 - val_loss: 3.4869
# Epoch 276/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9944 - loss: 0.0868 - val_accuracy: 0.2917 - val_loss: 3.5234
# Epoch 277/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9944 - loss: 0.0641 - val_accuracy: 0.2917 - val_loss: 3.5415
# Epoch 278/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9821 - loss: 0.0746 - val_accuracy: 0.2917 - val_loss: 3.5370
# Epoch 279/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9910 - loss: 0.0519 - val_accuracy: 0.2917 - val_loss: 3.5446
# Epoch 280/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9944 - loss: 0.0338 - val_accuracy: 0.2917 - val_loss: 3.5582
# Epoch 281/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9910 - loss: 0.0585 - val_accuracy: 0.2917 - val_loss: 3.5507
# Epoch 282/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9944 - loss: 0.0253 - val_accuracy: 0.2917 - val_loss: 3.5328
# Epoch 283/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0540 - val_accuracy: 0.2917 - val_loss: 3.5184
# Epoch 284/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9760 - loss: 0.0952 - val_accuracy: 0.2917 - val_loss: 3.5303
# Epoch 285/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0482 - val_accuracy: 0.2917 - val_loss: 3.5344
# Epoch 286/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9887 - loss: 0.0566 - val_accuracy: 0.2917 - val_loss: 3.5548
# Epoch 287/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9671 - loss: 0.1126 - val_accuracy: 0.2500 - val_loss: 3.5758
# Epoch 288/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9944 - loss: 0.0627 - val_accuracy: 0.2500 - val_loss: 3.5706
# Epoch 289/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9910 - loss: 0.0579 - val_accuracy: 0.2500 - val_loss: 3.5701
# Epoch 290/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9821 - loss: 0.0555 - val_accuracy: 0.2500 - val_loss: 3.5688
# Epoch 291/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9591 - loss: 0.1121 - val_accuracy: 0.2083 - val_loss: 3.5845
# Epoch 292/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9760 - loss: 0.0862 - val_accuracy: 0.2083 - val_loss: 3.6076
# Epoch 293/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9860 - loss: 0.0620 - val_accuracy: 0.2083 - val_loss: 3.6165
# Epoch 294/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9944 - loss: 0.0275 - val_accuracy: 0.2500 - val_loss: 3.6108
# Epoch 295/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9771 - loss: 0.0676 - val_accuracy: 0.2500 - val_loss: 3.6222
# Epoch 296/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9704 - loss: 0.0846 - val_accuracy: 0.2500 - val_loss: 3.6678
# Epoch 297/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0371 - val_accuracy: 0.2500 - val_loss: 3.7180
# Epoch 298/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.0265 - val_accuracy: 0.2500 - val_loss: 3.7484
# Epoch 299/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9910 - loss: 0.0369 - val_accuracy: 0.2083 - val_loss: 3.7588
# Epoch 300/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9831 - loss: 0.0568 - val_accuracy: 0.2500 - val_loss: 3.7527

# %%
# Fit the model and capture the training history in history_reg
history_reg = keras_model.fit(preprocessor(X_train), y_train_ohe,
                              batch_size=20,
                              epochs=300,
                              validation_split=0.25,
                              verbose=0)  # Set verbose=0 to reduce output during training

# Plot training and validation curves in two subplots
plt.figure(figsize=(12, 5))

# Plot Loss Curves
plt.subplot(1, 2, 1)
plt.plot(history_reg.history['loss'], label='Training Loss')
plt.plot(history_reg.history['val_loss'], label='Validation Loss')
plt.title("Loss Curves")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()

# Plot Accuracy Curves
plt.subplot(1, 2, 2)
plt.plot(history_reg.history['accuracy'], label='Training Accuracy')
plt.plot(history_reg.history['val_accuracy'], label='Validation Accuracy')
plt.title("Accuracy Curves")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# Neural Network Model without the regularization techniques includes a more detailed breakdown of accuracy values (e.g., 1.0, 0.9, 0.8, etc.), which might indicate specific performance metrics at certain epochs.
# The Neural Network Model with regularization techniques omits these specific values but provides a cleaner visualization of the overall trends.

# %%
# Experiment with different activation functions (ReLU, LeakyReLU, Tanh, Sigmoid) to observe their impact on model performance.

# Model using ReLU activation (baseline)
from keras.models import Sequential
from keras.layers import Dense
from keras.utils import to_categorical

# Count features in input data
feature_count = preprocessor(X_train).shape[1]

# Build the model
relu_model = Sequential()
relu_model.add(Dense(128, input_dim=feature_count, activation='relu'))
relu_model.add(Dense(64, activation='relu'))
relu_model.add(Dense(64, activation='relu'))
relu_model.add(Dense(32, activation='relu'))
relu_model.add(Dense(5, activation='softmax'))  # 5 neurons for 5 classes

# Compile the model
relu_model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Convert y_train to one-hot encoding
y_train_labels = y_train.astype('category').cat.codes
y_train_ohe = to_categorical(y_train_labels, num_classes=5)

# Train the model
history_relu = relu_model.fit(preprocessor(X_train), y_train_ohe,
                              batch_size=20,
                              epochs=300,
                              validation_split=0.25,
                              verbose=0)
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# Model using LeakyReLU activation
from keras.models import Sequential
from keras.layers import Dense, LeakyReLU

leaky_model = Sequential()
leaky_model.add(Dense(128, input_dim=feature_count))
leaky_model.add(LeakyReLU(alpha=0.1))
leaky_model.add(Dense(64))
leaky_model.add(LeakyReLU(alpha=0.1))
leaky_model.add(Dense(64))
leaky_model.add(LeakyReLU(alpha=0.1))
leaky_model.add(Dense(32))
leaky_model.add(LeakyReLU(alpha=0.1))
leaky_model.add(Dense(5, activation='softmax'))

leaky_model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

history_leaky = leaky_model.fit(preprocessor(X_train), y_train_ohe,
                                batch_size=20,
                                epochs=300,
                                validation_split=0.25,
                                verbose=0)
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /opt/anaconda3/lib/python3.12/site-packages/keras/src/layers/activations/leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(

# %%
# Model using Tanh activation
from keras.models import Sequential
from keras.layers import Dense

tanh_model = Sequential()
tanh_model.add(Dense(128, input_dim=feature_count, activation='tanh'))
tanh_model.add(Dense(64, activation='tanh'))
tanh_model.add(Dense(64, activation='tanh'))
tanh_model.add(Dense(32, activation='tanh'))
tanh_model.add(Dense(5, activation='softmax'))

tanh_model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

history_tanh = tanh_model.fit(preprocessor(X_train), y_train_ohe,
                              batch_size=20,
                              epochs=300,
                              validation_split=0.25,
                              verbose=0)
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# Model using Sigmoid activation
from keras.models import Sequential
from keras.layers import Dense

sigmoid_model = Sequential()
sigmoid_model.add(Dense(128, input_dim=feature_count, activation='sigmoid'))
sigmoid_model.add(Dense(64, activation='sigmoid'))
sigmoid_model.add(Dense(64, activation='sigmoid'))
sigmoid_model.add(Dense(32, activation='sigmoid'))
sigmoid_model.add(Dense(5, activation='softmax'))

sigmoid_model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

history_sigmoid = sigmoid_model.fit(preprocessor(X_train), y_train_ohe,
                                    batch_size=20,
                                    epochs=300,
                                    validation_split=0.25,
                                    verbose=0)
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
import matplotlib.pyplot as plt

epochs = range(1, len(history_relu.history['loss']) + 1)

fig, axs = plt.subplots(2, 2, figsize=(14, 10))

# ReLU subplot
ax = axs[0, 0]
ax.plot(epochs, history_relu.history['loss'], label='Train Loss', color='red')
ax.plot(epochs, history_relu.history['val_loss'], label='Val Loss', color='orange')
ax.set_xlabel('Epoch')
ax.set_ylabel('Loss', color='red')
ax2 = ax.twinx()
ax2.plot(epochs, history_relu.history['accuracy'], label='Train Acc', color='blue')
ax2.plot(epochs, history_relu.history['val_accuracy'], label='Val Acc', color='cyan')
ax2.set_ylabel('Accuracy', color='blue')
ax.set_title('ReLU')
ax.legend(loc='upper left')
ax2.legend(loc='upper right')

# LeakyReLU subplot
ax = axs[0, 1]
ax.plot(epochs, history_leaky.history['loss'], label='Train Loss', color='red')
ax.plot(epochs, history_leaky.history['val_loss'], label='Val Loss', color='orange')
ax.set_xlabel('Epoch')
ax.set_ylabel('Loss', color='red')
ax2 = ax.twinx()
ax2.plot(epochs, history_leaky.history['accuracy'], label='Train Acc', color='blue')
ax2.plot(epochs, history_leaky.history['val_accuracy'], label='Val Acc', color='cyan')
ax2.set_ylabel('Accuracy', color='blue')
ax.set_title('LeakyReLU')
ax.legend(loc='upper left')
ax2.legend(loc='upper right')

# Tanh subplot
ax = axs[1, 0]
ax.plot(epochs, history_tanh.history['loss'], label='Train Loss', color='red')
ax.plot(epochs, history_tanh.history['val_loss'], label='Val Loss', color='orange')
ax.set_xlabel('Epoch')
ax.set_ylabel('Loss', color='red')
ax2 = ax.twinx()
ax2.plot(epochs, history_tanh.history['accuracy'], label='Train Acc', color='blue')
ax2.plot(epochs, history_tanh.history['val_accuracy'], label='Val Acc', color='cyan')
ax2.set_ylabel('Accuracy', color='blue')
ax.set_title('Tanh')
ax.legend(loc='upper left')
ax2.legend(loc='upper right')

# Sigmoid subplot
ax = axs[1, 1]
ax.plot(epochs, history_sigmoid.history['loss'], label='Train Loss', color='red')
ax.plot(epochs, history_sigmoid.history['val_loss'], label='Val Loss', color='orange')
ax.set_xlabel('Epoch')
ax.set_ylabel('Loss', color='red')
ax2 = ax.twinx()
ax2.plot(epochs, history_sigmoid.history['accuracy'], label='Train Acc', color='blue')
ax2.plot(epochs, history_sigmoid.history['val_accuracy'], label='Val Acc', color='cyan')
ax2.set_ylabel('Accuracy', color='blue')
ax.set_title('Sigmoid')
ax.legend(loc='upper left')
ax2.legend(loc='upper right')

plt.tight_layout()
plt.show()

# %% [markdown]
# ReLU: Shows rapid convergence with training accuracy quickly reaching near 100% and staying stable. Validation accuracy stabilizes around 40%, suggesting overfitting. Training loss drops to near zero while validation loss continues to increase.
# LeakyReLU: Similar pattern to ReLU but with slightly lower validation accuracy (around 30%), suggesting it's also suffering from overfitting but perhaps more severely.
# Tanh: Shows worse performance than ReLU with validation accuracy stabilizing at only about 30-35%. The gap between training and validation metrics indicates significant overfitting.
# Sigmoid: Demonstrates the most unstable training process with erratic training accuracy and the lowest validation accuracy (around 20%). The training process takes longer to converge compared to other activation functions.

# %% [markdown]
# # Explainability - SHAP Feature Importance
# To better understand our model's predictions, we will use SHAP (SHapley Additive exPlanations) to analyze feature importance.

# %%
# Import necessary libraries
import shap
import matplotlib.pyplot as plt

# Ensure SHAP works with RandomForestClassifier
explainer = shap.TreeExplainer(model_2)

# Transform X_test using preprocessor to ensure it's fully numeric
X_test_sample = np.array(preprocess.transform(X_test).toarray(), dtype=np.float64)[:100]

# Get the correct feature names from the preprocessor if possible
if hasattr(preprocess, 'get_feature_names_out'):
    feature_names = preprocess.get_feature_names_out()
else:
    # If can't get feature names from preprocessor, create generic names
    feature_names = [f"feature_{i}" for i in range(X_test_sample.shape[1])]

# Compute SHAP values
shap_values = explainer.shap_values(X_test_sample)

# Plot SHAP summary plot
plt.figure(figsize=(10, 6))
shap.summary_plot(shap_values, X_test_sample, feature_names=feature_names)

# Plot SHAP bar chart for feature importance
plt.figure(figsize=(10, 6))
shap.summary_plot(shap_values, X_test_sample, plot_type="bar", feature_names=feature_names)

# %%
# Try model_4


# Ensure SHAP works with KNeighborsClassifier
X_train_transformed = preprocessor(X_train)
X_test_transformed = preprocessor(X_test)

# Use KernelExplainer for non-tree models
explainer = shap.KernelExplainer(model_4.predict_proba, X_train_transformed[:100])

# Compute SHAP values on a subset of test data
X_test_sample = X_test_transformed[:100]
shap_values = explainer.shap_values(X_test_sample)

# Plot SHAP summary plot
plt.figure(figsize=(10, 6))
shap.summary_plot(shap_values, X_test_sample, feature_names=feature_names)

# Plot SHAP bar chart for feature importance
plt.figure(figsize=(10, 6))
shap.summary_plot(shap_values, X_test_sample, plot_type="bar", feature_names=feature_names)
# Out:
#   0%|          | 0/42 [00:00<?, ?it/s]

# %% [markdown]
# The SHAP analysis helps in understanding the contribution of each feature and their interactions in the model’s predictions, it is easy to integrate and provides intuitive visualizations for technical audiences.
# However, it can be computationally complex for large datasets and complex models.
